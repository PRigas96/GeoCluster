# %%
from itertools import product, combinations
import matplotlib.pyplot as plt
import numpy as np
from src import k_tree
from src.utils import data as dt
import torch
from src.k_tree import Ktree
from src.utils.data import loadData, loadData_3d
from src.metrics import Linf_3d

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
device = "cpu"
data, _ = loadData_3d(10000, 100)

learning_rate = 5e-3 # 1e-2, 5e-3
k = 4
teacher_args = {
    "optimizer_lr": learning_rate,
    "epochs": 800, # 300
    "times": 20,
    "alpha": 0.1, #  projection loss 0.1
    "beta": 0.1, # latent loss 0.1
    "gamma": 0.01, # repulsive loss 0.01
    #"gamma": 0.4, # repulsive loss 0.01
    "delta": 0.2, # fuzzy scale 0.01
    "f_clk": 10, # 20
    "scale": 1, # fuzzy scale 
    "scale_flag": False,
    "number_of_centroids": k,
    "latent_size": 200,
    "encoder_activation": False,
    "encoder_depth": 5,
    "predictor_width": 5*100,
    "predictor_depth": 5,
}
n = 20
un_args = {
    "N": n,
    "M": n**3-1, # 10000 - 1
    "epsilon": 0.15 # here a layer value should be somehow included. As layers get denser  epilson should be smaller
}
student_args = {
    "optimizer_lr": 5e-3,
    "epochs": 3000, # 30000, 3000
    "width": 200,
    "depth": 5,
}

# thresshold = 0.1 * len(data)
threshold = k * 100
ktree = Ktree(threshold, data, Linf_3d, teacher_args, un_args, student_args, device, 3)
ktree.create_tree()
# Out:
# Loading data...
# Data loaded.
#
# ====================
# Creating student for node 0 that has 9999 data, which is more than the threshold 400.
# Bounding box for node 0: [[-6, 4007], [-8, 4007], [-8, 4008]]
# Creating teacher for node 0 with 4 centroids.
# ====================
# Training Teacher Model
# Shuffling data
# ====================
# Epoch: 40/800..
#  Training loss: 2402.98755..
#  torch.mean(F): 2399.67651..
#  Reg Proj: 0.00000..
#  Reg Latent: 3.31046..
#  Repulsive: 0.00055..
#  Memory: 479.93530..
#  Memory: 479.93530..
#  Output:
#  [[ 626.0245   209.42534 1405.1426 ]
#  [ 454.03613  150.55302 1021.22845]
#  [ 252.99327   84.50912  568.4101 ]
#  [ 394.3664   132.12302  885.15186]]
# ====================
# Epoch: 80/800..
#  Training loss: 1564.89099..
#  torch.mean(F): 1471.13281..
#  Reg Proj: 92.64028..
#  Reg Latent: 1.11785..
#  Repulsive: 0.00016..
#  Memory: 294.22656..
#  Memory: 294.22656..
#  Output:
#  [[1804.2294  1005.48444 2751.9534 ]
#  [2824.924   1570.9458  4316.1343 ]
#  [1249.7477   695.6946  1907.3336 ]
#  [ 928.7075   519.90564 1407.6537 ]]
# ====================
# Epoch: 120/800..
#  Training loss: 1431.48401..
#  torch.mean(F): 1417.60986..
#  Reg Proj: 12.48499..
#  Reg Latent: 1.38898..
#  Repulsive: 0.00015..
#  Memory: 283.52197..
#  Memory: 283.52197..
#  Output:
#  [[ 647.933   537.6097 1236.2758]
#  [1526.3022 1318.1956 2861.8193]
#  [2172.5413 1915.1418 4048.95  ]
#  [1174.7803 1034.6357 2207.9722]]
# ====================
# Epoch: 160/800..
#  Training loss: 2154.29761..
#  torch.mean(F): 2154.13403..
#  Reg Proj: 0.00000..
#  Reg Latent: 0.16310..
#  Repulsive: 0.00060..
#  Memory: 430.82681..
#  Memory: 430.82681..
#  Output:
#  [[ 393.79297  797.99396  573.02637]
#  [ 621.55707 1267.8519   908.85657]
#  [ 220.79643  463.32654  328.65945]
#  [ 299.3271   615.18976  437.7567 ]]
# ====================
# Epoch: 200/800..
#  Training loss: 2134.30811..
#  torch.mean(F): 2134.11499..
#  Reg Proj: 0.00000..
#  Reg Latent: 0.19191..
#  Repulsive: 0.00127..
#  Memory: 426.82300..
#  Memory: 426.82300..
#  Output:
#  [[1167.9926   486.17807 1324.4586 ]
#  [ 651.7136   268.35773  750.47754]
#  [ 630.29535  266.58344  711.7176 ]
#  [1077.5043   453.84015 1212.4307 ]]
# ====================
# Epoch: 240/800..
#  Training loss: 2902.58667..
#  torch.mean(F): 2902.48535..
#  Reg Proj: 0.00000..
#  Reg Latent: 0.09141..
#  Repulsive: 0.01000..
#  Memory: 580.49707..
#  Memory: 580.49707..
#  Output:
#  [[42.367847 40.784317 23.855549]
#  [95.230194 89.91801  52.65093 ]
#  [71.94229  72.77952  42.797035]
#  [37.227283 37.53008  22.170444]]
# ====================
# Epoch: 280/800..
#  Training loss: 1589.20300..
#  torch.mean(F): 1589.10486..
#  Reg Proj: 0.00000..
#  Reg Latent: 0.09753..
#  Repulsive: 0.00058..
#  Memory: 317.82097..
#  Memory: 317.82097..
#  Output:
#  [[ 867.55145 1280.6716   899.0266 ]
#  [1334.3783  1985.7335  1380.0667 ]
#  [1122.5382  1689.0876  1158.5654 ]
#  [ 770.22363 1181.0284   788.0613 ]]
# ====================
# Epoch: 320/800..
#  Training loss: 2427.26782..
#  torch.mean(F): 2427.15186..
#  Reg Proj: 0.00000..
#  Reg Latent: 0.11467..
#  Repulsive: 0.00126..
#  Memory: 485.43037..
#  Memory: 485.43037..
#  Output:
#  [[446.7836  645.9643  558.9606 ]
#  [280.36185 415.35767 358.0408 ]
#  [490.42526 727.6708  626.301  ]
#  [351.22794 525.45734 449.57297]]
# ====================
# Epoch: 360/800..
#  Training loss: 2664.71655..
#  torch.mean(F): 2664.49316..
#  Reg Proj: 0.00000..
#  Reg Latent: 0.21360..
#  Repulsive: 0.00975..
#  Memory: 532.89863..
#  Memory: 532.89863..
#  Output:
#  [[212.33926 238.62769 209.73712]
#  [215.3064  234.74419 205.97702]
#  [264.55093 288.42245 253.05846]
#  [337.5536  354.73724 311.02548]]
# ====================
# Epoch: 400/800..
#  Training loss: 2752.84546..
#  torch.mean(F): 2752.70508..
#  Reg Proj: 0.00000..
#  Reg Latent: 0.13729..
#  Repulsive: 0.00306..
#  Memory: 550.54102..
#  Memory: 550.54102..
#  Output:
#  [[251.7944  117.6216  165.59912]
#  [357.65488 168.32161 234.41734]
#  [270.72952 127.67304 177.12312]
#  [172.81387  81.55251 112.56201]]
# ====================
# Epoch: 440/800..
#  Training loss: 1374.92957..
#  torch.mean(F): 1374.65063..
#  Reg Proj: 0.00000..
#  Reg Latent: 0.27834..
#  Repulsive: 0.00063..
#  Memory: 274.93013..
#  Memory: 274.93013..
#  Output:
#  [[1114.9166 1033.5739 1329.2365]
#  [1888.9266 1753.9883 2255.047 ]
#  [1388.2151 1286.9257 1657.0645]
#  [1201.2772 1114.884  1434.4219]]
# ====================
# Epoch: 480/800..
#  Training loss: 1684.33411..
#  torch.mean(F): 1684.07104..
#  Reg Proj: 0.00000..
#  Reg Latent: 0.26225..
#  Repulsive: 0.00086..
#  Memory: 336.81421..
#  Memory: 336.81421..
#  Output:
#  [[ 812.85406  662.6702   896.0703 ]
#  [1385.7991  1131.2725  1530.0844 ]
#  [1016.7903   827.614   1121.2645 ]
#  [ 928.7701   756.19037 1025.7181 ]]
# ====================
# Epoch: 520/800..
#  Training loss: 2515.08667..
#  torch.mean(F): 2514.75073..
#  Reg Proj: 0.00000..
#  Reg Latent: 0.33214..
#  Repulsive: 0.00398..
#  Memory: 502.95015..
#  Memory: 502.95015..
#  Output:
#  [[376.20044 349.1845  448.92087]
#  [303.5444  279.09598 357.85468]
#  [405.91208 376.93173 485.1567 ]
#  [362.92188 336.28098 430.4238 ]]
# ====================
# Epoch: 560/800..
#  Training loss: 1605.20715..
#  torch.mean(F): 1603.82458..
#  Reg Proj: 0.00000..
#  Reg Latent: 1.38207..
#  Repulsive: 0.00043..
#  Memory: 320.76492..
#  Memory: 320.76492..
#  Output:
#  [[2238.3018   785.4432  2147.1653 ]
#  [ 744.5812   258.9176   715.4419 ]
#  [2381.0989   836.57196 2283.7422 ]
#  [1905.9258   666.5501  1827.6018 ]]
# ====================
# Epoch: 600/800..
#  Training loss: 1685.24719..
#  torch.mean(F): 1684.45874..
#  Reg Proj: 0.00000..
#  Reg Latent: 0.78780..
#  Repulsive: 0.00056..
#  Memory: 336.89175..
#  Memory: 336.89175..
#  Output:
#  [[2193.8467  698.9701 1968.3545]
#  [1077.9963  339.8747  966.0939]
#  [2288.8208  730.5835 2053.4663]
#  [1855.1875  588.2523 1662.7151]]
# ====================
# Epoch: 640/800..
#  Training loss: 2581.81348..
#  torch.mean(F): 2581.68188..
#  Reg Proj: 0.00000..
#  Reg Latent: 0.12694..
#  Repulsive: 0.00473..
#  Memory: 516.33638..
#  Memory: 516.33638..
#  Output:
#  [[340.28125 380.44098 289.96057]
#  [270.5441  292.31766 216.875  ]
#  [262.85968 291.12347 225.3256 ]
#  [474.4765  509.06995 378.02457]]
# ====================
# Epoch: 680/800..
#  Training loss: 2829.63599..
#  torch.mean(F): 2829.27124..
#  Reg Proj: 0.00000..
#  Reg Latent: 0.35753..
#  Repulsive: 0.00740..
#  Memory: 565.85425..
#  Memory: 565.85425..
#  Output:
#  [[ 71.889404 172.59322  217.63805 ]
#  [ 54.589424 128.69434  169.67705 ]
#  [ 54.898125 133.90831  163.80368 ]
#  [ 31.497217  75.599236  96.57618 ]]
# ====================
# Epoch: 720/800..
#  Training loss: 1377.59912..
#  torch.mean(F): 1377.50183..
#  Reg Proj: 0.00000..
#  Reg Latent: 0.09676..
#  Repulsive: 0.00055..
#  Memory: 275.50037..
#  Memory: 275.50037..
#  Output:
#  [[ 934.8888 1239.891  1316.6354]
#  [1459.7592 1916.7607 1925.8324]
#  [1584.1222 2101.4226 2115.3716]
#  [ 910.8229 1197.2787 1190.3417]]
# ====================
# Epoch: 760/800..
#  Training loss: 3253.42969..
#  torch.mean(F): 2100.93726..
#  Reg Proj: 1152.36934..
#  Reg Latent: 0.11876..
#  Repulsive: 0.00444..
#  Memory: 420.18745..
#  Memory: 420.18745..
#  Output:
#  [[1770.3154 5465.4653 2370.3306]
#  [1686.0154 5200.5527 2244.1914]
#  [1224.9756 3776.0974 1643.1849]
#  [1686.8405 5197.2134 2251.412 ]]
# ====================
# Epoch: 800/800..
#  Training loss: 2877.16919..
#  torch.mean(F): 2877.11377..
#  Reg Proj: 0.00000..
#  Reg Latent: 0.05326..
#  Repulsive: 0.00220..
#  Memory: 575.42275..
#  Memory: 575.42275..
#  Output:
#  [[111.47838   68.57754  188.79346 ]
#  [ 76.2294    46.72128  136.67348 ]
#  [ 21.290411   9.831744  10.421467]
#  [ 31.567686  21.271276  62.522686]]
# ====================
# getUncertaintyArea
# Ouputs are [[ 462.27887 1226.3429  1617.9702 ]
#  [2717.2832  2029.9409  2612.9714 ]
#  [1533.0676  1868.7135  2325.7144 ]
#  [1455.6178  1320.0609  2431.4033 ]]
# scale is 4016
# dx is 4013.0, dy is 4015.0, dz is 4016.0
# z is torch.Size([8000])
# Processing...
# flag is 3284
# m is 4717
# i is 8000
# Labeled 0/4717 points.
# Labeled 1000/4717 points.
# Labeled 2000/4717 points.
# Labeled 3000/4717 points.
# Labeled 4000/4717 points.
# Labeled all 4717/4717 points.
# Creating student for node 0 with 4 centroids.
# Device is: cpu
# ====================
# Training Student Model
# Acc:  0.14627941488234047
# Epoch:  0 Cost:  5449.31494140625
# Acc:  0.7502649989400042
# Epoch:  300 Cost:  60.73760986328125
# Acc:  0.8267966928132288
# Epoch:  600 Cost:  42.682861328125
# Acc:  0.8541445834216663
# Epoch:  900 Cost:  37.85008239746094
# Acc:  0.6453254186983252
# Epoch:  1200 Cost:  78.56231689453125
# Acc:  0.6970532117871528
# Epoch:  1500 Cost:  65.56122589111328
# Acc:  0.8017807928768285
# Epoch:  1800 Cost:  55.74409866333008
# Acc:  0.8562645749417003
# Epoch:  2100 Cost:  44.8266716003418
# Acc:  0.8976044095823617
# Epoch:  2400 Cost:  33.776424407958984
# Acc:  0.9090523637905449
# Epoch:  2700 Cost:  28.542591094970703
#
# ====================
# Creating student for node 00 that has 1871 data, which is more than the threshold 400.
# Bounding box for node 00: [[-5, 2767], [-8, 3525], [-8, 3050]]
# Creating teacher for node 00 with 4 centroids.
# ====================
# Training Teacher Model
# Shuffling data
# ====================
# Epoch: 40/800..
#  Training loss: 1841.31970..
#  torch.mean(F): 1841.23132..
#  Reg Proj: 0.00000..
#  Reg Latent: 0.08049..
#  Repulsive: 0.00795..
#  Memory: 368.24626..
#  Memory: 368.24626..
#  Output:
#  [[ 90.1947   107.3673    60.57604 ]
#  [ 68.49131   81.11335   45.953808]
#  [ 71.44558   88.90897   47.08896 ]
#  [134.05179  160.43298   89.51552 ]]
# ====================
# Epoch: 80/800..
#  Training loss: 1087.40820..
#  torch.mean(F): 1087.26343..
#  Reg Proj: 0.00000..
#  Reg Latent: 0.14430..
#  Repulsive: 0.00044..
#  Memory: 217.45269..
#  Memory: 217.45269..
#  Output:
#  [[ 472.58832  665.2938   274.41824]
#  [ 911.7799  1293.25     522.00256]
#  [ 279.06424  401.1794   156.99248]
#  [ 681.2188   968.1956   387.7415 ]]
# ====================
# Epoch: 120/800..
#  Training loss: 1049.87927..
#  torch.mean(F): 1049.80237..
#  Reg Proj: 0.00003..
#  Reg Latent: 0.07543..
#  Repulsive: 0.00148..
#  Memory: 209.96047..
#  Memory: 209.96047..
#  Output:
#  [[825.32837 907.60895 861.1986 ]
#  [676.90826 745.646   705.66724]
#  [577.91595 639.08575 599.7154 ]
#  [760.8842  839.22906 791.24615]]
# ====================
# Epoch: 160/800..
#  Training loss: 896.15649..
#  torch.mean(F): 895.94775..
#  Reg Proj: 0.16132..
#  Reg Latent: 0.04677..
#  Repulsive: 0.00064..
#  Memory: 179.18955..
#  Memory: 179.18955..
#  Output:
#  [[1137.8656   922.76196  864.5974 ]
#  [1334.1328  1071.1427  1004.9194 ]
#  [ 951.0136   748.8582   704.93195]
#  [1564.1034  1249.4563  1173.614  ]]
# ====================
# Epoch: 200/800..
#  Training loss: 1151.96313..
#  torch.mean(F): 1151.92334..
#  Reg Proj: 0.00001..
#  Reg Latent: 0.03831..
#  Repulsive: 0.00148..
#  Memory: 230.38467..
#  Memory: 230.38467..
#  Output:
#  [[949.1779  939.5042  753.8964 ]
#  [908.07306 906.25684 725.8588 ]
#  [611.34686 619.79504 494.90588]
#  [734.5342  737.7009  590.152  ]]
# ====================
# Epoch: 240/800..
#  Training loss: 894.47333..
#  torch.mean(F): 892.72638..
#  Reg Proj: 1.71182..
#  Reg Latent: 0.03446..
#  Repulsive: 0.00067..
#  Memory: 178.54528..
#  Memory: 178.54528..
#  Output:
#  [[1292.3385  1189.2616  1418.111  ]
#  [1227.4406  1127.5653  1321.8336 ]
#  [ 937.6601   859.4615   983.76764]
#  [1627.1063  1493.5785  1739.5457 ]]
# ====================
# Epoch: 280/800..
#  Training loss: 1329.36682..
#  torch.mean(F): 1329.34119..
#  Reg Proj: 0.00000..
#  Reg Latent: 0.02367..
#  Repulsive: 0.00191..
#  Memory: 265.86824..
#  Memory: 265.86824..
#  Output:
#  [[723.45966 567.92566 490.04178]
#  [496.72568 387.3552  334.69934]
#  [463.62903 357.44144 309.65613]
#  [597.62866 463.1854  400.6672 ]]
# ====================
# Epoch: 320/800..
#  Training loss: 1130.02539..
#  torch.mean(F): 1129.99963..
#  Reg Proj: 0.00100..
#  Reg Latent: 0.02371..
#  Repulsive: 0.00112..
#  Memory: 225.99993..
#  Memory: 225.99993..
#  Output:
#  [[950.7736  720.5482  936.9395 ]
#  [992.2334  757.78644 978.3055 ]
#  [367.756   287.16354 363.43372]
#  [660.06757 508.79105 651.4334 ]]
# ====================
# Epoch: 360/800..
#  Training loss: 979.47394..
#  torch.mean(F): 979.45441..
#  Reg Proj: 0.00001..
#  Reg Latent: 0.01887..
#  Repulsive: 0.00068..
#  Memory: 195.89088..
#  Memory: 195.89088..
#  Output:
#  [[ 744.1119  1164.3376   745.4828 ]
#  [ 668.9336  1033.6453   664.5599 ]
#  [ 333.93674  498.97876  325.54794]
#  [ 850.6463  1311.6398   844.87915]]
# ====================
# Epoch: 400/800..
#  Training loss: 1052.27344..
#  torch.mean(F): 1052.25745..
#  Reg Proj: 0.00000..
#  Reg Latent: 0.01422..
#  Repulsive: 0.00181..
#  Memory: 210.45149..
#  Memory: 210.45149..
#  Output:
#  [[ 619.76     764.1316   562.9703 ]
#  [ 598.5116   754.089    532.44025]
#  [ 839.8302  1061.9623   742.94135]
#  [ 703.29083  890.17865  622.48474]]
# ====================
# Epoch: 440/800..
#  Training loss: 1181.65198..
#  torch.mean(F): 1181.64099..
#  Reg Proj: 0.00000..
#  Reg Latent: 0.00954..
#  Repulsive: 0.00146..
#  Memory: 236.32820..
#  Memory: 236.32820..
#  Output:
#  [[506.0915  791.799   592.5626 ]
#  [458.9711  693.0792  565.19   ]
#  [614.0953  850.96356 774.3742 ]
#  [553.4678  856.73987 686.96014]]
# ====================
# Epoch: 480/800..
#  Training loss: 1233.08643..
#  torch.mean(F): 1233.07764..
#  Reg Proj: 0.00000..
#  Reg Latent: 0.00679..
#  Repulsive: 0.00190..
#  Memory: 246.61553..
#  Memory: 246.61553..
#  Output:
#  [[638.42554 662.3197  503.12244]
#  [544.2327  582.48047 450.92297]
#  [674.3326  766.88586 619.7118 ]
#  [688.3353  721.5969  552.5918 ]]
# ====================
# Epoch: 520/800..
#  Training loss: 1236.99707..
#  torch.mean(F): 1236.99036..
#  Reg Proj: 0.00000..
#  Reg Latent: 0.00515..
#  Repulsive: 0.00159..
#  Memory: 247.39807..
#  Memory: 247.39807..
#  Output:
#  [[565.4575  579.8998  451.6203 ]
#  [488.12036 531.2795  380.9102 ]
#  [655.52924 757.47925 483.31467]
#  [615.75256 667.43976 489.06378]]
# ====================
# Epoch: 560/800..
#  Training loss: 1234.56201..
#  torch.mean(F): 1234.55652..
#  Reg Proj: 0.00001..
#  Reg Latent: 0.00411..
#  Repulsive: 0.00130..
#  Memory: 246.91130..
#  Memory: 246.91130..
#  Output:
#  [[614.60565 513.4754  552.5309 ]
#  [579.35333 426.22034 479.22867]
#  [844.57294 544.4003  680.12384]
#  [747.4017  555.4985  606.48883]]
# ====================
# Epoch: 600/800..
#  Training loss: 1245.42920..
#  torch.mean(F): 1245.42395..
#  Reg Proj: 0.00001..
#  Reg Latent: 0.00340..
#  Repulsive: 0.00185..
#  Memory: 249.08479..
#  Memory: 249.08479..
#  Output:
#  [[486.10455 558.6642  576.95685]
#  [398.03296 471.7494  493.51697]
#  [520.5265  665.6737  709.2448 ]
#  [526.69653 610.0314  633.3584 ]]
# ====================
# Epoch: 640/800..
#  Training loss: 1111.22278..
#  torch.mean(F): 1111.21838..
#  Reg Proj: 0.00046..
#  Reg Latent: 0.00287..
#  Repulsive: 0.00115..
#  Memory: 222.24368..
#  Memory: 222.24368..
#  Output:
#  [[ 610.72754  579.2224   870.00854]
#  [ 515.47064  525.7679   726.27905]
#  [ 751.10236  769.4373  1049.212  ]
#  [ 673.10144  698.4359   951.7878 ]]
# ====================
# Epoch: 680/800..
#  Training loss: 1157.15308..
#  torch.mean(F): 1157.14087..
#  Reg Proj: 0.00002..
#  Reg Latent: 0.00954..
#  Repulsive: 0.00272..
#  Memory: 231.42817..
#  Memory: 231.42817..
#  Output:
#  [[409.52777 737.48584 646.2988 ]
#  [556.5581  926.5999  833.32745]
#  [452.86127 758.1518  689.9893 ]
#  [468.90515 789.1156  703.3391 ]]
# ====================
# Epoch: 720/800..
#  Training loss: 996.18958..
#  torch.mean(F): 996.16809..
#  Reg Proj: 0.01026..
#  Reg Latent: 0.00762..
#  Repulsive: 0.00361..
#  Memory: 199.23362..
#  Memory: 199.23362..
#  Output:
#  [[ 629.22595 1813.9242  1307.3986 ]
#  [ 499.35138 1473.389   1056.7078 ]
#  [ 500.1993  1483.5541  1065.5035 ]
#  [ 467.55038 1334.1326   964.4504 ]]
# ====================
# Epoch: 760/800..
#  Training loss: 1262.92444..
#  torch.mean(F): 1262.84558..
#  Reg Proj: 0.00000..
#  Reg Latent: 0.07710..
#  Repulsive: 0.00169..
#  Memory: 252.56912..
#  Memory: 252.56912..
#  Output:
#  [[554.11957 524.2739  469.374  ]
#  [742.78186 703.4658  625.8412 ]
#  [434.72955 411.84973 364.79022]
#  [591.9246  556.5418  504.98517]]
# ====================
# Epoch: 800/800..
#  Training loss: 1207.22449..
#  torch.mean(F): 1207.21008..
#  Reg Proj: 0.00000..
#  Reg Latent: 0.01315..
#  Repulsive: 0.00122..
#  Memory: 241.44202..
#  Memory: 241.44202..
#  Output:
#  [[482.80884 610.3986  294.97913]
#  [381.373   481.444   235.02835]
#  [639.093   807.9141  389.3202 ]
#  [568.02386 718.5562  342.16537]]
# ====================
# getUncertaintyArea
# Ouputs are [[ 839.9742  1851.4885  1966.0969 ]
#  [1164.285   1894.2755  1437.1187 ]
#  [ 700.3373  1140.6813   998.0611 ]
#  [ 638.00977 1830.5522  1341.6354 ]]
# scale is 3533
# dx is 2772.0, dy is 3533.0, dz is 3058.0
# z is torch.Size([8000])
# Processing...
# flag is 1282
# m is 6719
# i is 8000
# Labeled 0/6719 points.
# Labeled 1000/6719 points.
# Labeled 2000/6719 points.
# Labeled 3000/6719 points.
# Labeled 4000/6719 points.
# Labeled 5000/6719 points.
# Labeled 6000/6719 points.
# Labeled all 6719/6719 points.
# Creating student for node 00 with 4 centroids.
# Device is: cpu
# ====================
# Training Student Model
# Acc:  0.39232028575680905
# Epoch:  0 Cost:  2082.164306640625
# Acc:  0.7846405715136181
# Epoch:  300 Cost:  45.667110443115234
# Acc:  0.8691769608572705
# Epoch:  600 Cost:  35.66939926147461
# Acc:  0.8993897901473433
# Epoch:  900 Cost:  29.001266479492188
# Acc:  0.9115939872004762
# Epoch:  1200 Cost:  24.108705520629883
# Acc:  0.9218633725256734
# Epoch:  1500 Cost:  22.10008430480957
# Acc:  0.89641315671975
# Epoch:  1800 Cost:  26.078445434570312
# Acc:  0.9193332341122191
# Epoch:  2100 Cost:  20.77562713623047
# Acc:  0.9124869772287543
# Epoch:  2400 Cost:  19.902141571044922
# Acc:  0.9020687602321774
# Epoch:  2700 Cost:  23.181385040283203
#
# ====================
# Creating student for node 01 that has 3899 data, which is more than the threshold 400.
# Bounding box for node 01: [[701, 4007], [-8, 4007], [183, 4008]]
# Creating teacher for node 01 with 4 centroids.
# ====================
# Training Teacher Model
# Shuffling data
# ====================
# Epoch: 40/800..
#  Training loss: 2632.83862..
#  torch.mean(F): 2612.16284..
#  Reg Proj: 20.16278..
#  Reg Latent: 0.51027..
#  Repulsive: 0.00264..
#  Memory: 522.43257..
#  Memory: 522.43257..
#  Output:
#  [[915.1798  769.0313  900.7478 ]
#  [905.846   736.1367  879.2129 ]
#  [970.46375 792.0603  943.9934 ]
#  [804.2458  653.05133 780.3286 ]]
# ====================
# Epoch: 80/800..
#  Training loss: 1747.87073..
#  torch.mean(F): 1747.60022..
#  Reg Proj: 0.00355..
#  Reg Latent: 0.26489..
#  Repulsive: 0.00213..
#  Memory: 349.52004..
#  Memory: 349.52004..
#  Output:
#  [[3865.8264 1590.6052 1267.1742]
#  [3951.8208 1668.0125 1380.2852]
#  [3807.8198 1610.3584 1336.5433]
#  [3879.611  1631.7966 1343.569 ]]
# ====================
# Epoch: 120/800..
#  Training loss: 2726.03149..
#  torch.mean(F): 2701.28540..
#  Reg Proj: 24.38923..
#  Reg Latent: 0.35522..
#  Repulsive: 0.00180..
#  Memory: 540.25708..
#  Memory: 540.25708..
#  Output:
#  [[ 738.5039   515.2788  1664.0392 ]
#  [ 668.82635  489.8604  1676.1404 ]
#  [ 718.46497  533.6053  1844.1237 ]
#  [ 726.64795  525.7595  1760.8881 ]]
# ====================
# Epoch: 160/800..
#  Training loss: 1312.18054..
#  torch.mean(F): 1311.46814..
#  Reg Proj: 0.20654..
#  Reg Latent: 0.50148..
#  Repulsive: 0.00441..
#  Memory: 262.29363..
#  Memory: 262.29363..
#  Output:
#  [[2819.533  2389.8335 1929.068 ]
#  [2521.64   2152.2073 1734.6749]
#  [2503.9893 2144.1782 1726.5979]
#  [2540.5583 2163.194  1744.6759]]
# ====================
# Epoch: 200/800..
#  Training loss: 1222.43152..
#  torch.mean(F): 1222.03125..
#  Reg Proj: 0.25277..
#  Reg Latent: 0.14680..
#  Repulsive: 0.00056..
#  Memory: 244.40625..
#  Memory: 244.40625..
#  Output:
#  [[3310.7554 2027.2161 2152.8113]
#  [3404.4377 2103.9253 2215.3655]
#  [2354.697  1478.3507 1542.101 ]
#  [2877.093  1765.5005 1867.1423]]
# ====================
# Epoch: 240/800..
#  Training loss: 1840.98560..
#  torch.mean(F): 1836.49487..
#  Reg Proj: 4.36079..
#  Reg Latent: 0.12582..
#  Repulsive: 0.00404..
#  Memory: 367.29897..
#  Memory: 367.29897..
#  Output:
#  [[1806.5845 1692.124  1441.4524]
#  [1779.0586 1657.4409 1404.9558]
#  [1704.3214 1578.6482 1338.3595]
#  [1691.554  1593.8805 1353.198 ]]
# ====================
# Epoch: 280/800..
#  Training loss: 1383.42639..
#  torch.mean(F): 1382.62195..
#  Reg Proj: 0.62505..
#  Reg Latent: 0.17826..
#  Repulsive: 0.00117..
#  Memory: 276.52439..
#  Memory: 276.52439..
#  Output:
#  [[2199.012  1596.7278 2065.8613]
#  [2012.0553 1461.6632 1891.8131]
#  [2386.5552 1735.0421 2254.5164]
#  [2334.355  1695.0574 2188.3882]]
# ====================
# Epoch: 320/800..
#  Training loss: 1820.04150..
#  torch.mean(F): 1817.01929..
#  Reg Proj: 2.77433..
#  Reg Latent: 0.24261..
#  Repulsive: 0.00534..
#  Memory: 363.40386..
#  Memory: 363.40386..
#  Output:
#  [[1488.4532 2362.1868 1611.0695]
#  [1466.873  2330.7356 1568.6501]
#  [1520.9594 2407.9395 1605.9045]
#  [1469.1074 2338.1702 1582.9827]]
# ====================
# Epoch: 360/800..
#  Training loss: 1043.34155..
#  torch.mean(F): 1043.03149..
#  Reg Proj: 0.02247..
#  Reg Latent: 0.28706..
#  Repulsive: 0.00054..
#  Memory: 208.60630..
#  Memory: 208.60630..
#  Output:
#  [[2926.2544 2521.5916 2613.0872]
#  [2401.9836 2068.244  2137.7454]
#  [3605.7905 3105.167  3216.2593]
#  [2826.9336 2434.6604 2534.514 ]]
# ====================
# Epoch: 400/800..
#  Training loss: 1187.86682..
#  torch.mean(F): 1178.33789..
#  Reg Proj: 9.35221..
#  Reg Latent: 0.17126..
#  Repulsive: 0.00554..
#  Memory: 235.66758..
#  Memory: 235.66758..
#  Output:
#  [[2828.233  2154.171  2644.5254]
#  [4070.8228 3101.4766 3807.7993]
#  [4076.867  3103.7007 3809.7537]
#  [4186.0317 3197.3992 3927.9785]]
# ====================
# Epoch: 440/800..
#  Training loss: 2033.96948..
#  torch.mean(F): 2025.53552..
#  Reg Proj: 8.25846..
#  Reg Latent: 0.17190..
#  Repulsive: 0.00372..
#  Memory: 405.10710..
#  Memory: 405.10710..
#  Output:
#  [[1469.6523 1482.6991 1515.9458]
#  [1315.6829 1329.4438 1356.3644]
#  [1262.9657 1265.4515 1295.5928]
#  [1312.6082 1342.235  1363.508 ]]
# ====================
# Epoch: 480/800..
#  Training loss: 1743.32581..
#  torch.mean(F): 1740.29724..
#  Reg Proj: 2.88901..
#  Reg Latent: 0.13291..
#  Repulsive: 0.00659..
#  Memory: 348.05945..
#  Memory: 348.05945..
#  Output:
#  [[1802.6553 1608.2753 1603.218 ]
#  [1812.0763 1614.9491 1611.4801]
#  [1856.972  1659.6305 1651.2375]
#  [1879.1891 1669.9635 1671.4464]]
# ====================
# Epoch: 520/800..
#  Training loss: 1292.50281..
#  torch.mean(F): 1291.57373..
#  Reg Proj: 0.79145..
#  Reg Latent: 0.13617..
#  Repulsive: 0.00145..
#  Memory: 258.31475..
#  Memory: 258.31475..
#  Output:
#  [[2025.1737 1579.4677 1874.0387]
#  [2515.4714 1968.8008 2327.0464]
#  [2121.3044 1648.8516 1961.5768]
#  [2155.7324 1692.7152 1994.7125]]
# ====================
# Epoch: 560/800..
#  Training loss: 1277.45398..
#  torch.mean(F): 1277.19299..
#  Reg Proj: 0.06382..
#  Reg Latent: 0.19616..
#  Repulsive: 0.00093..
#  Memory: 255.43860..
#  Memory: 255.43860..
#  Output:
#  [[3174.5298 1992.5553 1798.7881]
#  [2671.1682 1674.4332 1510.9984]
#  [3336.9358 2091.679  1886.3782]
#  [3401.3345 2133.323  1928.168 ]]
# ====================
# Epoch: 600/800..
#  Training loss: 1266.14832..
#  torch.mean(F): 1266.04810..
#  Reg Proj: 0.00009..
#  Reg Latent: 0.09948..
#  Repulsive: 0.00061..
#  Memory: 253.20962..
#  Memory: 253.20962..
#  Output:
#  [[3102.095  2779.0586 2629.8735]
#  [3947.761  3541.0837 3356.4097]
#  [3243.6855 2906.7097 2749.0635]
#  [3422.3872 3070.3667 2911.6233]]
# ====================
# Epoch: 640/800..
#  Training loss: 1302.31873..
#  torch.mean(F): 1297.85693..
#  Reg Proj: 4.29905..
#  Reg Latent: 0.16183..
#  Repulsive: 0.00082..
#  Memory: 259.57139..
#  Memory: 259.57139..
#  Output:
#  [[2466.9116 2822.7522 2814.5251]
#  [3396.3772 4084.5496 3986.4792]
#  [3469.3274 4068.791  4011.6602]
#  [2562.5269 2884.233  2892.4778]]
# ====================
# Epoch: 680/800..
#  Training loss: 1306.17908..
#  torch.mean(F): 1306.00610..
#  Reg Proj: 0.01946..
#  Reg Latent: 0.15229..
#  Repulsive: 0.00124..
#  Memory: 261.20122..
#  Memory: 261.20122..
#  Output:
#  [[2914.2876 1648.6805 2129.7463]
#  [3051.8164 1699.2986 2271.8914]
#  [2981.0286 1667.5472 2215.9229]
#  [2624.1978 1488.6481 1905.3058]]
# ====================
# Epoch: 720/800..
#  Training loss: 1331.33643..
#  torch.mean(F): 1321.73792..
#  Reg Proj: 9.37430..
#  Reg Latent: 0.22356..
#  Repulsive: 0.00071..
#  Memory: 264.34758..
#  Memory: 264.34758..
#  Output:
#  [[3625.8552 2979.693  2332.68  ]
#  [4319.805  3488.468  2660.2737]
#  [3709.1658 2979.9365 2254.1274]
#  [3396.824  2813.3618 2199.02  ]]
# ====================
# Epoch: 760/800..
#  Training loss: 2782.60498..
#  torch.mean(F): 2759.32544..
#  Reg Proj: 23.11448..
#  Reg Latent: 0.14963..
#  Repulsive: 0.01549..
#  Memory: 551.86509..
#  Memory: 551.86509..
#  Output:
#  [[764.4587  740.7371  738.6867 ]
#  [755.82025 730.5882  723.45294]
#  [772.6153  745.87604 734.99176]
#  [766.70807 746.9061  746.1138 ]]
# ====================
# Epoch: 800/800..
#  Training loss: 2051.30347..
#  torch.mean(F): 2011.92676..
#  Reg Proj: 38.65045..
#  Reg Latent: 0.72617..
#  Repulsive: 0.00030..
#  Memory: 402.38535..
#  Memory: 402.38535..
#  Output:
#  [[4455.732   1824.8795   818.93036]
#  [3511.2014  1257.2498   641.0466 ]
#  [4817.4233  1744.8903   880.34735]
#  [3822.9785  1626.497    683.6139 ]]
# ====================
# getUncertaintyArea
# Ouputs are [[2276.1372 1985.6222 1970.0073]
#  [2893.6636 2802.638  2506.9167]
#  [2317.3945 2538.8684 2867.4453]
#  [2594.4065 2568.827  2444.7188]]
# scale is 4015
# dx is 3306.0, dy is 4015.0, dz is 3825.0
# z is torch.Size([8000])
# Processing...
# flag is 334
# m is 7667
# i is 8000
# Labeled 0/7667 points.
# Labeled 1000/7667 points.
# Labeled 2000/7667 points.
# Labeled 3000/7667 points.
# Labeled 4000/7667 points.
# Labeled 5000/7667 points.
# Labeled 6000/7667 points.
# Labeled 7000/7667 points.
# Labeled all 7667/7667 points.
# Creating student for node 01 with 4 centroids.
# Device is: cpu
# ====================
# Training Student Model
# Acc:  0.15260206077996608
# Epoch:  0 Cost:  10734.728515625
# Acc:  0.7931394287204904
# Epoch:  300 Cost:  47.7227668762207
# Acc:  0.8477892265553671
# Epoch:  600 Cost:  40.76084518432617
# Acc:  0.8729620451284726
# Epoch:  900 Cost:  32.98624038696289
# Acc:  0.88991782965958
# Epoch:  1200 Cost:  28.914325714111328
# Acc:  0.8870483892004696
# Epoch:  1500 Cost:  28.30595588684082
# Acc:  0.8163558106169297
# Epoch:  1800 Cost:  45.71862030029297
# Acc:  0.8691796008869179
# Epoch:  2100 Cost:  35.64672088623047
# Acc:  0.8750489109169166
# Epoch:  2400 Cost:  32.17413330078125
# Acc:  0.8921351245598017
# Epoch:  2700 Cost:  28.134546279907227
#
# ====================
# Creating student for node 02 that has 2733 data, which is more than the threshold 400.
# Bounding box for node 02: [[-6, 4000], [-7, 4007], [-7, 3996]]
# Creating teacher for node 02 with 4 centroids.
# ====================
# Training Teacher Model
# Shuffling data
# ====================
# Epoch: 40/800..
#  Training loss: 2039.50574..
#  torch.mean(F): 2027.20032..
#  Reg Proj: 11.93530..
#  Reg Latent: 0.36993..
#  Repulsive: 0.00025..
#  Memory: 405.44006..
#  Memory: 405.44006..
#  Output:
#  [[1995.3866  2461.2168  4123.8022 ]
#  [1851.6122  2286.5054  3827.9004 ]
#  [  83.75922  101.07346  171.7139 ]
#  [1672.5957  2066.18    3458.2483 ]]
# ====================
# Epoch: 80/800..
#  Training loss: 1386.57190..
#  torch.mean(F): 1384.87573..
#  Reg Proj: 1.10961..
#  Reg Latent: 0.58579..
#  Repulsive: 0.00076..
#  Memory: 276.97515..
#  Memory: 276.97515..
#  Output:
#  [[ 979.2575  2257.199   2398.0464 ]
#  [ 944.9829  2175.8635  2289.4626 ]
#  [ 715.5679  1649.4952  1761.7112 ]
#  [ 876.94434 2019.8744  2126.0247 ]]
# ====================
# Epoch: 120/800..
#  Training loss: 2275.61133..
#  torch.mean(F): 2262.56738..
#  Reg Proj: 12.58193..
#  Reg Latent: 0.46115..
#  Repulsive: 0.00065..
#  Memory: 452.51348..
#  Memory: 452.51348..
#  Output:
#  [[ 403.37195  193.84058  510.2061 ]
#  [ 234.21806  114.12336  293.30295]
#  [ 481.02023  230.35202  612.66235]
#  [ 952.3072   458.9815  1209.3518 ]]
# ====================
# Epoch: 160/800..
#  Training loss: 2764.01709..
#  torch.mean(F): 2747.55127..
#  Reg Proj: 16.13686..
#  Reg Latent: 0.29709..
#  Repulsive: 0.03165..
#  Memory: 549.51025..
#  Memory: 549.51025..
#  Output:
#  [[185.7499  156.02635 190.5948 ]
#  [200.83522 168.51494 204.29619]
#  [193.3701  162.07954 198.31082]
#  [195.11812 164.2549  200.5341 ]]
# ====================
# Epoch: 200/800..
#  Training loss: 2146.82080..
#  torch.mean(F): 2134.72583..
#  Reg Proj: 11.88142..
#  Reg Latent: 0.21230..
#  Repulsive: 0.00134..
#  Memory: 426.94517..
#  Memory: 426.94517..
#  Output:
#  [[ 541.03107  594.81854 1049.6604 ]
#  [ 708.13434  779.62836 1372.469  ]
#  [ 585.7791   642.76764 1138.526  ]
#  [ 626.38556  690.5706  1211.8131 ]]
# ====================
# Epoch: 240/800..
#  Training loss: 1901.08374..
#  torch.mean(F): 1889.94824..
#  Reg Proj: 10.95490..
#  Reg Latent: 0.17673..
#  Repulsive: 0.00379..
#  Memory: 377.98965..
#  Memory: 377.98965..
#  Output:
#  [[ 711.7026  1301.3772   677.8022 ]
#  [ 830.29376 1518.0211   790.6975 ]
#  [ 716.97107 1312.7361   685.57324]
#  [ 771.232   1409.5464   732.928  ]]
# ====================
# Epoch: 280/800..
#  Training loss: 1272.28455..
#  torch.mean(F): 1271.98560..
#  Reg Proj: 0.13477..
#  Reg Latent: 0.16241..
#  Repulsive: 0.00184..
#  Memory: 254.39712..
#  Memory: 254.39712..
#  Output:
#  [[1306.4325 2461.3418 1419.634 ]
#  [1324.7985 2494.8364 1440.0562]
#  [1457.638  2748.408  1581.1383]
#  [1377.1837 2593.5269 1497.9697]]
# ====================
# Epoch: 320/800..
#  Training loss: 1540.53308..
#  torch.mean(F): 1540.23950..
#  Reg Proj: 0.12022..
#  Reg Latent: 0.16483..
#  Repulsive: 0.00848..
#  Memory: 308.04790..
#  Memory: 308.04790..
#  Output:
#  [[1220.9836 1499.4087 1862.9153]
#  [1230.793  1512.6755 1879.0922]
#  [1255.4161 1532.1747 1905.5754]
#  [1240.2124 1525.9803 1894.9983]]
# ====================
# Epoch: 360/800..
#  Training loss: 1226.96436..
#  torch.mean(F): 1226.64526..
#  Reg Proj: 0.15054..
#  Reg Latent: 0.16435..
#  Repulsive: 0.00422..
#  Memory: 245.32905..
#  Memory: 245.32905..
#  Output:
#  [[1622.2441 2378.6277 1865.6726]
#  [1641.6708 2406.4702 1887.5367]
#  [1575.6415 2312.1018 1813.7281]
#  [1655.4329 2426.598  1903.1366]]
# ====================
# Epoch: 400/800..
#  Training loss: 1258.19666..
#  torch.mean(F): 1257.90039..
#  Reg Proj: 0.13281..
#  Reg Latent: 0.15919..
#  Repulsive: 0.00426..
#  Memory: 251.58008..
#  Memory: 251.58008..
#  Output:
#  [[1538.4489 2502.372  1450.5281]
#  [1549.2363 2523.7778 1462.7117]
#  [1529.0352 2462.1418 1431.137 ]
#  [1568.14   2560.9512 1482.5197]]
# ====================
# Epoch: 440/800..
#  Training loss: 1325.11536..
#  torch.mean(F): 1324.67871..
#  Reg Proj: 0.27321..
#  Reg Latent: 0.15582..
#  Repulsive: 0.00753..
#  Memory: 264.93574..
#  Memory: 264.93574..
#  Output:
#  [[1457.0493 2117.4402 1431.0192]
#  [1470.1382 2138.5837 1444.5099]
#  [1391.8226 2009.1875 1363.3605]
#  [1472.4476 2145.543  1447.7069]]
# ====================
# Epoch: 480/800..
#  Training loss: 1292.28455..
#  torch.mean(F): 1291.84680..
#  Reg Proj: 0.28274..
#  Reg Latent: 0.15346..
#  Repulsive: 0.00153..
#  Memory: 258.36936..
#  Memory: 258.36936..
#  Output:
#  [[1951.7373 1782.9814 1756.4567]
#  [2159.667  1969.2476 1937.9819]
#  [1907.1396 1754.3248 1732.4286]
#  [1814.7733 1652.9761 1626.9652]]
# ====================
# Epoch: 520/800..
#  Training loss: 1370.66370..
#  torch.mean(F): 1370.46643..
#  Reg Proj: 0.03999..
#  Reg Latent: 0.15182..
#  Repulsive: 0.00535..
#  Memory: 274.09329..
#  Memory: 274.09329..
#  Output:
#  [[1512.8706 1694.4535 1601.9949]
#  [1561.2211 1749.6984 1653.883 ]
#  [1498.6893 1673.4598 1580.7357]
#  [1481.7094 1661.1749 1570.8351]]
# ====================
# Epoch: 560/800..
#  Training loss: 1343.67957..
#  torch.mean(F): 1343.37366..
#  Reg Proj: 0.15070..
#  Reg Latent: 0.14926..
#  Repulsive: 0.00583..
#  Memory: 268.67473..
#  Memory: 268.67473..
#  Output:
#  [[1422.1146 1937.4532 1568.3386]
#  [1442.4178 1963.7201 1588.2007]
#  [1402.9508 1918.4564 1560.5746]
#  [1397.4309 1900.0553 1535.2091]]
# ====================
# Epoch: 600/800..
#  Training loss: 1378.46838..
#  torch.mean(F): 1378.29602..
#  Reg Proj: 0.02157..
#  Reg Latent: 0.14660..
#  Repulsive: 0.00414..
#  Memory: 275.65920..
#  Memory: 275.65920..
#  Output:
#  [[1539.3435 1629.6165 1934.455 ]
#  [1568.4688 1659.4017 1967.4854]
#  [1508.6486 1600.8007 1910.2142]
#  [1498.1984 1584.0824 1876.9791]]
# ====================
# Epoch: 640/800..
#  Training loss: 1299.39624..
#  torch.mean(F): 1299.21741..
#  Reg Proj: 0.03023..
#  Reg Latent: 0.14416..
#  Repulsive: 0.00445..
#  Memory: 259.84348..
#  Memory: 259.84348..
#  Output:
#  [[1588.4062 1861.7393 1635.9902]
#  [1633.5269 1914.3207 1681.0413]
#  [1562.4999 1830.6222 1613.6246]
#  [1550.2603 1817.0743 1594.6078]]
# ====================
# Epoch: 680/800..
#  Training loss: 1357.38611..
#  torch.mean(F): 1357.22290..
#  Reg Proj: 0.01784..
#  Reg Latent: 0.14171..
#  Repulsive: 0.00364..
#  Memory: 271.44458..
#  Memory: 271.44458..
#  Output:
#  [[1608.5776 1610.2408 1778.7858]
#  [1647.6221 1650.1824 1820.7605]
#  [1579.3793 1576.078  1750.0431]
#  [1553.7404 1556.7068 1715.7959]]
# ====================
# Epoch: 720/800..
#  Training loss: 1357.69287..
#  torch.mean(F): 1357.52759..
#  Reg Proj: 0.02224..
#  Reg Latent: 0.13929..
#  Repulsive: 0.00376..
#  Memory: 271.50552..
#  Memory: 271.50552..
#  Output:
#  [[1691.1305 1592.8955 1684.6421]
#  [1726.5267 1628.1755 1720.7074]
#  [1672.1354 1565.9423 1659.6512]
#  [1622.7816 1532.0745 1618.8529]]
# ====================
# Epoch: 760/800..
#  Training loss: 1371.72925..
#  torch.mean(F): 1371.55957..
#  Reg Proj: 0.02934..
#  Reg Latent: 0.13678..
#  Repulsive: 0.00357..
#  Memory: 274.31191..
#  Memory: 274.31191..
#  Output:
#  [[1731.7356 1651.4746 1637.5193]
#  [1765.0586 1681.0916 1665.5793]
#  [1693.7927 1625.2928 1617.0464]
#  [1670.0325 1588.4012 1572.9652]]
# ====================
# Epoch: 800/800..
#  Training loss: 1248.38159..
#  torch.mean(F): 1248.20593..
#  Reg Proj: 0.03770..
#  Reg Latent: 0.13422..
#  Repulsive: 0.00365..
#  Memory: 249.64119..
#  Memory: 249.64119..
#  Output:
#  [[1742.641  1730.2736 1915.9207]
#  [1773.05   1765.6567 1949.5758]
#  [1721.1508 1684.7045 1886.0923]
#  [1688.664  1686.197  1858.5533]]
# ====================
# getUncertaintyArea
# Ouputs are [[1401.9382 2287.679  1442.7609]
#  [1895.8818 1772.4187 1494.9287]
#  [ 976.8795 1987.9191 1975.2799]
#  [1581.059  1578.9268 1422.249 ]]
# scale is 4014
# dx is 4006.0, dy is 4014.0, dz is 4003.0
# z is torch.Size([8000])
# Processing...
# flag is 201
# m is 7800
# i is 8000
# Labeled 0/7800 points.
# Labeled 1000/7800 points.
# Labeled 2000/7800 points.
# Labeled 3000/7800 points.
# Labeled 4000/7800 points.
# Labeled 5000/7800 points.
# Labeled 6000/7800 points.
# Labeled 7000/7800 points.
# Labeled all 7800/7800 points.
# Creating student for node 02 with 4 centroids.
# Device is: cpu
# ====================
# Training Student Model
# Acc:  0.33794871794871795
# Epoch:  0 Cost:  3406.542236328125
# Acc:  0.8248717948717949
# Epoch:  300 Cost:  38.25410461425781
# Acc:  0.8946153846153846
# Epoch:  600 Cost:  30.955228805541992
# Acc:  0.8834615384615384
# Epoch:  900 Cost:  30.449953079223633
# Acc:  0.9107692307692308
# Epoch:  1200 Cost:  24.930282592773438
# Acc:  0.9057692307692308
# Epoch:  1500 Cost:  22.926227569580078
# Acc:  0.9166666666666666
# Epoch:  1800 Cost:  19.29209327697754
# Acc:  0.9392307692307692
# Epoch:  2100 Cost:  16.165603637695312
# Acc:  0.9101282051282051
# Epoch:  2400 Cost:  21.55045509338379
# Acc:  0.9333333333333333
# Epoch:  2700 Cost:  15.491058349609375
#
# ====================
# Creating student for node 03 that has 1496 data, which is more than the threshold 400.
# Bounding box for node 03: [[-6, 3315], [-8, 2885], [598, 4008]]
# Creating teacher for node 03 with 4 centroids.
# ====================
# Training Teacher Model
# Shuffling data
# ====================
# Epoch: 40/800..
#  Training loss: 1102.68164..
#  torch.mean(F): 1101.93335..
#  Reg Proj: 0.72442..
#  Reg Latent: 0.02310..
#  Repulsive: 0.00081..
#  Memory: 220.38667..
#  Memory: 220.38667..
#  Output:
#  [[1742.3499 1422.7852 2143.082 ]
#  [1406.7705 1148.8263 1731.1039]
#  [1620.9515 1323.6516 1996.1183]
#  [1835.0889 1498.328  2262.171 ]]
# ====================
# Epoch: 80/800..
#  Training loss: 1321.27405..
#  torch.mean(F): 1315.79321..
#  Reg Proj: 5.46046..
#  Reg Latent: 0.01901..
#  Repulsive: 0.00139..
#  Memory: 263.15864..
#  Memory: 263.15864..
#  Output:
#  [[ 676.27576  834.96356  988.4011 ]
#  [1361.8945  1681.9185  1989.9744 ]
#  [1017.17145 1256.1595  1485.8866 ]
#  [ 999.4213  1234.2947  1459.0797 ]]
# ====================
# Epoch: 120/800..
#  Training loss: 2218.38086..
#  torch.mean(F): 2206.33350..
#  Reg Proj: 12.02331..
#  Reg Latent: 0.01768..
#  Repulsive: 0.00649..
#  Memory: 441.26670..
#  Memory: 441.26670..
#  Output:
#  [[746.41425 830.5193  748.424  ]
#  [760.93555 846.85364 762.6581 ]
#  [711.442   791.8067  712.5684 ]
#  [774.6989  862.1842  774.85626]]
# ====================
# Epoch: 160/800..
#  Training loss: 1602.91736..
#  torch.mean(F): 1596.29712..
#  Reg Proj: 6.59736..
#  Reg Latent: 0.02168..
#  Repulsive: 0.00108..
#  Memory: 319.25942..
#  Memory: 319.25942..
#  Output:
#  [[ 984.9012   732.66846 1083.498  ]
#  [1366.8751  1016.9125  1503.4572 ]
#  [ 587.78326  437.2624   646.4425 ]
#  [1020.85175  759.7352  1122.875  ]]
# ====================
# Epoch: 200/800..
#  Training loss: 1490.20813..
#  torch.mean(F): 1481.13928..
#  Reg Proj: 8.95755..
#  Reg Latent: 0.11056..
#  Repulsive: 0.00074..
#  Memory: 296.22786..
#  Memory: 296.22786..
#  Output:
#  [[1207.4789 1049.4225  951.5439]
#  [1371.386  1191.8865 1080.7876]
#  [1112.163   966.5932  876.4951]
#  [1939.3916 1685.1624 1528.0852]]
# ====================
# Epoch: 240/800..
#  Training loss: 947.81348..
#  torch.mean(F): 947.64148..
#  Reg Proj: 0.06480..
#  Reg Latent: 0.10598..
#  Repulsive: 0.00121..
#  Memory: 189.52830..
#  Memory: 189.52830..
#  Output:
#  [[1298.03   1452.7358 2341.1982]
#  [1325.4457 1483.2483 2391.5295]
#  [1454.5729 1627.239  2624.8416]
#  [1202.7323 1345.0442 2170.1328]]
# ====================
# Epoch: 280/800..
#  Training loss: 2540.53369..
#  torch.mean(F): 2511.54956..
#  Reg Proj: 28.68064..
#  Reg Latent: 0.27125..
#  Repulsive: 0.03229..
#  Memory: 502.30991..
#  Memory: 502.30991..
#  Output:
#  [[422.7515  318.32983 537.9248 ]
#  [442.17322 333.8614  562.48773]
#  [441.18045 333.61853 561.0186 ]
#  [435.42154 329.36395 553.6182 ]]
# ====================
# Epoch: 320/800..
#  Training loss: 1023.62909..
#  torch.mean(F): 1023.24500..
#  Reg Proj: 0.01658..
#  Reg Latent: 0.35790..
#  Repulsive: 0.00959..
#  Memory: 204.64900..
#  Memory: 204.64900..
#  Output:
#  [[1181.3966 1262.9912 2372.508 ]
#  [1198.6621 1282.8965 2407.1362]
#  [1231.3657 1318.47   2472.7268]
#  [1179.4705 1262.6661 2368.1636]]
# ====================
# Epoch: 360/800..
#  Training loss: 1069.23706..
#  torch.mean(F): 1068.66431..
#  Reg Proj: 0.08320..
#  Reg Latent: 0.48610..
#  Repulsive: 0.00340..
#  Memory: 213.73286..
#  Memory: 213.73286..
#  Output:
#  [[1487.9196 1249.3414 2213.0337]
#  [1546.6202 1298.7738 2299.8096]
#  [1457.8999 1224.1925 2168.1714]
#  [1532.253  1286.5669 2278.7725]]
# ====================
# Epoch: 400/800..
#  Training loss: 1006.27368..
#  torch.mean(F): 1005.49316..
#  Reg Proj: 0.30640..
#  Reg Latent: 0.47246..
#  Repulsive: 0.00165..
#  Memory: 201.09863..
#  Memory: 201.09863..
#  Output:
#  [[1636.3694 1065.1349 2138.9988]
#  [1907.3226 1241.5406 2491.221 ]
#  [1595.1903 1038.4276 2084.331 ]
#  [1678.2756 1092.4998 2192.4016]]
# ====================
# Epoch: 440/800..
#  Training loss: 1135.47852..
#  torch.mean(F): 1134.66089..
#  Reg Proj: 0.23145..
#  Reg Latent: 0.58436..
#  Repulsive: 0.00179..
#  Memory: 226.93218..
#  Memory: 226.93218..
#  Output:
#  [[1753.7621 1239.2604 2084.1462]
#  [1650.5898 1166.5474 1961.2161]
#  [1707.7631 1207.2902 2029.6146]
#  [1554.8966 1099.13   1847.7167]]
# ====================
# Epoch: 480/800..
#  Training loss: 1183.87256..
#  torch.mean(F): 1183.26514..
#  Reg Proj: 0.19829..
#  Reg Latent: 0.40543..
#  Repulsive: 0.00379..
#  Memory: 236.65303..
#  Memory: 236.65303..
#  Output:
#  [[1378.4418 1152.494  1801.6593]
#  [1330.0541 1111.8882 1737.4476]
#  [1338.4628 1119.483  1750.2875]
#  [1524.5801 1275.0977 1992.9304]]
# ====================
# Epoch: 520/800..
#  Training loss: 1036.19421..
#  torch.mean(F): 1024.19080..
#  Reg Proj: 11.72577..
#  Reg Latent: 0.27721..
#  Repulsive: 0.00041..
#  Memory: 204.83816..
#  Memory: 204.83816..
#  Output:
#  [[2211.2715 1843.9443 3147.4507]
#  [2397.9634 1999.696  3414.4949]
#  [1646.6316 1371.8352 2334.3262]
#  [1777.8807 1483.6086 2538.5   ]]
# ====================
# Epoch: 560/800..
#  Training loss: 1938.54236..
#  torch.mean(F): 1931.29675..
#  Reg Proj: 6.95115..
#  Reg Latent: 0.29265..
#  Repulsive: 0.00182..
#  Memory: 386.25935..
#  Memory: 386.25935..
#  Output:
#  [[1159.9664   904.5656  1014.81226]
#  [1282.0021  1000.32434 1126.1497 ]
#  [1237.7313   967.1109  1067.7894 ]
#  [1074.053    836.6885   947.82007]]
# ====================
# Epoch: 600/800..
#  Training loss: 1174.26514..
#  torch.mean(F): 1173.24866..
#  Reg Proj: 0.60010..
#  Reg Latent: 0.41394..
#  Repulsive: 0.00242..
#  Memory: 234.64973..
#  Memory: 234.64973..
#  Output:
#  [[ 727.2502   905.6479  2323.6934 ]
#  [ 760.772    945.7545  2433.3303 ]
#  [ 753.19696  939.4443  2412.015  ]
#  [ 674.9611   839.53253 2152.173  ]]
# ====================
# Epoch: 640/800..
#  Training loss: 1663.21497..
#  torch.mean(F): 1661.23352..
#  Reg Proj: 1.88777..
#  Reg Latent: 0.09061..
#  Repulsive: 0.00309..
#  Memory: 332.24670..
#  Memory: 332.24670..
#  Output:
#  [[ 973.2701   893.12    1504.1005 ]
#  [1021.4619   938.15015 1577.8976 ]
#  [ 996.65485  917.06995 1538.3002 ]
#  [ 934.2593   855.92194 1444.2545 ]]
# ====================
# Epoch: 680/800..
#  Training loss: 1431.70435..
#  torch.mean(F): 1423.52515..
#  Reg Proj: 7.96284..
#  Reg Latent: 0.21534..
#  Repulsive: 0.00092..
#  Memory: 284.70503..
#  Memory: 284.70503..
#  Output:
#  [[1651.8772 1750.6016 1617.4573]
#  [1743.2104 1846.4138 1710.0999]
#  [1435.7325 1518.7706 1414.9991]
#  [1882.785  1995.422  1842.6063]]
# ====================
# Epoch: 720/800..
#  Training loss: 1064.39587..
#  torch.mean(F): 1063.68933..
#  Reg Proj: 0.34595..
#  Reg Latent: 0.35942..
#  Repulsive: 0.00121..
#  Memory: 212.73787..
#  Memory: 212.73787..
#  Output:
#  [[1048.2231 1256.8284 2295.2131]
#  [ 967.3094 1162.9841 2119.2031]
#  [ 895.2298 1084.5901 1963.6958]
#  [1073.4795 1287.8867 2350.1064]]
# ====================
# Epoch: 760/800..
#  Training loss: 1052.41101..
#  torch.mean(F): 1051.29883..
#  Reg Proj: 0.75015..
#  Reg Latent: 0.36102..
#  Repulsive: 0.00112..
#  Memory: 210.25977..
#  Memory: 210.25977..
#  Output:
#  [[2242.6914  1374.8906  2793.686  ]
#  [1622.4495   994.625   2021.3164 ]
#  [1345.5345   825.04755 1677.4348 ]
#  [1594.6531   977.61554 1985.1455 ]]
# ====================
# Epoch: 800/800..
#  Training loss: 1103.52576..
#  torch.mean(F): 1103.09656..
#  Reg Proj: 0.06287..
#  Reg Latent: 0.36465..
#  Repulsive: 0.00173..
#  Memory: 220.61931..
#  Memory: 220.61931..
#  Output:
#  [[1379.41   1133.6467 2083.702 ]
#  [1266.3434 1041.0465 1912.5476]
#  [1429.1096 1175.4354 2158.33  ]
#  [1458.784  1198.9005 2202.9495]]
# ====================
# getUncertaintyArea
# Ouputs are [[1233.914  1010.897  2929.4172]
#  [1516.2178  938.6873 2718.0894]
#  [1957.9551 1017.8754 2671.013 ]
#  [1454.6792  823.4025 3073.9978]]
# scale is 3410
# dx is 3321.0, dy is 2893.0, dz is 3410.0
# z is torch.Size([8000])
# Processing...
# flag is 1
# m is 8000
# i is 8000
# Labeled 0/8000 points.
# Labeled 1000/8000 points.
# Labeled 2000/8000 points.
# Labeled 3000/8000 points.
# Labeled 4000/8000 points.
# Labeled 5000/8000 points.
# Labeled 6000/8000 points.
# Labeled 7000/8000 points.
# Labeled all 8000/8000 points.
# Creating student for node 03 with 4 centroids.
# Device is: cpu
# ====================
# Training Student Model
# Acc:  0.2585
# Epoch:  0 Cost:  4142.2568359375
# Acc:  0.8375
# Epoch:  300 Cost:  35.21078109741211
# Acc:  0.851
# Epoch:  600 Cost:  31.94928741455078
# Acc:  0.868
# Epoch:  900 Cost:  28.23442840576172
# Acc:  0.90725
# Epoch:  1200 Cost:  23.811378479003906
# Acc:  0.9175
# Epoch:  1500 Cost:  20.808481216430664
# Acc:  0.919
# Epoch:  1800 Cost:  18.83103370666504
# Acc:  0.9345
# Epoch:  2100 Cost:  17.440954208374023
# Acc:  0.9445
# Epoch:  2400 Cost:  15.45417308807373
# Acc:  0.915625
# Epoch:  2700 Cost:  18.3903865814209
#
# ====================
# Creating student for node 002 that has 909 data, which is more than the threshold 400.
# Bounding box for node 002: [[-4, 2400], [-8, 2460], [-8, 2727]]
# Creating teacher for node 002 with 4 centroids.
# ====================
# Training Teacher Model
# ====================
# Epoch: 40/800..
#  Training loss: 1338.68506..
#  torch.mean(F): 1338.57483..
#  Reg Proj: 0.00000..
#  Reg Latent: 0.10616..
#  Repulsive: 0.00400..
#  Memory: 267.71497..
#  Memory: 267.71497..
#  Output:
#  [[ 55.53958  162.1408    60.867798]
#  [ 30.933727  86.84096   35.856968]
#  [ 76.98341  222.25647   87.03468 ]
#  [ 25.892767  74.0129    29.4371  ]]
# ====================
# Epoch: 80/800..
#  Training loss: 951.88312..
#  torch.mean(F): 951.78864..
#  Reg Proj: 0.00000..
#  Reg Latent: 0.09217..
#  Repulsive: 0.00232..
#  Memory: 190.35773..
#  Memory: 190.35773..
#  Output:
#  [[576.1408  687.8925  337.6057 ]
#  [459.51862 587.7851  247.96976]
#  [486.53778 632.37    254.81688]
#  [609.7497  737.2734  359.59097]]
# ====================
# Epoch: 120/800..
#  Training loss: 1341.98621..
#  torch.mean(F): 1341.90576..
#  Reg Proj: 0.00000..
#  Reg Latent: 0.07536..
#  Repulsive: 0.00507..
#  Memory: 268.38115..
#  Memory: 268.38115..
#  Output:
#  [[170.71109  164.67178   53.679035]
#  [ 55.454987  51.941765  17.552849]
#  [ 45.032345  43.09462   14.358575]
#  [ 97.680756  92.958244  29.497627]]
# ====================
# Epoch: 160/800..
#  Training loss: 900.27161..
#  torch.mean(F): 900.21667..
#  Reg Proj: 0.00000..
#  Reg Latent: 0.05378..
#  Repulsive: 0.00118..
#  Memory: 180.04333..
#  Memory: 180.04333..
#  Output:
#  [[628.8602  348.22556 502.97278]
#  [553.2788  303.44675 443.51163]
#  [780.84216 428.60574 625.891  ]
#  [419.8886  231.97699 335.87448]]
# ====================
# Epoch: 200/800..
#  Training loss: 747.09241..
#  torch.mean(F): 747.06366..
#  Reg Proj: 0.00067..
#  Reg Latent: 0.02696..
#  Repulsive: 0.00112..
#  Memory: 149.41273..
#  Memory: 149.41273..
#  Output:
#  [[ 343.04523  555.7233   466.57544]
#  [ 284.5234   476.86942  389.65836]
#  [ 649.8612  1084.3644   889.26184]
#  [ 243.75168  400.7544   332.42767]]
# ====================
# Epoch: 240/800..
#  Training loss: 833.92621..
#  torch.mean(F): 833.92096..
#  Reg Proj: 0.00001..
#  Reg Latent: 0.00446..
#  Repulsive: 0.00080..
#  Memory: 166.78419..
#  Memory: 166.78419..
#  Output:
#  [[ 610.33795  376.14032  297.03638]
#  [ 510.47745  303.05026  241.66286]
#  [1126.4343   672.3091   535.5157 ]
#  [ 378.15997  229.46748  182.28749]]
# ====================
# Epoch: 280/800..
#  Training loss: 1113.85889..
#  torch.mean(F): 1113.84106..
#  Reg Proj: 0.00000..
#  Reg Latent: 0.01684..
#  Repulsive: 0.00098..
#  Memory: 222.76821..
#  Memory: 222.76821..
#  Output:
#  [[ 89.240425  92.8699   126.117905]
#  [301.87155  316.43906  426.97348 ]
#  [200.71605  210.32607  283.9553  ]
#  [ 16.351294  16.812624  22.923285]]
# ====================
# Epoch: 320/800..
#  Training loss: 1318.36975..
#  torch.mean(F): 1318.30530..
#  Reg Proj: 0.00001..
#  Reg Latent: 0.06237..
#  Repulsive: 0.00207..
#  Memory: 263.66106..
#  Memory: 263.66106..
#  Output:
#  [[110.78046   37.506382 277.33844 ]
#  [ 69.56033   24.625399 176.39401 ]
#  [ 51.727955  19.008652 132.9689  ]
#  [ 26.115728   9.626883  67.08262 ]]
# ====================
# Epoch: 360/800..
#  Training loss: 1135.39868..
#  torch.mean(F): 1135.38867..
#  Reg Proj: 0.00001..
#  Reg Latent: 0.00754..
#  Repulsive: 0.00239..
#  Memory: 227.07773..
#  Memory: 227.07773..
#  Output:
#  [[561.09814 163.68175 299.66693]
#  [602.8879  174.40027 319.18478]
#  [512.61633 147.80162 270.38263]
#  [423.125   123.80647 227.04616]]
# ====================
# Epoch: 400/800..
#  Training loss: 1197.54016..
#  torch.mean(F): 1197.52808..
#  Reg Proj: 0.00000..
#  Reg Latent: 0.00718..
#  Repulsive: 0.00484..
#  Memory: 239.50562..
#  Memory: 239.50562..
#  Output:
#  [[314.88715  288.29846   80.4155  ]
#  [394.4996   386.4591   104.00543 ]
#  [329.4086   282.72217   81.12117 ]
#  [401.45877  366.1219   101.107376]]
# ====================
# Epoch: 440/800..
#  Training loss: 1066.96362..
#  torch.mean(F): 1066.93140..
#  Reg Proj: 0.00001..
#  Reg Latent: 0.03151..
#  Repulsive: 0.00072..
#  Memory: 213.38628..
#  Memory: 213.38628..
#  Output:
#  [[166.32242  565.45     316.8534  ]
#  [ 40.575665  42.636784  25.179983]
#  [266.02032  637.8452   362.64505 ]
#  [ 47.228916 266.5729   143.53555 ]]
# ====================
# Epoch: 480/800..
#  Training loss: 1300.05188..
#  torch.mean(F): 1300.01807..
#  Reg Proj: 0.00000..
#  Reg Latent: 0.03262..
#  Repulsive: 0.00122..
# ...
#  [[1447.0303   801.82587 2377.4216 ]
#  [1495.769    824.1341  2455.4248 ]
#  [1330.9952   729.9609  2182.3447 ]
#  [1460.3779   796.845   2393.1184 ]]
# ====================
# Epoch: 200/800..
#  Training loss: 1175.48962..
#  torch.mean(F): 1174.64624..
#  Reg Proj: 0.43854..
#  Reg Latent: 0.40355..
#  Repulsive: 0.00123..
#  Memory: 234.92925..
#  Memory: 234.92925..
#  Output:
#  [[1282.1891 2212.323  2958.0642]
#  [1132.2662 1953.4232 2610.2185]
#  [1351.7816 2330.7256 3113.0928]
#  [1326.8983 2287.9421 3054.2822]]
# ====================
# Epoch: 240/800..
#  Training loss: 1231.39905..
#  torch.mean(F): 1230.57886..
#  Reg Proj: 0.41168..
#  Reg Latent: 0.40557..
#  Repulsive: 0.00311..
#  Memory: 246.11577..
#  Memory: 246.11577..
#  Output:
#  [[1669.1482 1936.5029 2529.2092]
#  [1440.7217 1669.291  2182.078 ]
#  [1613.411  1869.8182 2442.1077]
#  [1661.799  1922.9773 2514.621 ]]
# ====================
# Epoch: 280/800..
#  Training loss: 1103.16003..
#  torch.mean(F): 1101.89746..
#  Reg Proj: 0.97029..
#  Reg Latent: 0.28944..
#  Repulsive: 0.00286..
#  Memory: 220.37949..
#  Memory: 220.37949..
#  Output:
#  [[1478.7958 2512.0347 3153.6729]
#  [1615.3646 2750.2893 3445.3477]
#  [1623.5604 2764.948  3460.1255]
#  [1520.1512 2594.7722 3239.335 ]]
# ====================
# Epoch: 320/800..
#  Training loss: 1657.97754..
#  torch.mean(F): 1656.96155..
#  Reg Proj: 0.72959..
#  Reg Latent: 0.28530..
#  Repulsive: 0.00111..
#  Memory: 331.39231..
#  Memory: 331.39231..
#  Output:
#  [[1214.7344  1555.3029  2102.164  ]
#  [1144.6558  1466.0746  1983.0864 ]
#  [1083.3419  1387.732   1878.1666 ]
#  [1005.95233 1289.0652  1746.3196 ]]
# ====================
# Epoch: 360/800..
#  Training loss: 1233.10596..
#  torch.mean(F): 1232.46863..
#  Reg Proj: 0.29843..
#  Reg Latent: 0.33830..
#  Repulsive: 0.00064..
#  Memory: 246.49373..
#  Memory: 246.49373..
#  Output:
#  [[1187.2166 1704.7806 3310.2805]
#  [1012.4801 1453.4996 2817.8071]
#  [1223.8734 1756.9746 3404.0945]
#  [1332.27   1912.3411 3701.0923]]
# ====================
# Epoch: 400/800..
#  Training loss: 1383.04822..
#  torch.mean(F): 1381.37695..
#  Reg Proj: 1.43284..
#  Reg Latent: 0.23567..
#  Repulsive: 0.00271..
#  Memory: 276.27539..
#  Memory: 276.27539..
#  Output:
#  [[1525.6263 1473.0388 2418.3784]
#  [1551.9042 1499.4857 2464.5754]
#  [1572.9517 1520.149  2499.6887]
#  [1472.2686 1423.7338 2343.322 ]]
# ====================
# Epoch: 440/800..
#  Training loss: 1186.91443..
#  torch.mean(F): 1186.36572..
#  Reg Proj: 0.26673..
#  Reg Latent: 0.28112..
#  Repulsive: 0.00086..
#  Memory: 237.27314..
#  Memory: 237.27314..
#  Output:
#  [[1386.9264 2059.7073 3785.1106]
#  [1180.2363 1755.3761 3229.749 ]
#  [1210.8402 1801.7727 3316.1274]
#  [1126.6202 1678.5417 3092.109 ]]
# ====================
# Epoch: 480/800..
#  Training loss: 1258.12805..
#  torch.mean(F): 1256.81970..
#  Reg Proj: 1.02148..
#  Reg Latent: 0.28238..
#  Repulsive: 0.00450..
#  Memory: 251.36394..
#  Memory: 251.36394..
#  Output:
#  [[1945.9274 1363.7865 2550.2292]
#  [1956.2611 1375.1119 2568.8423]
#  [1995.8577 1403.6748 2621.5632]
#  [1916.005  1350.0483 2519.8389]]
# ====================
# Epoch: 520/800..
#  Training loss: 1489.27441..
#  torch.mean(F): 1487.88074..
#  Reg Proj: 1.10936..
#  Reg Latent: 0.28220..
#  Repulsive: 0.00202..
#  Memory: 297.57615..
#  Memory: 297.57615..
#  Output:
#  [[ 892.939   2723.4124  2442.0574 ]
#  [ 811.0992  2478.776   2220.881  ]
#  [ 902.02655 2757.5837  2470.1418 ]
#  [ 920.60223 2817.288   2522.4287 ]]
# ====================
# Epoch: 560/800..
#  Training loss: 1474.74500..
#  torch.mean(F): 1472.60803..
#  Reg Proj: 1.92693..
#  Reg Latent: 0.20829..
#  Repulsive: 0.00189..
#  Memory: 294.52161..
#  Memory: 294.52161..
#  Output:
#  [[1304.1823 1223.1908 2121.0598]
#  [1400.1599 1313.96   2273.9565]
#  [1491.8373 1400.2976 2420.9685]
#  [1474.6714 1384.5298 2391.5825]]
# ====================
# Epoch: 600/800..
#  Training loss: 1254.35327..
#  torch.mean(F): 1253.14636..
#  Reg Proj: 0.92879..
#  Reg Latent: 0.27770..
#  Repulsive: 0.00035..
#  Memory: 250.62927..
#  Memory: 250.62927..
#  Output:
#  [[1094.3871  1139.4745  2335.9194 ]
#  [1203.0532  1252.6362  2568.6616 ]
#  [ 872.38306  908.48364 1863.0518 ]
#  [1478.7772  1539.9609  3158.2415 ]]
# ====================
# Epoch: 640/800..
#  Training loss: 1329.09021..
#  torch.mean(F): 1328.34473..
#  Reg Proj: 0.50627..
#  Reg Latent: 0.23846..
#  Repulsive: 0.00086..
#  Memory: 265.66895..
#  Memory: 265.66895..
#  Output:
#  [[1195.3489 1549.5922 2243.0027]
#  [1400.2954 1814.7368 2625.3826]
#  [1076.4094 1394.822  2017.0667]
#  [1144.5999 1483.0259 2144.27  ]]
# ====================
# Epoch: 680/800..
#  Training loss: 1280.55042..
#  torch.mean(F): 1279.88184..
#  Reg Proj: 0.49658..
#  Reg Latent: 0.17082..
#  Repulsive: 0.00125..
#  Memory: 255.97637..
#  Memory: 255.97637..
#  Output:
#  [[1446.2052 1453.8584 2733.1882]
#  [1295.8165 1306.1246 2451.977 ]
#  [1417.3981 1430.4177 2683.4949]
#  [1523.9775 1538.7378 2885.9966]]
# ====================
# Epoch: 720/800..
#  Training loss: 2049.82520..
#  torch.mean(F): 2046.00000..
#  Reg Proj: 3.66719..
#  Reg Latent: 0.15004..
#  Repulsive: 0.00788..
#  Memory: 409.20000..
#  Memory: 409.20000..
#  Output:
#  [[ 402.16098 1233.7366  2620.7542 ]
#  [ 408.35028 1253.2241  2662.7644 ]
#  [ 405.20688 1243.7975  2642.9966 ]
#  [ 399.67163 1228.2463  2610.0999 ]]
# ====================
# Epoch: 760/800..
#  Training loss: 1867.36548..
#  torch.mean(F): 1865.47559..
#  Reg Proj: 1.79315..
#  Reg Latent: 0.09371..
#  Repulsive: 0.00310..
#  Memory: 373.09512..
#  Memory: 373.09512..
#  Output:
#  [[ 843.3891   821.9078  2573.6538 ]
#  [ 827.1672   807.01117 2525.3662 ]
#  [ 874.19543  854.2427  2670.9084 ]
#  [ 818.63165  801.3023  2503.3374 ]]
# ====================
# Epoch: 800/800..
#  Training loss: 1295.90149..
#  torch.mean(F): 1295.34460..
#  Reg Proj: 0.44077..
#  Reg Latent: 0.10999..
#  Repulsive: 0.00614..
#  Memory: 259.06892..
#  Memory: 259.06892..
#  Output:
#  [[1414.158  1540.8966 3093.9019]
#  [1385.0732 1508.8763 3028.6128]
#  [1379.1562 1502.2776 3014.8076]
#  [1372.0529 1494.3683 2998.3804]]
# ====================
# getUncertaintyArea
# Ouputs are [[2545.0635 1498.4652 3150.418 ]
#  [2264.819  1864.0851 2375.2908]
#  [2436.1826 1504.8452 2994.3694]
#  [2574.2458 2003.2354 3161.4941]]
# scale is 3389
# dx is 3135.0, dy is 3389.0, dz is 2913.0
# z is torch.Size([8000])
# Processing...
# flag is 1247
# m is 6754
# i is 8000
# Labeled 0/6754 points.
# Labeled 1000/6754 points.
# Labeled 2000/6754 points.
# Labeled 3000/6754 points.
# Labeled 4000/6754 points.
# Labeled 5000/6754 points.
# Labeled 6000/6754 points.
# Labeled all 6754/6754 points.
# Creating student for node 0120 with 4 centroids.
# Device is: cpu
# ====================
# Training Student Model
# Acc:  0.5728457210541901
# Epoch:  0 Cost:  1487.1839599609375
# Acc:  0.7977494817885697
# Epoch:  300 Cost:  44.51969909667969
# Acc:  0.8298785904649096
# Epoch:  600 Cost:  40.301334381103516
# Acc:  0.8304708320994966
# Epoch:  900 Cost:  38.634422302246094
# Acc:  0.8424637251998816
# Epoch:  1200 Cost:  34.50048828125
# Acc:  0.754663902872372
# Epoch:  1500 Cost:  64.08973693847656
# Acc:  0.8320994965946106
# Epoch:  1800 Cost:  37.716609954833984
# Acc:  0.8409831211134142
# Epoch:  2100 Cost:  35.10259246826172
# Acc:  0.8473497186852236
# Epoch:  2400 Cost:  32.99845886230469
# Acc:  0.8794788273615635
# Epoch:  2700 Cost:  30.372804641723633
#
# ====================
# Creating student for node 0210 that has 471 data, which is more than the threshold 400.
# Bounding box for node 0210: [[2126, 4000], [-7, 3206], [-7, 2456]]
# Creating teacher for node 0210 with 4 centroids.
# ====================
# Training Teacher Model
# ====================
# Epoch: 40/800..
#  Training loss: 2886.94458..
#  torch.mean(F): 2854.04102..
#  Reg Proj: 32.75320..
#  Reg Latent: 0.14822..
#  Repulsive: 0.00219..
#  Memory: 570.80820..
#  Memory: 570.80820..
#  Output:
#  [[1.6534511e+02 1.9834164e+00 3.0316963e+00]
#  [7.8774376e+01 9.0052468e-01 1.3460124e+00]
#  [2.0610983e+02 1.4576501e-01 1.1652757e-01]
#  [2.7409415e+02 2.0311947e+00 3.0517318e+00]]
# ====================
# Epoch: 80/800..
#  Training loss: 2009.68567..
#  torch.mean(F): 1979.64294..
#  Reg Proj: 29.94178..
#  Reg Latent: 0.10077..
#  Repulsive: 0.00019..
#  Memory: 395.92859..
#  Memory: 395.92859..
#  Output:
#  [[1049.2017   384.8225   682.90027]
#  [5475.0356  2027.8713  3548.2966 ]
#  [4203.179   1545.6848  2744.9365 ]
#  [4482.1807  1639.5632  2947.084  ]]
# ====================
# Epoch: 120/800..
#  Training loss: 1075.37280..
#  torch.mean(F): 1067.26562..
#  Reg Proj: 7.95389..
#  Reg Latent: 0.15215..
#  Repulsive: 0.00127..
#  Memory: 213.45312..
#  Memory: 213.45312..
#  Output:
#  [[2245.8755   873.2377  1090.3488 ]
#  [2243.6758   814.92413 1030.7504 ]
#  [1939.5046   719.8031   906.46625]
#  [2059.854    761.5072   959.6146 ]]
# ====================
# Epoch: 160/800..
#  Training loss: 1071.84558..
#  torch.mean(F): 1064.27771..
#  Reg Proj: 7.31946..
#  Reg Latent: 0.24283..
#  Repulsive: 0.00556..
#  Memory: 212.85554..
#  Memory: 212.85554..
#  Output:
#  [[2222.4795   741.13184 1097.6378 ]
#  [2385.0703   672.71564 1152.3793 ]
#  [2276.5713   692.35657 1110.2141 ]
#  [2284.5415   685.2497  1112.3798 ]]
# ====================
# Epoch: 200/800..
#  Training loss: 1302.58655..
#  torch.mean(F): 1294.83655..
#  Reg Proj: 7.46182..
#  Reg Latent: 0.28254..
#  Repulsive: 0.00559..
#  Memory: 258.96731..
#  Memory: 258.96731..
#  Output:
#  [[1741.9034 1165.5762  954.0782]
#  [1851.1193 1034.8245 1070.8604]
#  [1799.3254 1093.9421 1016.9198]
#  [1807.9681 1085.6776 1024.7832]]
# ====================
# Epoch: 240/800..
#  Training loss: 1671.99268..
#  torch.mean(F): 1651.98145..
#  Reg Proj: 19.69207..
#  Reg Latent: 0.31578..
#  Repulsive: 0.00341..
#  Memory: 330.39629..
#  Memory: 330.39629..
#  Output:
#  [[1410.154    950.5585  1339.7319 ]
#  [1481.7411   881.70996 1352.3192 ]
#  [1467.6287   935.78674 1368.4843 ]
#  [1426.1226   904.65906 1330.1935 ]]
# ====================
# Epoch: 280/800..
#  Training loss: 1003.99463..
#  torch.mean(F): 997.46588..
#  Reg Proj: 6.09699..
#  Reg Latent: 0.42829..
#  Repulsive: 0.00350..
#  Memory: 199.49318..
#  Memory: 199.49318..
#  Output:
#  [[2195.0818  1231.6754   811.54736]
#  [2196.7234  1259.5989   730.65607]
#  [2205.2979  1250.8689   778.5073 ]
#  [2144.1025  1217.1074   755.09644]]
# ====================
# Epoch: 320/800..
#  Training loss: 1188.51562..
#  torch.mean(F): 1174.16321..
#  Reg Proj: 13.76626..
#  Reg Latent: 0.58389..
#  Repulsive: 0.00231..
#  Memory: 234.83264..
#  Memory: 234.83264..
#  Output:
#  [[4210.706    842.9194   710.5282 ]
#  [4198.4453   778.07574  591.6086 ]
#  [4152.8687   803.5152   647.66437]
#  [4093.2156   790.249    632.9047 ]]
# ====================
# Epoch: 360/800..
#  Training loss: 964.37842..
#  torch.mean(F): 956.37543..
#  Reg Proj: 7.50321..
#  Reg Latent: 0.49700..
#  Repulsive: 0.00275..
#  Memory: 191.27509..
#  Memory: 191.27509..
#  Output:
#  [[3619.4382 1674.1287 1223.1295]
#  [3635.0813 1663.1827 1109.223 ]
#  [3689.446  1698.3451 1191.9396]
#  [3641.2485 1675.5872 1173.162 ]]
# ====================
# Epoch: 400/800..
#  Training loss: 782.99048..
#  torch.mean(F): 777.25848..
#  Reg Proj: 5.16161..
#  Reg Latent: 0.56857..
#  Repulsive: 0.00185..
#  Memory: 155.45170..
#  Memory: 155.45170..
#  Output:
#  [[2874.1863 1514.9828 1164.7904]
#  [2907.414  1410.5339 1191.1387]
#  [2943.562  1495.834  1199.8505]
#  [3027.7666 1543.4525 1233.4857]]
# ====================
# Epoch: 440/800..
#  Training loss: 967.67291..
#  torch.mean(F): 962.03949..
#  Reg Proj: 5.09645..
#  Reg Latent: 0.53324..
#  Repulsive: 0.00371..
#  Memory: 192.40790..
#  Memory: 192.40790..
#  Output:
#  [[2544.5583   956.0842  1400.9305 ]
#  [2487.9746   913.21704 1346.5802 ]
#  [2469.0977   918.4945  1350.5436 ]
#  [2590.5356   964.9493  1417.9912 ]]
# ====================
# Epoch: 480/800..
#  Training loss: 989.35748..
#  torch.mean(F): 982.48090..
#  Reg Proj: 6.22354..
#  Reg Latent: 0.65028..
#  Repulsive: 0.00277..
#  Memory: 196.49618..
#  Memory: 196.49618..
#  Output:
#  [[2805.2812   811.36127 1335.0846 ]
#  [2989.2405   809.4179  1357.223  ]
#  [2830.7612   792.5387  1313.9364 ]
#  [2950.9014   831.20245 1379.5493 ]]
# ====================
# Epoch: 520/800..
#  Training loss: 1477.68640..
#  torch.mean(F): 1466.95105..
#  Reg Proj: 10.06879..
#  Reg Latent: 0.66165..
#  Repulsive: 0.00488..
#  Memory: 293.39021..
#  Memory: 293.39021..
#  Output:
#  [[1662.6313  1334.6305   793.24915]
#  [1551.8348  1318.3636   760.09534]
#  [1604.3416  1325.9568   776.3975 ]
#  [1616.7911  1327.348    780.5191 ]]
# ====================
# Epoch: 560/800..
#  Training loss: 992.32599..
#  torch.mean(F): 985.18127..
#  Reg Proj: 6.41072..
#  Reg Latent: 0.73029..
#  Repulsive: 0.00374..
#  Memory: 197.03625..
#  Memory: 197.03625..
#  Output:
#  [[2175.5828  1031.531    817.74194]
#  [2291.0305  1045.8776   820.6066 ]
#  [2233.586   1039.0692   820.09894]
#  [2260.994   1057.2032   836.046  ]]
# ====================
# Epoch: 600/800..
#  Training loss: 1036.65515..
#  torch.mean(F): 1031.13892..
#  Reg Proj: 4.75610..
#  Reg Latent: 0.75838..
#  Repulsive: 0.00176..
#  Memory: 206.22778..
#  Memory: 206.22778..
#  Output:
#  [[2925.116  1243.2317 1695.476 ]
#  [2786.5107 1190.052  1607.2527]
#  [2691.9253 1147.4038 1557.6362]
#  [2874.7803 1221.9009 1669.6956]]
# ====================
# Epoch: 640/800..
#  Training loss: 943.44910..
#  torch.mean(F): 936.76477..
#  Reg Proj: 5.95874..
#  Reg Latent: 0.72266..
#  Repulsive: 0.00290..
#  Memory: 187.35295..
#  Memory: 187.35295..
#  Output:
#  [[2947.777    923.0759  1367.0933 ]
#  [2761.6685   860.78827 1293.0166 ]
#  [2828.5618   884.6128  1318.2532 ]
#  [2800.257    875.7421  1301.5082 ]]
# ====================
# Epoch: 680/800..
#  Training loss: 842.83270..
#  torch.mean(F): 837.02679..
#  Reg Proj: 5.05256..
#  Reg Latent: 0.74894..
#  Repulsive: 0.00441..
#  Memory: 167.40536..
#  Memory: 167.40536..
#  Output:
#  [[2445.9695  1156.8527  1038.7589 ]
#  [2502.5767  1179.3362  1071.6315 ]
#  [2514.9417  1188.1226  1072.5438 ]
#  [2388.221   1130.2721  1013.24316]]
# ====================
# Epoch: 720/800..
#  Training loss: 818.94476..
#  torch.mean(F): 813.91699..
#  Reg Proj: 4.29553..
#  Reg Latent: 0.72958..
#  Repulsive: 0.00267..
#  Memory: 162.78340..
#  Memory: 162.78340..
#  Output:
#  [[2718.6677 1682.8344 1250.8134]
#  [2596.9043 1620.0076 1189.0416]
#  [2544.5554 1581.0234 1168.3737]
#  [2627.368  1635.9901 1211.1061]]
# ====================
# Epoch: 760/800..
#  Training loss: 902.73578..
#  torch.mean(F): 895.86151..
#  Reg Proj: 6.13017..
#  Reg Latent: 0.73952..
#  Repulsive: 0.00459..
#  Memory: 179.17230..
#  Memory: 179.17230..
#  Output:
#  [[2962.4807   977.63025 1255.4453 ]
#  [2960.8018   956.107   1272.847  ]
#  [2887.4966   943.9849  1231.9181 ]
#  [2922.1472   957.99146 1245.0736 ]]
# ====================
# Epoch: 800/800..
#  Training loss: 728.67224..
#  torch.mean(F): 722.80389..
#  Reg Proj: 5.18645..
#  Reg Latent: 0.67967..
#  Repulsive: 0.00219..
#  Memory: 144.56078..
#  Memory: 144.56078..
#  Output:
#  [[2910.3362 1407.4434 1125.5131]
#  [2664.6145 1301.0447 1037.1973]
#  [2753.0889 1336.781  1067.7991]
#  [2781.621  1349.4089 1077.365 ]]
# ====================
# getUncertaintyArea
# Ouputs are [[2560.6003  1235.81    1385.9355 ]
#  [2670.967   1322.4551   890.2821 ]
#  [3143.15    1638.6482   852.31915]
#  [2708.7266   652.5592   892.83594]]
# scale is 3213
# dx is 1874.0, dy is 3213.0, dz is 2463.0
# z is torch.Size([8000])
# Processing...
# flag is 1595
# m is 6406
# i is 8000
# Labeled 0/6406 points.
# Labeled 1000/6406 points.
# Labeled 2000/6406 points.
# Labeled 3000/6406 points.
# Labeled 4000/6406 points.
# Labeled 5000/6406 points.
# Labeled 6000/6406 points.
# Labeled all 6406/6406 points.
# Creating student for node 0210 with 4 centroids.
# Device is: cpu
# ====================
# Training Student Model
# Acc:  0.17421167655323136
# Epoch:  0 Cost:  7001.77392578125
# Acc:  0.8026849828285982
# Epoch:  300 Cost:  42.1454963684082
# Acc:  0.7841086481423666
# Epoch:  600 Cost:  43.28350830078125
# Acc:  0.8582578832344677
# Epoch:  900 Cost:  33.21781921386719
# Acc:  0.875741492350921
# Epoch:  1200 Cost:  28.60693359375
# Acc:  0.902591320636903
# Epoch:  1500 Cost:  26.354751586914062
# Acc:  0.9105526069310022
# Epoch:  1800 Cost:  23.845130920410156
# Acc:  0.8857321261317515
# Epoch:  2100 Cost:  24.184696197509766
# Acc:  0.9077427411801436
# Epoch:  2400 Cost:  21.104631423950195
# Acc:  0.7848891664064939
# Epoch:  2700 Cost:  60.090572357177734

# %%
# Report some tree stats.
leaves = ktree.get_leaves()
number_of_nodes = ktree.number_of_nodes

height = max([len(leaf.index) for leaf in leaves])
print(f"Tree height is {height}.")

leaf_sizes = [len(leaf.data) for leaf in leaves]
print(f"Created {len(leaves)} leaves with sizes")
print(leaf_sizes)
print(number_of_nodes)
# Out:
# Tree height is 5.
# Created 58 leaves with sizes
# [153, 399, 282, 358, 169, 100, 73, 15, 309, 13, 74, 160, 84, 340, 111, 79, 171, 360, 255, 175, 309, 141, 21, 81, 249, 132, 347, 108, 146, 192, 216, 148, 120, 274, 191, 355, 37, 75, 250, 109, 193, 140, 60, 306, 47, 229, 119, 228, 176, 213, 76, 71, 123, 251, 51, 148, 66, 321]
# 77

# %%
import numpy as np
import matplotlib.pyplot as plt
mean_acc_per_layer = np.zeros(height)
times=0
while times < 4:
    # now lets create randomly N points in the space 0-300, 0-300
    n = 300
    random_p = torch.zeros(n, 3)
    x_lim = [min(data[:, 0]), max(data[:, 0])]
    y_lim = [min(data[:, 1]), max(data[:, 1])]
    z_lim = [min(data[:, 2]), max(data[:, 2])]

    for i in range(n):
        random_p[i] = torch.Tensor([np.random.randint(x_lim[0], x_lim[1]), np.random.randint(y_lim[0], y_lim[1]), np.random.randint(z_lim[0], z_lim[1])])
    infer_points = random_p.to(device)

    correct_predictions_per_layer = np.zeros(height)
    accuracy_per_layer = np.zeros(height)
    
    qp = infer_points
    for i, query_point in enumerate(qp):
        preds_per_layer = ktree.query_verbose(query_point)["predictions per layer"]
        brute_force = ktree.root.query(query_point)

        for j, pred in enumerate(preds_per_layer):
            if np.array_equal(pred, brute_force):
                correct_predictions_per_layer[j] += 1

    accuracy_per_layer = correct_predictions_per_layer / len(infer_points) * 100
    mean_acc_per_layer += accuracy_per_layer
    times += 1
    print(f"The percentage of correct predictions per layer is: ")
    print(accuracy_per_layer)

print(f"The mean percentage of correct predictions is: ")
print(mean_acc_per_layer/times)
# Out:
# The percentage of correct predictions per layer is:
# [90.33333333 81.66666667 74.33333333 64.         12.66666667]
# The percentage of correct predictions per layer is:
# [94.33333333 83.         72.33333333 62.33333333  9.66666667]
# The percentage of correct predictions per layer is:
# [94.66666667 82.33333333 70.66666667 59.66666667 13.33333333]
# The percentage of correct predictions per layer is:
# [92.66666667 82.33333333 73.33333333 60.33333333 12.66666667]
# The mean percentage of correct predictions is:
# [93.         82.33333333 72.66666667 61.58333333 12.08333333]

# %%
import numpy as np
import matplotlib.pyplot as plt
mean_acc_per_layer = np.zeros(height)
times=0
while times < 4:
    # now lets create randomly N points in the space 0-300, 0-300
    n = 300
    random_p = torch.zeros(n, 3)
    x_lim = [min(data[:, 0]), max(data[:, 0])]
    y_lim = [min(data[:, 1]), max(data[:, 1])]
    z_lim = [min(data[:, 2]), max(data[:, 2])]

    for i in range(n):
        random_p[i] = torch.Tensor([np.random.randint(x_lim[0], x_lim[1]), np.random.randint(y_lim[0], y_lim[1]), np.random.randint(z_lim[0], z_lim[1])])
    infer_points = random_p.to(device)

    correct_predictions_per_layer = np.zeros(height)
    accuracy_per_layer = np.zeros(height)
    
    qp = infer_points
    for i, query_point in enumerate(qp):
        preds_per_layer = ktree.query_verbose(query_point)["predictions per layer"]
        k_nearest_neighbors = ktree.root.query(query_point, k=2)

        for j, pred in enumerate(preds_per_layer):
            if any(np.array_equal(pred[0], k_nearest_neighbors[ki]) for ki in range(2)):
                correct_predictions_per_layer[j] += 1

    accuracy_per_layer = correct_predictions_per_layer / len(infer_points) * 100
    mean_acc_per_layer += accuracy_per_layer
    times += 1
    print(f"The percentage of correct predictions per layer is: ")
    print(accuracy_per_layer)

print(f"The mean percentage of correct predictions is: ")
print(mean_acc_per_layer/times)
# Out:
# The percentage of correct predictions per layer is:
# [97.33333333 92.33333333 86.66666667 75.33333333 12.        ]
# The percentage of correct predictions per layer is:
# [96.33333333 90.66666667 83.66666667 71.         15.33333333]
# The percentage of correct predictions per layer is:
# [96.         87.         80.33333333 67.66666667 12.33333333]
# The percentage of correct predictions per layer is:
# [97.33333333 89.         82.33333333 71.         15.33333333]
# The mean percentage of correct predictions is:
# [96.75 89.75 83.25 71.25 13.75]

# %%
import numpy as np
import matplotlib.pyplot as plt
mean_acc_per_layer = np.zeros(height)
times=0
while times < 4:
    # now lets create randomly N points in the space 0-300, 0-300
    n = 300
    random_p = torch.zeros(n, 3)
    x_lim = [min(data[:, 0]), max(data[:, 0])]
    y_lim = [min(data[:, 1]), max(data[:, 1])]
    z_lim = [min(data[:, 2]), max(data[:, 2])]

    for i in range(n):
        random_p[i] = torch.Tensor([np.random.randint(x_lim[0], x_lim[1]), np.random.randint(y_lim[0], y_lim[1]), np.random.randint(z_lim[0], z_lim[1])])
    infer_points = random_p.to(device)

    correct_predictions_per_layer = np.zeros(height)
    accuracy_per_layer = np.zeros(height)
    
    qp = infer_points
    for i, query_point in enumerate(qp):
        preds_per_layer = ktree.query_verbose(query_point)["predictions per layer"]
        k_nearest_neighbors = ktree.root.query(query_point, k=5)

        for j, pred in enumerate(preds_per_layer):
            if any(np.array_equal(pred[0], k_nearest_neighbors[ki]) for ki in range(5)):
                correct_predictions_per_layer[j] += 1

    accuracy_per_layer = correct_predictions_per_layer / len(infer_points) * 100
    mean_acc_per_layer += accuracy_per_layer
    times += 1
    print(f"The percentage of correct predictions per layer is: ")
    print(accuracy_per_layer)

print(f"The mean percentage of correct predictions is: ")
print(mean_acc_per_layer/times)
# Out:
# The percentage of correct predictions per layer is:
# [99.         95.         92.33333333 82.66666667 13.33333333]
# The percentage of correct predictions per layer is:
# [98.33333333 95.33333333 90.66666667 75.66666667 14.33333333]
# The percentage of correct predictions per layer is:
# [99.33333333 97.66666667 94.66666667 84.         15.        ]
# The percentage of correct predictions per layer is:
# [99.33333333 96.66666667 92.66666667 79.         15.        ]
# The mean percentage of correct predictions is:
# [99.         96.16666667 92.58333333 80.33333333 14.41666667]

# %%
import numpy as np
import matplotlib.pyplot as plt
mean_acc_per_layer = np.zeros(height)
times=0
while times < 4:
    # now lets create randomly N points in the space 0-300, 0-300
    n = 300
    random_p = torch.zeros(n, 3)
    x_lim = [min(data[:, 0]), max(data[:, 0])]
    y_lim = [min(data[:, 1]), max(data[:, 1])]
    z_lim = [min(data[:, 2]), max(data[:, 2])]

    for i in range(n):
        random_p[i] = torch.Tensor([np.random.randint(x_lim[0], x_lim[1]), np.random.randint(y_lim[0], y_lim[1]), np.random.randint(z_lim[0], z_lim[1])])
    infer_points = random_p.to(device)

    correct_predictions_per_layer = np.zeros(height)
    accuracy_per_layer = np.zeros(height)
    
    qp = infer_points
    for i, query_point in enumerate(qp):
        preds_per_layer = ktree.query_verbose(query_point)["predictions per layer"]
        k_nearest_neighbors = ktree.root.query(query_point, k=10)

        for j, pred in enumerate(preds_per_layer):
            if any(np.array_equal(pred[0], k_nearest_neighbors[ki]) for ki in range(10)):
                correct_predictions_per_layer[j] += 1

    accuracy_per_layer = correct_predictions_per_layer / len(infer_points) * 100
    mean_acc_per_layer += accuracy_per_layer
    times += 1
    print(f"The percentage of correct predictions per layer is: ")
    print(accuracy_per_layer)

print(f"The mean percentage of correct predictions is: ")
print(mean_acc_per_layer/times)
# Out:
# The percentage of correct predictions per layer is:
# [99.66666667 99.66666667 99.33333333 88.66666667 20.33333333]
# The percentage of correct predictions per layer is:
# [99.66666667 99.         97.33333333 87.33333333 18.        ]
# The percentage of correct predictions per layer is:
# [99.33333333 97.66666667 96.33333333 82.33333333 21.        ]
# The percentage of correct predictions per layer is:
# [100.          98.          96.33333333  84.          15.66666667]
# The mean percentage of correct predictions is:
# [99.66666667 98.58333333 97.33333333 85.58333333 18.75      ]

# %%
import numpy as np
import matplotlib.pyplot as plt
mean_acc_per_layer = np.zeros(height)
times=0

while times < 1:
    nop =  500
    random_p = torch.zeros(nop, 3)
    x_lim = [min(data[:, 0]), max(data[:, 0])]
    y_lim = [min(data[:, 1]), max(data[:, 1])]
    z_lim = [min(data[:, 2]), max(data[:, 2])]
    num = int(nop ** (1/3))
    for i, x in enumerate(np.linspace(x_lim[0],x_lim[1], num)):
        for j, y in enumerate(np.linspace(y_lim[0],y_lim[1], num)):
            for k, z in enumerate(np.linspace(z_lim[0],z_lim[1], num)):
                random_p[i * (num ** 2) + j * num + k] = torch.Tensor([x, y, z])
    
    infer_points = random_p.to(device)
    # plt.scatter(infer_points[:,0], infer_points[:,1], infer_points[:,2])

    correct_predictions_per_layer = np.zeros(height)
    accuracy_per_layer = np.zeros(height)

    qp = infer_points
    for i, query_point in enumerate(qp):
        preds_per_layer = ktree.query_verbose(query_point)["predictions per layer"]
        brute_force = ktree.root.query(query_point)

        for j, pred in enumerate(preds_per_layer):
            if np.array_equal(pred, brute_force):
                correct_predictions_per_layer[j] += 1

    accuracy_per_layer = correct_predictions_per_layer / len(infer_points) * 100
    mean_acc_per_layer += accuracy_per_layer
    times += 1
    print(f"The percentage of correct predictions per layer is: ")
    print(accuracy_per_layer)

print(f"The mean percentage of correct predictions is: ")
print(mean_acc_per_layer/times)
# Out:
# The percentage of correct predictions per layer is:
# [94.2 89.8 83.  75.4  9. ]
# The mean percentage of correct predictions is:
# [94.2 89.8 83.  75.4  9. ]
