# %%
from itertools import product, combinations
import matplotlib.pyplot as plt
import numpy as np
from src import k_tree
from src.utils import data as dt
import torch
from src.k_tree import Ktree
from src.utils.data import loadData, loadData_3d
from src.metrics import Linf_simple
from src import ellipses as el

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
device = "cpu"
data, _ = loadData(1000)


#data = rects
learning_rate = 5e-3 # 1e-2, 5e-3
k = 3
teacher_args = {
    "optimizer_lr": learning_rate,
    "epochs": 1000, # 300
    "times": 20,
    "alpha": 0.1, #  projection loss 0.1
    "beta": 0.1, # latent loss 0.1
    "gamma": 0.01, # repulsive loss 0.01 - dioxnei makria ta kentra to ena apo to allo - fainetai sto log an einai megalo
    #"gamma": 0.4, # repulsive loss 0.01
    "delta": 0.05, # fuzzy scale 0.01
    "f_clk": 10, # 20
    "scale": 1, # fuzzy scale 
    "scale_flag": False,
    "number_of_centroids": k,
    "latent_size": 200,
    "encoder_activation": False,
    "encoder_depth": 5,
    "predictor_width": 5*100,
    "predictor_depth": 5,
}
n = 30
un_args = {
    "N": n,
    "M": n**2-1, # 10000 - 1
    "epsilon": 0.15 # here a layer value should be somehow included. As layers get denser  epilson should be smaller
}
student_args = {
    "optimizer_lr": 5e-3,
    "epochs": 3000, # 30000, 3000
    "width": 200,
    "depth": 5,
}

# thresshold = 0.1 * len(data)
threshold = k * 100
metric = Linf_simple
ktree = Ktree(threshold, data, metric,teacher_args, un_args, student_args,device=device)
ktree.create_tree(plot=True)
# Out:
# Loading data...
# Data loaded.
#
# ====================
# Creating student for node 0 that has 999 data, which is more than the threshold 300.
# Bounding box for node 0: [[3, 7004], [11, 7006]]
# Creating teacher for node 0 with 3 centroids.
# ====================
# Training Teacher Model
# /home/geoten/Projects/GeoCluster/src/geometry.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   rotation = torch.tensor(rotation)
# ====================
# Epoch: 50/1000..
#  Training loss: 1853.79321..
#  torch.mean(F): 1853.75378..
#  Reg Proj: 0.00000..
#  Reg Latent: 0.03945..
#  Repulsive: 0.00003..
#  Memory: 92.68769..
#  Memory: 92.68769..
#  Output:
#  [[2977.312  2021.2949]
#  [1119.376   760.1071]
#  [4909.006  3332.5771]]
# ====================
# Epoch: 100/1000..
#  Training loss: 1678.71631..
#  torch.mean(F): 1678.67883..
#  Reg Proj: 0.00000..
#  Reg Latent: 0.03749..
#  Repulsive: 0.00003..
#  Memory: 83.93394..
#  Memory: 83.93394..
#  Output:
#  [[3760.7864 3082.465 ]
#  [1945.066  1594.1752]
#  [5707.7    4678.3467]]
# ====================
# Epoch: 150/1000..
#  Training loss: 1621.86548..
#  torch.mean(F): 1621.82947..
#  Reg Proj: 0.00000..
#  Reg Latent: 0.03598..
#  Repulsive: 0.00003..
#  Memory: 81.09147..
#  Memory: 81.09147..
#  Output:
#  [[3323.2075 3359.5059]
#  [1844.5192 1864.7573]
#  [4779.3457 4831.4897]]
# ====================
# Epoch: 200/1000..
#  Training loss: 1619.83435..
#  torch.mean(F): 1619.79956..
#  Reg Proj: 0.00000..
#  Reg Latent: 0.03485..
#  Repulsive: 0.00003..
#  Memory: 80.98998..
#  Memory: 80.98998..
#  Output:
#  [[3465.0144 3558.139 ]
#  [2038.2189 2093.1301]
#  [4997.0576 5131.263 ]]
# ====================
# Epoch: 250/1000..
#  Training loss: 1623.66858..
#  torch.mean(F): 1623.63416..
#  Reg Proj: 0.00000..
#  Reg Latent: 0.03448..
#  Repulsive: 0.00003..
#  Memory: 81.18171..
#  Memory: 81.18171..
#  Output:
#  [[3546.855  3418.514 ]
#  [1919.7649 1850.2667]
#  [5010.853  4829.5815]]
# ====================
# Epoch: 300/1000..
#  Training loss: 1618.57361..
#  torch.mean(F): 1618.53931..
#  Reg Proj: 0.00000..
#  Reg Latent: 0.03431..
#  Repulsive: 0.00003..
#  Memory: 80.92697..
#  Memory: 80.92697..
#  Output:
#  [[3510.473  3566.8694]
#  [1960.0781 1991.8037]
#  [4994.37   5074.352 ]]
# ====================
# Epoch: 350/1000..
#  Training loss: 1627.97900..
#  torch.mean(F): 1627.94470..
#  Reg Proj: 0.00000..
#  Reg Latent: 0.03425..
#  Repulsive: 0.00003..
#  Memory: 81.39724..
#  Memory: 81.39724..
#  Output:
#  [[3754.761  3716.3738]
#  [2165.0083 2142.8403]
#  [5324.71   5270.3193]]
# ====================
# Epoch: 400/1000..
#  Training loss: 1620.37231..
#  torch.mean(F): 1620.33777..
#  Reg Proj: 0.00000..
#  Reg Latent: 0.03454..
#  Repulsive: 0.00003..
#  Memory: 81.01689..
#  Memory: 81.01689..
#  Output:
#  [[3592.0537 3686.0854]
#  [2048.652  2102.3577]
#  [5161.7393 5296.7715]]
# ====================
# Epoch: 450/1000..
#  Training loss: 1621.88293..
#  torch.mean(F): 1621.84827..
#  Reg Proj: 0.00000..
#  Reg Latent: 0.03463..
#  Repulsive: 0.00003..
#  Memory: 81.09241..
#  Memory: 81.09241..
#  Output:
#  [[3654.596  3707.0774]
#  [2012.5869 2041.6318]
#  [5214.6    5289.325 ]]
# ====================
# Epoch: 500/1000..
#  Training loss: 1618.97888..
#  torch.mean(F): 1618.94421..
#  Reg Proj: 0.00000..
#  Reg Latent: 0.03473..
#  Repulsive: 0.00003..
#  Memory: 80.94721..
#  Memory: 80.94721..
#  Output:
#  [[3518.233  3663.19  ]
#  [1962.7756 2043.7902]
#  [5000.6104 5206.546 ]]
# ====================
# Epoch: 550/1000..
#  Training loss: 1630.95227..
#  torch.mean(F): 1630.91760..
#  Reg Proj: 0.00000..
#  Reg Latent: 0.03472..
#  Repulsive: 0.00003..
#  Memory: 81.54588..
#  Memory: 81.54588..
#  Output:
#  [[3786.8955 3695.4126]
#  [2116.1147 2064.9937]
#  [5447.7686 5316.198 ]]
# ====================
# Epoch: 600/1000..
#  Training loss: 1624.50049..
#  torch.mean(F): 1624.46570..
#  Reg Proj: 0.00000..
#  Reg Latent: 0.03483..
#  Repulsive: 0.00003..
#  Memory: 81.22328..
#  Memory: 81.22328..
#  Output:
#  [[3688.853  3535.5012]
#  [2111.008  2023.3395]
#  [5232.7905 5015.147 ]]
# ====================
# Epoch: 650/1000..
#  Training loss: 1664.16406..
#  torch.mean(F): 1664.13000..
#  Reg Proj: 0.00000..
#  Reg Latent: 0.03408..
#  Repulsive: 0.00004..
#  Memory: 83.20650..
#  Memory: 83.20650..
#  Output:
#  [[2968.0156 2978.942 ]
#  [1605.4359 1611.5493]
#  [4322.3447 4338.089 ]]
# ====================
# Epoch: 700/1000..
#  Training loss: 1619.88123..
#  torch.mean(F): 1619.84729..
#  Reg Proj: 0.00000..
#  Reg Latent: 0.03391..
#  Repulsive: 0.00003..
#  Memory: 80.99236..
#  Memory: 80.99236..
#  Output:
#  [[3344.7363 3440.608 ]
#  [1912.3816 1967.2225]
#  [4843.565  4982.3887]]
# ====================
# Epoch: 750/1000..
#  Training loss: 1635.63745..
#  torch.mean(F): 1635.60388..
#  Reg Proj: 0.00000..
#  Reg Latent: 0.03353..
#  Repulsive: 0.00003..
#  Memory: 81.78019..
#  Memory: 81.78019..
#  Output:
#  [[3657.1223 3879.162 ]
#  [1966.8297 2086.3657]
#  [5338.5947 5662.5767]]
# ====================
# Epoch: 800/1000..
#  Training loss: 1620.40381..
#  torch.mean(F): 1620.37024..
#  Reg Proj: 0.00000..
#  Reg Latent: 0.03352..
#  Repulsive: 0.00003..
#  Memory: 81.01851..
#  Memory: 81.01851..
#  Output:
#  [[3319.8447 3489.5632]
#  [1884.0848 1980.4822]
#  [4763.079  5006.5156]]
# ====================
# Epoch: 850/1000..
#  Training loss: 1619.44763..
#  torch.mean(F): 1619.41467..
#  Reg Proj: 0.00000..
#  Reg Latent: 0.03293..
#  Repulsive: 0.00003..
#  Memory: 80.97073..
#  Memory: 80.97073..
#  Output:
#  [[3392.9214 3496.8347]
#  [1911.0756 1969.6327]
#  [4928.0093 5078.9087]]
# ====================
# Epoch: 900/1000..
#  Training loss: 1621.00195..
#  torch.mean(F): 1620.96899..
#  Reg Proj: 0.00000..
#  Reg Latent: 0.03293..
#  Repulsive: 0.00003..
#  Memory: 81.04845..
#  Memory: 81.04845..
#  Output:
#  [[3430.3076 3697.9797]
#  [1974.1471 2128.146 ]
#  [4953.1123 5339.618 ]]
# ====================
# Epoch: 950/1000..
#  Training loss: 1627.33447..
#  torch.mean(F): 1627.30176..
#  Reg Proj: 0.00000..
#  Reg Latent: 0.03275..
#  Repulsive: 0.00003..
#  Memory: 81.36509..
#  Memory: 81.36509..
#  Output:
#  [[3675.7654 3773.806 ]
#  [2118.5215 2174.9438]
#  [5266.2363 5406.776 ]]
# ====================
# Epoch: 1000/1000..
#  Training loss: 1668.96753..
#  torch.mean(F): 1668.93579..
#  Reg Proj: 0.00000..
#  Reg Latent: 0.03169..
#  Repulsive: 0.00003..
#  Memory: 83.44679..
#  Memory: 83.44679..
#  Output:
#  [[4115.1167 3931.7346]
#  [2284.872  2183.1797]
#  [5930.579  5666.161 ]]
# ====================
# getUncertaintyArea
# Ouputs are [[3545.892  3690.0894]
#  [1899.4131 2051.4453]
#  [5092.0234 4947.292 ]]
# scale is 7001
# Processing...
# flag is 761
# m is 140
# i is 900
# Labeled 0/140 points.
# Labeled all 140/140 points.
# Creating student for node 0 with 3 centroids.
# Device is: cpu
# ====================
# Training Student Model
# Acc:  0.2571428571428571
# Epoch:  0 Cost:  6188.28271484375
# Acc:  0.6928571428571428
# Epoch:  300 Cost:  74.60366821289062
# Acc:  0.4928571428571429
# Epoch:  600 Cost:  87.98563385009766
# Acc:  0.8
# Epoch:  900 Cost:  53.05121612548828
# Acc:  0.6928571428571428
# Epoch:  1200 Cost:  55.55837631225586
# Acc:  0.7071428571428572
# Epoch:  1500 Cost:  52.33845520019531
# Acc:  0.6
# Epoch:  1800 Cost:  84.90383911132812
# Acc:  0.5785714285714286
# Epoch:  2100 Cost:  76.67306518554688
# Acc:  0.5357142857142857
# Epoch:  2400 Cost:  68.99254608154297
# Acc:  0.7857142857142857
# Epoch:  2700 Cost:  56.866539001464844
# ====================
# Creating student for node 00 that has 402 data, which is more than the threshold 300.
# Bounding box for node 00: [[71, 6962], [11, 7001]]
# Creating teacher for node 00 with 3 centroids.
# ====================
# Training Teacher Model
# ====================
# Epoch: 50/1000..
#  Training loss: 2011.52966..
#  torch.mean(F): 2008.89929..
#  Reg Proj: 2.56647..
#  Reg Latent: 0.06380..
#  Repulsive: 0.00002..
#  Memory: 100.44496..
#  Memory: 100.44496..
#  Output:
#  [[5096.316  4103.6904]
#  [ 666.9321  536.5012]
#  [3350.1353 2698.9302]]
# ====================
# Epoch: 100/1000..
#  Training loss: 2538.11523..
#  torch.mean(F): 2534.64062..
#  Reg Proj: 3.41454..
#  Reg Latent: 0.06001..
#  Repulsive: 0.00002..
#  Memory: 126.73203..
#  Memory: 126.73203..
#  Output:
#  [[4634.454  5704.31  ]
#  [ 944.5934 1162.5989]
#  [2090.994  2573.6826]]
# ====================
# Epoch: 150/1000..
#  Training loss: 1852.71643..
#  torch.mean(F): 1850.16638..
#  Reg Proj: 2.49072..
#  Reg Latent: 0.05930..
#  Repulsive: 0.00003..
#  Memory: 92.50832..
#  Memory: 92.50832..
#  Output:
#  [[3095.3347  4284.042  ]
#  [2170.7405  3005.314  ]
#  [ 705.0435   975.24963]]
# ====================
# Epoch: 200/1000..
#  Training loss: 1814.18384..
#  torch.mean(F): 1812.03113..
#  Reg Proj: 2.09348..
#  Reg Latent: 0.05916..
#  Repulsive: 0.00004..
#  Memory: 90.60156..
#  Memory: 90.60156..
#  Output:
#  [[4528.309  3917.4626]
#  [3675.8242 3180.7073]
#  [1347.9078 1166.07  ]]
# ====================
# Epoch: 250/1000..
#  Training loss: 1734.39075..
#  torch.mean(F): 1732.34155..
#  Reg Proj: 1.99028..
#  Reg Latent: 0.05900..
#  Repulsive: 0.00004..
#  Memory: 86.61708..
#  Memory: 86.61708..
#  Output:
#  [[3731.6108 4208.22  ]
#  [2895.7568 3265.9124]
#  [1158.551  1306.4033]]
# ====================
# Epoch: 300/1000..
#  Training loss: 1822.89392..
#  torch.mean(F): 1820.86328..
#  Reg Proj: 1.97134..
#  Reg Latent: 0.05938..
#  Repulsive: 0.00004..
#  Memory: 91.04316..
#  Memory: 91.04316..
#  Output:
#  [[3879.2195 3458.0994]
#  [3007.6921 2681.2634]
#  [1276.3223 1137.759 ]]
# ====================
# Epoch: 350/1000..
#  Training loss: 1762.93567..
#  torch.mean(F): 1760.93066..
#  Reg Proj: 1.94525..
#  Reg Latent: 0.05976..
#  Repulsive: 0.00004..
#  Memory: 88.04653..
#  Memory: 88.04653..
#  Output:
#  [[4216.489  3882.0374]
#  [3471.019  3195.802 ]
#  [1466.625  1350.2473]]
# ====================
# Epoch: 400/1000..
#  Training loss: 1905.71741..
#  torch.mean(F): 1903.34668..
#  Reg Proj: 2.31062..
#  Reg Latent: 0.06002..
#  Repulsive: 0.00003..
#  Memory: 95.16733..
#  Memory: 95.16733..
#  Output:
#  [[4957.9463 4699.577 ]
#  [3577.054  3390.5505]
#  [1652.9    1566.7509]]
# ====================
# Epoch: 450/1000..
#  Training loss: 1739.96191..
#  torch.mean(F): 1738.20618..
#  Reg Proj: 1.69610..
#  Reg Latent: 0.05966..
#  Repulsive: 0.00005..
#  Memory: 86.91031..
#  Memory: 86.91031..
#  Output:
#  [[3956.312  4053.3455]
#  [3090.1855 3165.9824]
#  [1704.5355 1746.3248]]
# ====================
# Epoch: 500/1000..
#  Training loss: 1732.48572..
#  torch.mean(F): 1730.74902..
#  Reg Proj: 1.67625..
#  Reg Latent: 0.06044..
#  Repulsive: 0.00005..
#  Memory: 86.53745..
#  Memory: 86.53745..
#  Output:
#  [[3924.393  4046.93  ]
#  [3194.2336 3293.633 ]
#  [1717.1254 1770.7812]]
# ====================
# Epoch: 550/1000..
#  Training loss: 1748.14563..
#  torch.mean(F): 1746.45569..
#  Reg Proj: 1.62960..
#  Reg Latent: 0.06031..
#  Repulsive: 0.00005..
#  Memory: 87.32278..
#  Memory: 87.32278..
#  Output:
#  [[4081.7302 4256.7856]
#  [3273.4663 3413.5613]
#  [1850.8038 1930.2069]]
# ====================
# Epoch: 600/1000..
#  Training loss: 1737.10461..
#  torch.mean(F): 1735.62146..
#  Reg Proj: 1.42498..
#  Reg Latent: 0.05822..
#  Repulsive: 0.00005..
#  Memory: 86.78107..
#  Memory: 86.78107..
#  Output:
#  [[3945.899  3952.957 ]
#  [3210.334  3215.6975]
#  [1957.2834 1960.8102]]
# ====================
# Epoch: 650/1000..
#  Training loss: 1677.02075..
#  torch.mean(F): 1676.62439..
#  Reg Proj: 0.33812..
#  Reg Latent: 0.05817..
#  Repulsive: 0.00009..
#  Memory: 83.83122..
#  Memory: 83.83122..
#  Output:
#  [[4058.1113 4038.1892]
#  [3501.407  3484.397 ]
#  [2946.8567 2932.3855]]
# ====================
# Epoch: 700/1000..
#  Training loss: 1683.10352..
#  torch.mean(F): 1682.65906..
#  Reg Proj: 0.38691..
#  Reg Latent: 0.05739..
#  Repulsive: 0.00010..
#  Memory: 84.13295..
#  Memory: 84.13295..
#  Output:
#  [[4290.014  3984.751 ]
#  [3758.3906 3490.87  ]
#  [3241.1294 3010.4937]]
# ====================
# Epoch: 750/1000..
#  Training loss: 1704.09900..
#  torch.mean(F): 1703.50183..
#  Reg Proj: 0.54111..
#  Reg Latent: 0.05586..
#  Repulsive: 0.00008..
#  Memory: 85.17509..
#  Memory: 85.17509..
#  Output:
#  [[4439.169  4315.09  ]
#  [3771.4563 3666.0461]
#  [3170.6584 3082.041 ]]
# ====================
# Epoch: 800/1000..
#  Training loss: 1709.34485..
#  torch.mean(F): 1709.03308..
#  Reg Proj: 0.25617..
#  Reg Latent: 0.05543..
#  Repulsive: 0.00010..
#  Memory: 85.45165..
#  Memory: 85.45165..
#  Output:
#  [[3626.0952 3931.6538]
#  [3144.3308 3409.3228]
#  [2689.7847 2916.4414]]
# ====================
# Epoch: 850/1000..
#  Training loss: 1997.16479..
#  torch.mean(F): 1995.02710..
#  Reg Proj: 2.08344..
#  Reg Latent: 0.05417..
#  Repulsive: 0.00005..
#  Memory: 99.75135..
#  Memory: 99.75135..
#  Output:
#  [[6290.0103 5911.2837]
#  [4845.6353 4553.9243]
#  [3994.9138 3754.3481]]
# ====================
# Epoch: 900/1000..
#  Training loss: 1743.24939..
#  torch.mean(F): 1742.51648..
#  Reg Proj: 0.68090..
#  Reg Latent: 0.05192..
#  Repulsive: 0.00009..
#  Memory: 87.12582..
#  Memory: 87.12582..
#  Output:
#  [[4503.1577 4502.682 ]
#  [3917.7983 3917.3748]
#  [3384.368  3384.0037]]
# ====================
# Epoch: 950/1000..
#  Training loss: 1677.09448..
#  torch.mean(F): 1676.68652..
#  Reg Proj: 0.35375..
#  Reg Latent: 0.05403..
#  Repulsive: 0.00011..
#  Memory: 83.83433..
#  Memory: 83.83433..
#  Output:
#  [[4127.068  3956.9734]
#  [3688.509  3536.5364]
#  [3217.517  3084.9814]]
# ====================
# Epoch: 1000/1000..
#  Training loss: 1724.58728..
#  torch.mean(F): 1724.25183..
#  Reg Proj: 0.28213..
#  Reg Latent: 0.05320..
#  Repulsive: 0.00010..
#  Memory: 86.21259..
#  Memory: 86.21259..
#  Output:
#  [[3759.3342 3807.9756]
#  [3191.946  3233.2588]
#  [2719.196  2754.4226]]
# ====================
# getUncertaintyArea
# Ouputs are [[3861.7178 4363.6113]
#  [3318.7627 3750.0332]
#  [2824.4414 3191.4043]]
# scale is 6990
# Processing...
# flag is 316
# m is 585
# i is 900
# Labeled 0/585 points.
# Labeled all 585/585 points.
# Creating student for node 00 with 3 centroids.
# Device is: cpu
# ====================
# Training Student Model
# Acc:  0.3487179487179487
# Epoch:  0 Cost:  6871.0703125
# Acc:  0.7316239316239316
# Epoch:  300 Cost:  62.665321350097656
# Acc:  0.7128205128205128
# Epoch:  600 Cost:  66.29182434082031
# Acc:  0.6307692307692307
# Epoch:  900 Cost:  129.91134643554688
# Acc:  0.8752136752136752
# Epoch:  1200 Cost:  35.00681686401367
# Acc:  0.7726495726495727
# Epoch:  1500 Cost:  42.14164352416992
# Acc:  0.6991452991452991
# Epoch:  1800 Cost:  58.938114166259766
# Acc:  0.6444444444444445
# Epoch:  2100 Cost:  83.75109100341797
# Acc:  0.8905982905982905
# Epoch:  2400 Cost:  29.86066436767578
# Acc:  0.9504273504273504
# Epoch:  2700 Cost:  23.534399032592773
# ====================
# Creating student for node 01 that has 324 data, which is more than the threshold 300.
# Bounding box for node 01: [[3, 5179], [21, 5194]]
# Creating teacher for node 01 with 3 centroids.
# ====================
# Training Teacher Model
# ====================
# Epoch: 50/1000..
#  Training loss: 1640.40649..
#  torch.mean(F): 1638.92725..
#  Reg Proj: 1.46707..
#  Reg Latent: 0.01216..
#  Repulsive: 0.00003..
#  Memory: 81.94636..
#  Memory: 81.94636..
#  Output:
#  [[1736.5929  3950.3176 ]
#  [ 254.36597  578.0363 ]
#  [2126.5042  4837.92   ]]
# ====================
# Epoch: 100/1000..
#  Training loss: 1136.16113..
#  torch.mean(F): 1136.07764..
#  Reg Proj: 0.07157..
#  Reg Latent: 0.01188..
#  Repulsive: 0.00007..
#  Memory: 56.80388..
#  Memory: 56.80388..
#  Output:
#  [[1655.105   1659.2257 ]
#  [ 849.22174  851.3362 ]
#  [2313.5112  2319.2825 ]]
# ====================
# Epoch: 150/1000..
#  Training loss: 1115.12817..
#  torch.mean(F): 1114.97217..
#  Reg Proj: 0.14484..
#  Reg Latent: 0.01116..
#  Repulsive: 0.00006..
#  Memory: 55.74861..
#  Memory: 55.74861..
#  Output:
#  [[1805.7761  1956.0016 ]
#  [ 926.96704 1004.2284 ]
#  [2398.9321  2598.3647 ]]
# ====================
# Epoch: 200/1000..
#  Training loss: 1166.49597..
#  torch.mean(F): 1166.44885..
#  Reg Proj: 0.03536..
#  Reg Latent: 0.01161..
#  Repulsive: 0.00007..
#  Memory: 58.32244..
#  Memory: 58.32244..
#  Output:
#  [[1823.6855 1487.7721]
#  [ 931.6238  760.0048]
#  [2462.916  2009.2598]]
# ====================
# Epoch: 250/1000..
#  Training loss: 1208.17334..
#  torch.mean(F): 1207.10291..
#  Reg Proj: 1.05882..
#  Reg Latent: 0.01165..
#  Repulsive: 0.00005..
#  Memory: 60.35515..
#  Memory: 60.35515..
#  Output:
#  [[2174.1638 2169.8296]
#  [1122.1149 1119.8949]
#  [3068.3875 3062.2551]]
# ====================
# Epoch: 300/1000..
#  Training loss: 1184.14917..
#  torch.mean(F): 1183.55664..
#  Reg Proj: 0.58057..
#  Reg Latent: 0.01201..
#  Repulsive: 0.00005..
#  Memory: 59.17783..
#  Memory: 59.17783..
#  Output:
#  [[2222.0632 1926.4865]
#  [1141.707   989.8568]
#  [3062.3794 2655.025 ]]
# ====================
# Epoch: 350/1000..
#  Training loss: 1172.82947..
#  torch.mean(F): 1172.78711..
#  Reg Proj: 0.03137..
#  Reg Latent: 0.01092..
#  Repulsive: 0.00007..
#  Memory: 58.63936..
#  Memory: 58.63936..
#  Output:
#  [[1641.129   1536.648  ]
#  [ 853.61224  799.27405]
#  [2222.709   2081.209  ]]
# ====================
# Epoch: 400/1000..
#  Training loss: 1170.85425..
#  torch.mean(F): 1170.19312..
#  Reg Proj: 0.64941..
#  Reg Latent: 0.01178..
#  Repulsive: 0.00006..
#  Memory: 58.50966..
#  Memory: 58.50966..
#  Output:
#  [[2073.7573 2016.5647]
#  [1062.8588 1033.5397]
#  [2884.8435 2805.2827]]
# ====================
# Epoch: 450/1000..
#  Training loss: 1146.22766..
#  torch.mean(F): 1145.73279..
#  Reg Proj: 0.48264..
#  Reg Latent: 0.01219..
#  Repulsive: 0.00006..
#  Memory: 57.28664..
#  Memory: 57.28664..
#  Output:
#  [[2039.6526 2046.9243]
#  [ 997.0862 1000.6509]
#  [2746.6365 2756.3909]]
# ====================
# Epoch: 500/1000..
#  Training loss: 1150.11938..
#  torch.mean(F): 1149.73181..
#  Reg Proj: 0.37629..
#  Reg Latent: 0.01121..
#  Repulsive: 0.00005..
#  Memory: 57.48659..
#  Memory: 57.48659..
#  Output:
#  [[2089.2708 1834.115 ]
#  [1042.599   915.277 ]
#  [2894.0557 2540.6223]]
# ====================
# Epoch: 550/1000..
#  Training loss: 1150.51501..
#  torch.mean(F): 1150.43616..
#  Reg Proj: 0.06824..
#  Reg Latent: 0.01055..
#  Repulsive: 0.00007..
#  Memory: 57.52181..
#  Memory: 57.52181..
#  Output:
#  [[2028.0024 1670.2578]
#  [1080.727   890.1068]
#  [2589.8457 2132.971 ]]
# ====================
# Epoch: 600/1000..
#  Training loss: 1238.58118..
#  torch.mean(F): 1236.01245..
#  Reg Proj: 2.55675..
#  Reg Latent: 0.01191..
#  Repulsive: 0.00004..
#  Memory: 61.80062..
#  Memory: 61.80062..
#  Output:
#  [[2547.079  2289.616 ]
#  [1380.8729 1241.3248]
#  [3979.1855 3576.9531]]
# ====================
# Epoch: 650/1000..
#  Training loss: 1135.68298..
#  torch.mean(F): 1135.56897..
#  Reg Proj: 0.10088..
#  Reg Latent: 0.01311..
#  Repulsive: 0.00007..
#  Memory: 56.77845..
#  Memory: 56.77845..
#  Output:
#  [[1794.0322  1655.264  ]
#  [1000.14856  922.7104 ]
#  [2482.5552  2290.5872 ]]
# ====================
# Epoch: 700/1000..
#  Training loss: 1141.73193..
#  torch.mean(F): 1141.34644..
#  Reg Proj: 0.37075..
#  Reg Latent: 0.01481..
#  Repulsive: 0.00006..
#  Memory: 57.06732..
#  Memory: 57.06732..
#  Output:
#  [[2109.1155  1927.9567 ]
#  [1056.3921   965.60614]
#  [2804.71    2563.8696 ]]
# ====================
# Epoch: 750/1000..
#  Training loss: 1205.06006..
#  torch.mean(F): 1205.02710..
#  Reg Proj: 0.01845..
#  Reg Latent: 0.01441..
#  Repulsive: 0.00008..
#  Memory: 60.25135..
#  Memory: 60.25135..
#  Output:
#  [[1556.4375  1513.6328 ]
#  [ 776.71484  755.3544 ]
#  [2068.1272  2011.2546 ]]
# ====================
# Epoch: 800/1000..
#  Training loss: 1177.64917..
#  torch.mean(F): 1177.60840..
#  Reg Proj: 0.02617..
#  Reg Latent: 0.01454..
#  Repulsive: 0.00008..
#  Memory: 58.88042..
#  Memory: 58.88042..
#  Output:
#  [[1481.385  1477.8292]
#  [ 803.4976  801.5712]
#  [2125.1113 2120.004 ]]
# ====================
# Epoch: 850/1000..
#  Training loss: 1166.22058..
#  torch.mean(F): 1165.75989..
#  Reg Proj: 0.44626..
#  Reg Latent: 0.01439..
#  Repulsive: 0.00005..
#  Memory: 58.28799..
#  Memory: 58.28799..
#  Output:
#  [[2211.0593  1893.859  ]
#  [1101.3123   943.27075]
#  [2995.4653  2565.8726 ]]
# ====================
# Epoch: 900/1000..
#  Training loss: 1143.19714..
#  torch.mean(F): 1142.72266..
#  Reg Proj: 0.46025..
#  Reg Latent: 0.01423..
#  Repulsive: 0.00006..
#  Memory: 57.13613..
#  Memory: 57.13613..
#  Output:
#  [[1936.6392 2057.1448]
#  [ 969.0752 1029.5659]
#  [2672.04   2837.7854]]
# ====================
# Epoch: 950/1000..
#  Training loss: 1146.83374..
#  torch.mean(F): 1146.76758..
#  Reg Proj: 0.05216..
#  Reg Latent: 0.01391..
#  Repulsive: 0.00007..
#  Memory: 57.33838..
#  Memory: 57.33838..
#  Output:
#  [[1729.212   1699.4097 ]
#  [ 873.0461   858.01654]
#  [2267.468   2228.314  ]]
# ====================
# Epoch: 1000/1000..
#  Training loss: 1122.38440..
#  torch.mean(F): 1122.22766..
#  Reg Proj: 0.14301..
#  Reg Latent: 0.01361..
#  Repulsive: 0.00007..
#  Memory: 56.11138..
#  Memory: 56.11138..
#  Output:
#  [[1833.9509 1813.4628]
#  [ 922.0281  911.7682]
#  [2463.5156 2435.8599]]
# ====================
# getUncertaintyArea
# Ouputs are [[1809.0835 1972.7566]
#  [ 876.7816  956.03  ]
#  [2417.8403 2636.7922]]
# scale is 5176
# Processing...
# flag is 641
# m is 260
# i is 900
# Labeled 0/260 points.
# Labeled all 260/260 points.
# Creating student for node 01 with 3 centroids.
# Device is: cpu
# ====================
# Training Student Model
# Acc:  0.15384615384615385
# Epoch:  0 Cost:  2561.267822265625
# Acc:  0.7346153846153847
# Epoch:  300 Cost:  70.2790298461914
# Acc:  0.7576923076923077
# Epoch:  600 Cost:  48.014625549316406
# Acc:  0.8730769230769231
# Epoch:  900 Cost:  38.02434539794922
# Acc:  0.8346153846153846
# Epoch:  1200 Cost:  38.48809814453125
# Acc:  0.8038461538461539
# Epoch:  1500 Cost:  34.11092758178711
# Acc:  0.8269230769230769
# Epoch:  1800 Cost:  35.28947067260742
# Acc:  0.6269230769230769
# Epoch:  2100 Cost:  85.86894226074219
# Acc:  0.8038461538461539
# Epoch:  2400 Cost:  47.38990020751953
# Acc:  0.8846153846153846
# Epoch:  2700 Cost:  29.917482376098633

# %%
# Report some tree stats.
leaves = ktree.get_leaves()
number_of_nodes = ktree.number_of_nodes

height = max([len(leaf.index) for leaf in leaves])
print(f"Tree height is {height}.")

leaf_sizes = [len(leaf.data) for leaf in leaves]
print(f"Created {len(leaves)} leaves with sizes")
print(leaf_sizes)
print(number_of_nodes)
# Out:
# Tree height is 3.
# Created 7 leaves with sizes
# [122, 162, 118, 129, 75, 120, 273]
# 10

# %%
import numpy as np
import matplotlib.pyplot as plt
mean_acc_per_layer = np.zeros(height)
times=0
while times < 4:
    # now lets create randomly N points in the space 0-300, 0-300
    n = 300
    random_p = torch.zeros(n, 2)
    x_lim = [min(data[:, 0]), max(data[:, 0])]
    y_lim = [min(data[:, 1]), max(data[:, 1])]


    for i in range(n):
        random_p[i] = torch.Tensor([np.random.randint(x_lim[0],x_lim[1]), np.random.randint(y_lim[0],y_lim[1])])
        
    infer_points = random_p.to(device)
    plt.scatter(infer_points[:,0], infer_points[:,1])

    correct_predictions_per_layer = np.zeros(height)
    accuracy_per_layer = np.zeros(height)

    qp = infer_points
    for i, query_point in enumerate(qp):
        preds_per_layer = ktree.query_verbose(query_point)["predictions per layer"]
        k_nearest_neighbors = ktree.root.query(query_point, k=1)

        for j, pred in enumerate(preds_per_layer):
            if any(np.array_equal(pred[0], k_nearest_neighbors[ki]) for ki in range(1)):
                correct_predictions_per_layer[j] += 1

    accuracy_per_layer = correct_predictions_per_layer / len(infer_points) * 100
    mean_acc_per_layer += accuracy_per_layer
    times += 1
    print(f"The percentage of correct predictions per layer is: ")
    print(accuracy_per_layer)

print(f"The mean percentage of correct predictions is: ")
print(mean_acc_per_layer/times)
# Out:
# The percentage of correct predictions per layer is:
# [88.         69.66666667 44.66666667]
# The percentage of correct predictions per layer is:
# [91.         71.33333333 47.33333333]
# The percentage of correct predictions per layer is:
# [91.33333333 70.         43.        ]
# The percentage of correct predictions per layer is:
# [89.66666667 66.33333333 40.66666667]
# The mean percentage of correct predictions is:
# [90.         69.33333333 43.91666667]

# %%
import numpy as np
import matplotlib.pyplot as plt
mean_acc_per_layer = np.zeros(height)
times=0
while times < 4:
    # now lets create randomly N points in the space 0-300, 0-300
    n = 300
    random_p = torch.zeros(n, 2)
    x_lim = [min(data[:, 0]), max(data[:, 0])]
    y_lim = [min(data[:, 1]), max(data[:, 1])]


    for i in range(n):
        random_p[i] = torch.Tensor([np.random.randint(x_lim[0],x_lim[1]), np.random.randint(y_lim[0],y_lim[1])])
        
    infer_points = random_p.to(device)
    plt.scatter(infer_points[:,0], infer_points[:,1])

    correct_predictions_per_layer = np.zeros(height)
    accuracy_per_layer = np.zeros(height)

    qp = infer_points
    for i, query_point in enumerate(qp):
        preds_per_layer = ktree.query_verbose(query_point)["predictions per layer"]
        k_nearest_neighbors = ktree.root.query(query_point, k=2)

        for j, pred in enumerate(preds_per_layer):
            if any(np.array_equal(pred[0], k_nearest_neighbors[ki]) for ki in range(2)):
                 correct_predictions_per_layer[j] += 1

    accuracy_per_layer = correct_predictions_per_layer / len(infer_points) * 100
    mean_acc_per_layer += accuracy_per_layer
    times += 1
    print(f"The percentage of correct predictions per layer is: ")
    print(accuracy_per_layer)

print(f"The mean percentage of correct predictions is: ")
print(mean_acc_per_layer/times)
# Out:
# The percentage of correct predictions per layer is:
# [94.         73.33333333 49.66666667]
# The percentage of correct predictions per layer is:
# [88.66666667 72.33333333 44.66666667]
# The percentage of correct predictions per layer is:
# [92.66666667 75.66666667 46.        ]
# The percentage of correct predictions per layer is:
# [90.66666667 67.66666667 37.33333333]
# The mean percentage of correct predictions is:
# [91.5        72.25       44.41666667]

# %%
import numpy as np
import matplotlib.pyplot as plt
mean_acc_per_layer = np.zeros(height)
times=0
while times < 4:
    # now lets create randomly N points in the space 0-300, 0-300
    n = 300
    random_p = torch.zeros(n, 2)
    x_lim = [min(data[:, 0]), max(data[:, 0])]
    y_lim = [min(data[:, 1]), max(data[:, 1])]


    for i in range(n):
        random_p[i] = torch.Tensor([np.random.randint(x_lim[0],x_lim[1]), np.random.randint(y_lim[0],y_lim[1])])
        
    infer_points = random_p.to(device)
    plt.scatter(infer_points[:,0], infer_points[:,1])

    correct_predictions_per_layer = np.zeros(height)
    accuracy_per_layer = np.zeros(height)

    qp = infer_points
    for i, query_point in enumerate(qp):
        preds_per_layer = ktree.query_verbose(query_point)["predictions per layer"]
        k_nearest_neighbors = ktree.root.query(query_point, k=5)

        for j, pred in enumerate(preds_per_layer):
            if any(np.array_equal(pred[0], k_nearest_neighbors[ki]) for ki in range(5)):
                 correct_predictions_per_layer[j] += 1

    accuracy_per_layer = correct_predictions_per_layer / len(infer_points) * 100
    mean_acc_per_layer += accuracy_per_layer
    times += 1
    print(f"The percentage of correct predictions per layer is: ")
    print(accuracy_per_layer)

print(f"The mean percentage of correct predictions is: ")
print(mean_acc_per_layer/times)
# Out:
# The percentage of correct predictions per layer is:
# [92.33333333 79.33333333 49.33333333]
# The percentage of correct predictions per layer is:
# [91.33333333 75.33333333 50.66666667]
# The percentage of correct predictions per layer is:
# [93.         77.33333333 53.66666667]
# The percentage of correct predictions per layer is:
# [93.66666667 76.         46.        ]
# The mean percentage of correct predictions is:
# [92.58333333 77.         49.91666667]

# %%
import numpy as np
import matplotlib.pyplot as plt
mean_acc_per_layer = np.zeros(height)
times=0
while times < 4:
    # now lets create randomly N points in the space 0-300, 0-300
    n = 300
    random_p = torch.zeros(n, 2)
    x_lim = [min(data[:, 0]), max(data[:, 0])]
    y_lim = [min(data[:, 1]), max(data[:, 1])]


    for i in range(n):
        random_p[i] = torch.Tensor([np.random.randint(x_lim[0],x_lim[1]), np.random.randint(y_lim[0],y_lim[1])])
        
    infer_points = random_p.to(device)
    plt.scatter(infer_points[:,0], infer_points[:,1])

    correct_predictions_per_layer = np.zeros(height)
    accuracy_per_layer = np.zeros(height)

    qp = infer_points
    for i, query_point in enumerate(qp):
        preds_per_layer = ktree.query_verbose(query_point)["predictions per layer"]
        k_nearest_neighbors = ktree.root.query(query_point, k=10)

        for j, pred in enumerate(preds_per_layer):
            if any(np.array_equal(pred[0], k_nearest_neighbors[ki]) for ki in range(10)):
                 correct_predictions_per_layer[j] += 1

    accuracy_per_layer = correct_predictions_per_layer / len(infer_points) * 100
    mean_acc_per_layer += accuracy_per_layer
    times += 1
    print(f"The percentage of correct predictions per layer is: ")
    print(accuracy_per_layer)

print(f"The mean percentage of correct predictions is: ")
print(mean_acc_per_layer/times)
# Out:
# The percentage of correct predictions per layer is:
# [92.33333333 78.66666667 53.33333333]
# The percentage of correct predictions per layer is:
# [95.66666667 82.         57.        ]
# The percentage of correct predictions per layer is:
# [96.33333333 82.33333333 54.        ]
# The percentage of correct predictions per layer is:
# [95.66666667 84.66666667 54.        ]
# The mean percentage of correct predictions is:
# [95.         81.91666667 54.58333333]

# %%
import numpy as np
import matplotlib.pyplot as plt
mean_acc_per_layer = np.zeros(height)
times=0
while times < 4:
    # now lets create randomly N points in the space 0-300, 0-300
    n = 300
    random_p = torch.zeros(n, 2)
    x_lim = [min(data[:, 0]), max(data[:, 0])]
    y_lim = [min(data[:, 1]), max(data[:, 1])]


    for i in range(n):
        random_p[i] = torch.Tensor([np.random.randint(x_lim[0],x_lim[1]), np.random.randint(y_lim[0],y_lim[1])])
        
    infer_points = random_p.to(device)
    plt.scatter(infer_points[:,0], infer_points[:,1])

    correct_predictions_per_layer = np.zeros(height)
    accuracy_per_layer = np.zeros(height)

    qp = infer_points
    for i, query_point in enumerate(qp):
        preds_per_layer = ktree.query_verbose(query_point)["predictions per layer"]
        k_nearest_neighbors = ktree.root.query(query_point, k=50)

        for j, pred in enumerate(preds_per_layer):
            if any(np.array_equal(pred[0], k_nearest_neighbors[ki]) for ki in range(50)):
                 correct_predictions_per_layer[j] += 1

    accuracy_per_layer = correct_predictions_per_layer / len(infer_points) * 100
    mean_acc_per_layer += accuracy_per_layer
    times += 1
    print(f"The percentage of correct predictions per layer is: ")
    print(accuracy_per_layer)

print(f"The mean percentage of correct predictions is: ")
print(mean_acc_per_layer/times)
# Out:
# The percentage of correct predictions per layer is:
# [97.66666667 96.         64.66666667]
# The percentage of correct predictions per layer is:
# [99.33333333 95.33333333 67.66666667]
# The percentage of correct predictions per layer is:
# [99.         95.33333333 64.33333333]
# The percentage of correct predictions per layer is:
# [99.         97.         68.66666667]
# The mean percentage of correct predictions is:
# [98.75       95.91666667 66.33333333]

# %%
import numpy as np
import matplotlib.pyplot as plt
mean_acc_per_layer = np.zeros(height)
times=0
while times < 4:
    # now lets create randomly N points in the space 0-300, 0-300
    n = 300
    random_p = torch.zeros(n, 2)
    x_lim = [min(data[:, 0]), max(data[:, 0])]
    y_lim = [min(data[:, 1]), max(data[:, 1])]


    for i in range(n):
        random_p[i] = torch.Tensor([np.random.randint(x_lim[0],x_lim[1]), np.random.randint(y_lim[0],y_lim[1])])
        
    infer_points = random_p.to(device)
    plt.scatter(infer_points[:,0], infer_points[:,1])

    correct_predictions_per_layer = np.zeros(height)
    accuracy_per_layer = np.zeros(height)

    qp = infer_points
    for i, query_point in enumerate(qp):
        preds_per_layer = ktree.query_verbose(query_point)["predictions per layer"]
        k_nearest_neighbors = ktree.root.query(query_point, k=100)

        for j, pred in enumerate(preds_per_layer):
            if any(np.array_equal(pred[0], k_nearest_neighbors[ki]) for ki in range(100)):
                 correct_predictions_per_layer[j] += 1

    accuracy_per_layer = correct_predictions_per_layer / len(infer_points) * 100
    mean_acc_per_layer += accuracy_per_layer
    times += 1
    print(f"The percentage of correct predictions per layer is: ")
    print(accuracy_per_layer)

print(f"The mean percentage of correct predictions is: ")
print(mean_acc_per_layer/times)
# Out:
# The percentage of correct predictions per layer is:
# [100.          99.          69.33333333]
# The percentage of correct predictions per layer is:
# [100.         100.          70.66666667]
# The percentage of correct predictions per layer is:
# [100.         100.          69.33333333]
# The percentage of correct predictions per layer is:
# [100.          99.66666667  68.66666667]
# The mean percentage of correct predictions is:
# [100.          99.66666667  69.5       ]
