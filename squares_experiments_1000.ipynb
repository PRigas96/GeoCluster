# %%
from itertools import product, combinations
import matplotlib.pyplot as plt
import numpy as np
from src import k_tree
from src.utils import data as dt
import torch
from src.k_tree import Ktree
from src.utils.data import loadData, loadData_3d
from src.metrics import Linf_simple
from src import ellipses as el

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
device = "cpu"
data, _ = loadData(1000)


#data = rects
learning_rate = 5e-3 # 1e-2, 5e-3
k = 3
teacher_args = {
    "optimizer_lr": learning_rate,
    "epochs": 1000, # 300
    "times": 20,
    "alpha": 0.1, #  projection loss 0.1
    "beta": 0.1, # latent loss 0.1
    "gamma": 0.01, # repulsive loss 0.01 - dioxnei makria ta kentra to ena apo to allo - fainetai sto log an einai megalo
    #"gamma": 0.4, # repulsive loss 0.01
    "delta": 0.05, # fuzzy scale 0.01
    "f_clk": 10, # 20
    "scale": 1, # fuzzy scale 
    "scale_flag": False,
    "number_of_centroids": k,
    "latent_size": 200,
    "encoder_activation": False,
    "encoder_depth": 5,
    "predictor_width": 5*100,
    "predictor_depth": 5,
}
n = 30
un_args = {
    "N": n,
    "M": n**2-1, # 10000 - 1
    "epsilon": 0.15 # here a layer value should be somehow included. As layers get denser  epilson should be smaller
}
student_args = {
    "optimizer_lr": 5e-3,
    "epochs": 3000, # 30000, 3000
    "width": 200,
    "depth": 5,
}

# thresshold = 0.1 * len(data)
threshold = k * 100
metric = Linf_simple
ktree = Ktree(threshold, data, metric,teacher_args, un_args, student_args,device=device)
ktree.create_tree(plot=True)
# Out:
# Loading data...
# Data loaded.
#
# ====================
# Creating student for node 0 that has 999 data, which is more than the threshold 300.
# Bounding box for node 0: [[3, 7004], [11, 7006]]
# Creating teacher for node 0 with 3 centroids.
# ====================
# Training Teacher Model
# /home/geoten/Projects/GeoCluster/src/geometry.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   rotation = torch.tensor(rotation)
# ====================
# Epoch: 50/1000..
#  Training loss: 1940.18494..
#  torch.mean(F): 1899.35742..
#  Reg Proj: 40.81514..
#  Reg Latent: 0.01228..
#  Repulsive: 0.00003..
#  Memory: 94.96787..
#  Memory: 94.96787..
#  Output:
#  [[1817.9166 3141.325 ]
#  [2657.1042 4590.913 ]
#  [4172.242  7209.0757]]
# ====================
# Epoch: 100/1000..
#  Training loss: 1629.87280..
#  torch.mean(F): 1629.86157..
#  Reg Proj: 0.00000..
#  Reg Latent: 0.01127..
#  Repulsive: 0.00003..
#  Memory: 81.49308..
#  Memory: 81.49308..
#  Output:
#  [[1918.7745 1906.7133]
#  [3212.0034 3191.5571]
#  [4886.756  4855.7983]]
# ====================
# Epoch: 150/1000..
#  Training loss: 1619.05859..
#  torch.mean(F): 1619.04724..
#  Reg Proj: 0.00000..
#  Reg Latent: 0.01141..
#  Repulsive: 0.00003..
#  Memory: 80.95236..
#  Memory: 80.95236..
#  Output:
#  [[1929.5747 1992.9645]
#  [3419.7693 3531.852 ]
#  [4917.602  5078.934 ]]
# ====================
# Epoch: 200/1000..
#  Training loss: 1623.18567..
#  torch.mean(F): 1623.17419..
#  Reg Proj: 0.00000..
#  Reg Latent: 0.01152..
#  Repulsive: 0.00003..
#  Memory: 81.15871..
#  Memory: 81.15871..
#  Output:
#  [[2062.1038 2122.8423]
#  [3640.2534 3747.4954]
#  [5211.2905 5364.824 ]]
# ====================
# Epoch: 250/1000..
#  Training loss: 1623.13647..
#  torch.mean(F): 1623.12341..
#  Reg Proj: 0.00000..
#  Reg Latent: 0.01302..
#  Repulsive: 0.00003..
#  Memory: 81.15617..
#  Memory: 81.15617..
#  Output:
#  [[2055.0745 1975.6661]
#  [3639.9429 3500.3306]
#  [5207.379  5007.1714]]
# ====================
# Epoch: 300/1000..
#  Training loss: 1619.74561..
#  torch.mean(F): 1619.73218..
#  Reg Proj: 0.00000..
#  Reg Latent: 0.01342..
#  Repulsive: 0.00003..
#  Memory: 80.98661..
#  Memory: 80.98661..
#  Output:
#  [[1964.8374 1998.2457]
#  [3596.049  3656.6738]
#  [5053.8784 5139.314 ]]
# ====================
# Epoch: 350/1000..
#  Training loss: 1620.22925..
#  torch.mean(F): 1620.21655..
#  Reg Proj: 0.00000..
#  Reg Latent: 0.01273..
#  Repulsive: 0.00003..
#  Memory: 81.01083..
#  Memory: 81.01083..
#  Output:
#  [[2002.7145 1987.9277]
#  [3518.6917 3492.7102]
#  [5083.017  5045.489 ]]
# ====================
# Epoch: 400/1000..
#  Training loss: 1621.01001..
#  torch.mean(F): 1620.99805..
#  Reg Proj: 0.00000..
#  Reg Latent: 0.01194..
#  Repulsive: 0.00003..
#  Memory: 81.04990..
#  Memory: 81.04990..
#  Output:
#  [[1889.9937 1903.0142]
#  [3371.4539 3394.2385]
#  [4802.173  4834.7993]]
# ====================
# Epoch: 450/1000..
#  Training loss: 1636.15466..
#  torch.mean(F): 1636.14185..
#  Reg Proj: 0.00000..
#  Reg Latent: 0.01277..
#  Repulsive: 0.00003..
#  Memory: 81.80709..
#  Memory: 81.80709..
#  Output:
#  [[2039.7516 2210.6863]
#  [3603.9895 3906.274 ]
#  [5253.062  5693.573 ]]
# ====================
# Epoch: 500/1000..
#  Training loss: 1620.15283..
#  torch.mean(F): 1620.14087..
#  Reg Proj: 0.00000..
#  Reg Latent: 0.01201..
#  Repulsive: 0.00003..
#  Memory: 81.00704..
#  Memory: 81.00704..
#  Output:
#  [[1867.9005 1901.7062]
#  [3386.4885 3447.7185]
#  [4812.8374 4899.9023]]
# ====================
# Epoch: 550/1000..
#  Training loss: 1618.97693..
#  torch.mean(F): 1618.96301..
#  Reg Proj: 0.00000..
#  Reg Latent: 0.01394..
#  Repulsive: 0.00003..
#  Memory: 80.94815..
#  Memory: 80.94815..
#  Output:
#  [[1881.4679 1952.0613]
#  [3443.0862 3572.2004]
#  [4915.9424 5100.3076]]
# ====================
# Epoch: 600/1000..
#  Training loss: 1632.42065..
#  torch.mean(F): 1632.40576..
#  Reg Proj: 0.00000..
#  Reg Latent: 0.01484..
#  Repulsive: 0.00003..
#  Memory: 81.62029..
#  Memory: 81.62029..
#  Output:
#  [[2039.8422 2180.6006]
#  [3601.9255 3850.5264]
#  [5260.23   5623.272 ]]
# ====================
# Epoch: 650/1000..
#  Training loss: 1620.93933..
#  torch.mean(F): 1620.92224..
#  Reg Proj: 0.00000..
#  Reg Latent: 0.01712..
#  Repulsive: 0.00003..
#  Memory: 81.04611..
#  Memory: 81.04611..
#  Output:
#  [[1990.1937 1947.1598]
#  [3538.3467 3461.7083]
#  [5088.667  4978.49  ]]
# ====================
# Epoch: 700/1000..
#  Training loss: 1633.59399..
#  torch.mean(F): 1633.57788..
#  Reg Proj: 0.00000..
#  Reg Latent: 0.01609..
#  Repulsive: 0.00004..
#  Memory: 81.67889..
#  Memory: 81.67889..
#  Output:
#  [[1799.4823 1801.1427]
#  [3140.5771 3143.4858]
#  [4614.4775 4618.7417]]
# ====================
# Epoch: 750/1000..
#  Training loss: 1646.57751..
#  torch.mean(F): 1646.56262..
#  Reg Proj: 0.00000..
#  Reg Latent: 0.01494..
#  Repulsive: 0.00003..
#  Memory: 82.32813..
#  Memory: 82.32813..
#  Output:
#  [[2127.7927 2137.597 ]
#  [3930.396  3948.4963]
#  [5540.9805 5566.5005]]
# ====================
# Epoch: 800/1000..
#  Training loss: 1619.38135..
#  torch.mean(F): 1619.36694..
#  Reg Proj: 0.00000..
#  Reg Latent: 0.01444..
#  Repulsive: 0.00003..
#  Memory: 80.96835..
#  Memory: 80.96835..
#  Output:
#  [[1962.5217 1972.1769]
#  [3520.2156 3537.592 ]
#  [5103.787  5128.963 ]]
# ====================
# Epoch: 850/1000..
#  Training loss: 1620.63354..
#  torch.mean(F): 1620.61768..
#  Reg Proj: 0.00000..
#  Reg Latent: 0.01591..
#  Repulsive: 0.00003..
#  Memory: 81.03088..
#  Memory: 81.03088..
#  Output:
#  [[1862.3942 1892.719 ]
#  [3322.9678 3377.1462]
#  [4820.1846 4898.74  ]]
# ====================
# Epoch: 900/1000..
#  Training loss: 1624.31372..
#  torch.mean(F): 1624.29883..
#  Reg Proj: 0.00000..
#  Reg Latent: 0.01486..
#  Repulsive: 0.00003..
#  Memory: 81.21494..
#  Memory: 81.21494..
#  Output:
#  [[2059.96   1964.2548]
#  [3610.222  3442.2834]
#  [5179.9326 4939.0254]]
# ====================
# Epoch: 950/1000..
#  Training loss: 1631.13403..
#  torch.mean(F): 1631.11853..
#  Reg Proj: 0.00000..
#  Reg Latent: 0.01545..
#  Repulsive: 0.00003..
#  Memory: 81.55593..
#  Memory: 81.55593..
#  Output:
#  [[1833.5343 1768.3391]
#  [3332.437  3214.0525]
#  [4754.8447 4585.9023]]
# ====================
# Epoch: 1000/1000..
#  Training loss: 1619.75867..
#  torch.mean(F): 1619.74390..
#  Reg Proj: 0.00000..
#  Reg Latent: 0.01479..
#  Repulsive: 0.00003..
#  Memory: 80.98719..
#  Memory: 80.98719..
#  Output:
#  [[1905.0287 1959.7007]
#  [3389.8674 3486.936 ]
#  [4801.8623 4939.467 ]]
# ====================
# getUncertaintyArea
# Ouputs are [[1956.8597 2072.7368]
#  [3390.394  3547.2837]
#  [5036.01   4820.734 ]]
# scale is 7001
# Processing...
# flag is 751
# m is 150
# i is 900
# Labeled 0/150 points.
# Labeled all 150/150 points.
# Creating student for node 0 with 3 centroids.
# Device is: cpu
# ====================
# Training Student Model
# Acc:  0.5533333333333333
# Epoch:  0 Cost:  4567.30712890625
# Acc:  0.66
# Epoch:  300 Cost:  66.81126403808594
# Acc:  0.8133333333333334
# Epoch:  600 Cost:  50.42094039916992
# Acc:  0.6266666666666667
# Epoch:  900 Cost:  75.9039077758789
# Acc:  0.7666666666666667
# Epoch:  1200 Cost:  57.85045623779297
# Acc:  0.8
# Epoch:  1500 Cost:  50.27835464477539
# Acc:  0.6666666666666666
# Epoch:  1800 Cost:  54.62322235107422
# Acc:  0.5466666666666666
# Epoch:  2100 Cost:  86.82157135009766
# Acc:  0.7466666666666667
# Epoch:  2400 Cost:  63.331031799316406
# Acc:  0.8066666666666666
# Epoch:  2700 Cost:  57.770751953125
# ====================
# Creating student for node 00 that has 311 data, which is more than the threshold 300.
# Bounding box for node 00: [[3, 5179], [21, 5192]]
# Creating teacher for node 00 with 3 centroids.
# ====================
# Training Teacher Model
# ====================
# Epoch: 50/1000..
#  Training loss: 1270.14709..
#  torch.mean(F): 1268.71692..
#  Reg Proj: 1.37101..
#  Reg Latent: 0.05924..
#  Repulsive: 0.00004..
#  Memory: 63.43585..
#  Memory: 63.43585..
#  Output:
#  [[2136.8044 2857.0706]
#  [ 713.0708  953.4377]
#  [2933.8157 3922.4788]]
# ====================
# Epoch: 100/1000..
#  Training loss: 1228.94458..
#  torch.mean(F): 1226.88135..
#  Reg Proj: 2.01598..
#  Reg Latent: 0.04727..
#  Repulsive: 0.00003..
#  Memory: 61.34407..
#  Memory: 61.34407..
#  Output:
#  [[1705.6537 2578.334 ]
#  [ 911.6636 1378.189 ]
#  [3009.3486 4549.541 ]]
# ====================
# Epoch: 150/1000..
#  Training loss: 1199.76099..
#  torch.mean(F): 1199.38928..
#  Reg Proj: 0.32656..
#  Reg Latent: 0.04503..
#  Repulsive: 0.00007..
#  Memory: 59.96946..
#  Memory: 59.96946..
#  Output:
#  [[1750.4637 1906.7059]
#  [1227.4628 1336.9836]
#  [2759.966  3006.2607]]
# ====================
# Epoch: 200/1000..
#  Training loss: 1163.31958..
#  torch.mean(F): 1162.85901..
#  Reg Proj: 0.41808..
#  Reg Latent: 0.04245..
#  Repulsive: 0.00005..
#  Memory: 58.14295..
#  Memory: 58.14295..
#  Output:
#  [[2026.9413 1999.3834]
#  [1037.2982 1023.3244]
#  [2875.4521 2836.1182]]
# ====================
# Epoch: 250/1000..
#  Training loss: 1128.71973..
#  torch.mean(F): 1128.58765..
#  Reg Proj: 0.09035..
#  Reg Latent: 0.04166..
#  Repulsive: 0.00007..
#  Memory: 56.42938..
#  Memory: 56.42938..
#  Output:
#  [[1978.8455  1934.3346 ]
#  [ 646.88135  632.42194]
#  [2460.3115  2404.9666 ]]
# ====================
# Epoch: 300/1000..
#  Training loss: 1109.80994..
#  torch.mean(F): 1109.70935..
#  Reg Proj: 0.05926..
#  Reg Latent: 0.04128..
#  Repulsive: 0.00007..
#  Memory: 55.48547..
#  Memory: 55.48547..
#  Output:
#  [[1753.882   1705.2274 ]
#  [ 869.2305   845.15314]
#  [2352.8545  2287.5874 ]]
# ====================
# Epoch: 350/1000..
#  Training loss: 1140.04089..
#  torch.mean(F): 1139.96423..
#  Reg Proj: 0.03475..
#  Reg Latent: 0.04171..
#  Repulsive: 0.00008..
#  Memory: 56.99821..
#  Memory: 56.99821..
#  Output:
#  [[1614.0403  1595.7877 ]
#  [ 836.9008   827.43494]
#  [2153.2974  2128.9492 ]]
# ====================
# Epoch: 400/1000..
#  Training loss: 1115.38123..
#  torch.mean(F): 1115.21960..
#  Reg Proj: 0.11977..
#  Reg Latent: 0.04185..
#  Repulsive: 0.00006..
#  Memory: 55.76098..
#  Memory: 55.76098..
#  Output:
#  [[1669.1143  1669.5784 ]
#  [ 793.73645  794.03424]
#  [2538.584   2539.2852 ]]
# ====================
# Epoch: 450/1000..
#  Training loss: 1120.14270..
#  torch.mean(F): 1120.06482..
#  Reg Proj: 0.03681..
#  Reg Latent: 0.04087..
#  Repulsive: 0.00007..
#  Memory: 56.00324..
#  Memory: 56.00324..
#  Output:
#  [[1628.1403  1715.6393 ]
#  [ 844.2282   889.54895]
#  [2167.098   2283.5757 ]]
# ====================
# Epoch: 500/1000..
#  Training loss: 1100.30518..
#  torch.mean(F): 1100.21423..
#  Reg Proj: 0.05047..
#  Reg Latent: 0.04041..
#  Repulsive: 0.00006..
#  Memory: 55.01071..
#  Memory: 55.01071..
#  Output:
#  [[1665.0221  1874.1993 ]
#  [ 826.67175  930.6872 ]
#  [2247.1326  2529.3606 ]]
# ====================
# Epoch: 550/1000..
#  Training loss: 1120.49548..
#  torch.mean(F): 1120.21570..
#  Reg Proj: 0.24019..
#  Reg Latent: 0.03954..
#  Repulsive: 0.00006..
#  Memory: 56.01078..
#  Memory: 56.01078..
#  Output:
#  [[2036.2982 1868.0231]
#  [1001.3278  918.1094]
#  [2738.6428 2512.6567]]
# ====================
# Epoch: 600/1000..
#  Training loss: 1105.71521..
#  torch.mean(F): 1105.56921..
#  Reg Proj: 0.10636..
#  Reg Latent: 0.03966..
#  Repulsive: 0.00006..
#  Memory: 55.27846..
#  Memory: 55.27846..
#  Output:
#  [[1803.3175  2050.4912 ]
#  [ 913.61694 1038.9001 ]
#  [2438.9197  2773.1575 ]]
# ====================
# Epoch: 650/1000..
#  Training loss: 1119.81299..
#  torch.mean(F): 1119.73682..
#  Reg Proj: 0.03660..
#  Reg Latent: 0.03944..
#  Repulsive: 0.00007..
#  Memory: 55.98684..
#  Memory: 55.98684..
#  Output:
#  [[1617.0645 1720.8083]
#  [ 806.8789  858.4059]
#  [2156.568  2295.1843]]
# ====================
# Epoch: 700/1000..
#  Training loss: 1097.21875..
#  torch.mean(F): 1097.09631..
#  Reg Proj: 0.08393..
#  Reg Latent: 0.03831..
#  Repulsive: 0.00007..
#  Memory: 54.85482..
#  Memory: 54.85482..
#  Output:
#  [[1833.5951  1947.6273 ]
#  [ 940.62305  999.0724 ]
#  [2430.2576  2581.453  ]]
# ====================
# Epoch: 750/1000..
#  Training loss: 1132.84863..
#  torch.mean(F): 1132.77283..
#  Reg Proj: 0.03680..
#  Reg Latent: 0.03890..
#  Repulsive: 0.00008..
#  Memory: 56.63864..
#  Memory: 56.63864..
#  Output:
#  [[1648.8091  1642.2279 ]
#  [ 797.82465  795.0695 ]
#  [2176.8833  2167.6133 ]]
# ====================
# Epoch: 800/1000..
#  Training loss: 1114.80774..
#  torch.mean(F): 1114.72900..
#  Reg Proj: 0.04050..
#  Reg Latent: 0.03806..
#  Repulsive: 0.00007..
#  Memory: 55.73645..
#  Memory: 55.73645..
#  Output:
#  [[1631.0065 1705.9705]
#  [ 824.7339  862.6165]
#  [2210.4907 2312.1262]]
# ====================
# Epoch: 850/1000..
#  Training loss: 1101.45374..
#  torch.mean(F): 1101.36682..
#  Reg Proj: 0.04846..
#  Reg Latent: 0.03832..
#  Repulsive: 0.00006..
#  Memory: 55.06834..
#  Memory: 55.06834..
#  Output:
#  [[1659.0409 1918.9292]
#  [ 815.8263  944.3048]
#  [2201.3306 2544.8618]]
# ====================
# Epoch: 900/1000..
#  Training loss: 1118.62952..
#  torch.mean(F): 1118.54810..
#  Reg Proj: 0.03998..
#  Reg Latent: 0.04122..
#  Repulsive: 0.00007..
#  Memory: 55.92740..
#  Memory: 55.92740..
#  Output:
#  [[1647.8563  1687.6809 ]
#  [ 815.26874  835.11   ]
#  [2213.725   2266.9434 ]]
# ====================
# Epoch: 950/1000..
#  Training loss: 1138.47351..
#  torch.mean(F): 1138.40088..
#  Reg Proj: 0.03200..
#  Reg Latent: 0.04052..
#  Repulsive: 0.00008..
#  Memory: 56.92004..
#  Memory: 56.92004..
#  Output:
#  [[1571.3281 1628.2472]
#  [ 822.8314  852.6271]
#  [2099.0251 2175.078 ]]
# ====================
# Epoch: 1000/1000..
#  Training loss: 1112.00256..
#  torch.mean(F): 1111.87183..
#  Reg Proj: 0.09359..
#  Reg Latent: 0.03703..
#  Repulsive: 0.00006..
#  Memory: 55.59359..
#  Memory: 55.59359..
#  Output:
#  [[1886.593  1694.4232]
#  [ 939.1308  842.5641]
#  [2527.6228 2272.4653]]
# ====================
# getUncertaintyArea
# Ouputs are [[1832.7759  1867.5248 ]
#  [ 819.87823 1152.0077 ]
#  [2345.443   2630.4924 ]]
# scale is 5176
# Processing...
# flag is 630
# m is 271
# i is 900
# Labeled 0/271 points.
# Labeled all 271/271 points.
# Creating student for node 00 with 3 centroids.
# Device is: cpu
# ====================
# Training Student Model
# Acc:  0.4317343173431734
# Epoch:  0 Cost:  588.1087646484375
# Acc:  0.6752767527675276
# Epoch:  300 Cost:  67.92170715332031
# Acc:  0.8191881918819188
# Epoch:  600 Cost:  46.776973724365234
# Acc:  0.6937269372693727
# Epoch:  900 Cost:  76.4280776977539
# Acc:  0.8339483394833949
# Epoch:  1200 Cost:  43.77873611450195
# Acc:  0.9188191881918819
# Epoch:  1500 Cost:  27.361995697021484
# Acc:  0.9298892988929889
# Epoch:  1800 Cost:  20.874019622802734
# Acc:  0.955719557195572
# Epoch:  2100 Cost:  19.34857749938965
# Acc:  0.9077490774907749
# Epoch:  2400 Cost:  18.93576431274414
# Acc:  1.0
# Epoch:  2700 Cost:  11.735210418701172
# ====================
# Creating student for node 01 that has 393 data, which is more than the threshold 300.
# Bounding box for node 01: [[71, 6962], [11, 7001]]
# Creating teacher for node 01 with 3 centroids.
# ====================
# Training Teacher Model
# ====================
# Epoch: 50/1000..
#  Training loss: 1901.89270..
#  torch.mean(F): 1893.59729..
#  Reg Proj: 8.07969..
#  Reg Latent: 0.21555..
#  Repulsive: 0.00011..
#  Memory: 94.67986..
#  Memory: 94.67986..
#  Output:
#  [[3033.249    3821.9539  ]
#  [  48.128017   60.71657 ]
#  [-107.98162  -136.04445 ]]
# ====================
# Epoch: 100/1000..
#  Training loss: 2621.73145..
#  torch.mean(F): 2619.20337..
#  Reg Proj: 2.26726..
#  Reg Latent: 0.26085..
#  Repulsive: 0.00003..
#  Memory: 130.96017..
#  Memory: 130.96017..
#  Output:
#  [[5295.4927  3308.6604 ]
#  [ 349.8263   218.85643]
#  [1233.7443   770.945  ]]
# ====================
# Epoch: 150/1000..
#  Training loss: 1914.59106..
#  torch.mean(F): 1913.29626..
#  Reg Proj: 1.04914..
#  Reg Latent: 0.24554..
#  Repulsive: 0.00009..
#  Memory: 95.66481..
#  Memory: 95.66481..
#  Output:
#  [[3660.8066  3036.2312 ]
#  [ 353.31686  293.04752]
#  [3389.3625  2811.105  ]]
# ====================
# Epoch: 200/1000..
#  Training loss: 1787.19470..
#  torch.mean(F): 1785.83557..
#  Reg Proj: 1.11497..
#  Reg Latent: 0.24418..
#  Repulsive: 0.00006..
#  Memory: 89.29178..
#  Memory: 89.29178..
#  Output:
#  [[3825.257   4014.786  ]
#  [ 447.55652  469.6466 ]
#  [3412.4712  3581.5837 ]]
# ====================
# Epoch: 250/1000..
#  Training loss: 1772.17688..
#  torch.mean(F): 1770.77991..
#  Reg Proj: 1.14649..
#  Reg Latent: 0.25046..
#  Repulsive: 0.00004..
#  Memory: 88.53900..
#  Memory: 88.53900..
#  Output:
#  [[3561.1    3623.0884]
#  [ 374.2616  380.742 ]
#  [2882.1633 2932.3435]]
# ====================
# Epoch: 300/1000..
#  Training loss: 1757.04224..
#  torch.mean(F): 1755.65979..
#  Reg Proj: 1.13778..
#  Reg Latent: 0.24463..
#  Repulsive: 0.00004..
#  Memory: 87.78299..
#  Memory: 87.78299..
#  Output:
#  [[3997.8606  3975.533  ]
#  [ 397.67825  395.321  ]
#  [3326.5203  3307.9724 ]]
# ====================
# Epoch: 350/1000..
#  Training loss: 1740.29858..
#  torch.mean(F): 1738.95081..
#  Reg Proj: 1.11060..
#  Reg Latent: 0.23712..
#  Repulsive: 0.00004..
#  Memory: 86.94754..
#  Memory: 86.94754..
#  Output:
#  [[3705.3833  4401.338  ]
#  [ 334.2547   396.80392]
#  [3038.7324  3609.5107 ]]
# ====================
# Epoch: 400/1000..
#  Training loss: 1754.45349..
#  torch.mean(F): 1753.11206..
#  Reg Proj: 1.10633..
#  Reg Latent: 0.23509..
#  Repulsive: 0.00004..
#  Memory: 87.65560..
#  Memory: 87.65560..
#  Output:
#  [[3958.7795  3748.772  ]
#  [ 313.59427  297.1451 ]
#  [3250.225   3077.7585 ]]
# ====================
# Epoch: 450/1000..
#  Training loss: 1730.65161..
#  torch.mean(F): 1729.34985..
#  Reg Proj: 1.06594..
#  Reg Latent: 0.23587..
#  Repulsive: 0.00004..
#  Memory: 86.46749..
#  Memory: 86.46749..
#  Output:
#  [[3738.6943  4184.7563 ]
#  [ 246.66988  276.14627]
#  [3056.0781  3420.6812 ]]
# ====================
# Epoch: 500/1000..
#  Training loss: 1829.59131..
#  torch.mean(F): 1828.31726..
#  Reg Proj: 1.03896..
#  Reg Latent: 0.23506..
#  Repulsive: 0.00005..
#  Memory: 91.41586..
#  Memory: 91.41586..
#  Output:
#  [[3677.6858  3283.3345 ]
#  [ 227.06172  203.04851]
#  [3122.2024  2787.3625 ]]
# ====================
# Epoch: 550/1000..
#  Training loss: 1890.48010..
#  torch.mean(F): 1888.90967..
#  Reg Proj: 1.35234..
#  Reg Latent: 0.21810..
#  Repulsive: 0.00003..
#  Memory: 94.44548..
#  Memory: 94.44548..
#  Output:
#  [[4692.5903  4163.0635 ]
#  [ 229.27892  203.21274]
#  [3686.9153  3270.9187 ]]
# ====================
# Epoch: 600/1000..
#  Training loss: 1929.79126..
#  torch.mean(F): 1927.61694..
#  Reg Proj: 1.97662..
#  Reg Latent: 0.19777..
#  Repulsive: 0.00002..
#  Memory: 96.38085..
#  Memory: 96.38085..
#  Output:
#  [[5334.1226  4981.747  ]
#  [ 253.31197  236.52974]
#  [3544.2146  3310.0994 ]]
# ====================
# Epoch: 650/1000..
#  Training loss: 1773.40234..
#  torch.mean(F): 1772.09656..
#  Reg Proj: 1.11777..
#  Reg Latent: 0.18797..
#  Repulsive: 0.00003..
#  Memory: 88.60483..
#  Memory: 88.60483..
#  Output:
#  [[4151.2627  4122.61   ]
#  [ 156.68936  155.57909]
#  [3282.8884  3260.2402 ]]
# ====================
# Epoch: 700/1000..
#  Training loss: 1724.02075..
#  torch.mean(F): 1722.79639..
#  Reg Proj: 1.03004..
#  Reg Latent: 0.19431..
#  Repulsive: 0.00004..
#  Memory: 86.13982..
#  Memory: 86.13982..
#  Output:
#  [[3626.6807  4179.712  ]
#  [ 129.02235  148.58151]
#  [2955.8416  3406.5852 ]]
# ====================
# Epoch: 750/1000..
#  Training loss: 1778.66919..
#  torch.mean(F): 1777.38293..
#  Reg Proj: 1.08900..
#  Reg Latent: 0.19731..
#  Repulsive: 0.00004..
#  Memory: 88.86915..
#  Memory: 88.86915..
#  Output:
#  [[4099.3584  3625.748  ]
#  [ 271.8676   240.34406]
#  [3391.7856  2999.9607 ]]
# ====================
# Epoch: 800/1000..
#  Training loss: 1765.91492..
#  torch.mean(F): 1764.66760..
#  Reg Proj: 1.05271..
#  Reg Latent: 0.19456..
#  Repulsive: 0.00004..
#  Memory: 88.23338..
#  Memory: 88.23338..
#  Output:
#  [[3721.689   3583.294  ]
#  [ 194.80727  187.63513]
#  [3033.7295  2920.9072 ]]
# ====================
# Epoch: 850/1000..
#  Training loss: 1860.08594..
#  torch.mean(F): 1858.59192..
#  Reg Proj: 1.30322..
#  Reg Latent: 0.19080..
#  Repulsive: 0.00003..
#  Memory: 92.92960..
#  Memory: 92.92960..
#  Output:
#  [[4468.246   4185.0557 ]
#  [ 226.77971  212.36656]
#  [3648.6025  3417.378  ]]
# ====================
# Epoch: 900/1000..
#  Training loss: 1738.27295..
#  torch.mean(F): 1737.04785..
#  Reg Proj: 1.03463..
#  Reg Latent: 0.19046..
#  Repulsive: 0.00004..
#  Memory: 86.85239..
#  Memory: 86.85239..
#  Output:
#  [[3729.5056  3768.9556 ]
#  [ 148.38641  149.89899]
#  [3048.3464  3080.6062 ]]
# ====================
# Epoch: 950/1000..
#  Training loss: 1735.58484..
#  torch.mean(F): 1734.35754..
#  Reg Proj: 1.03630..
#  Reg Latent: 0.19100..
#  Repulsive: 0.00004..
#  Memory: 86.71788..
#  Memory: 86.71788..
#  Output:
#  [[3830.1038  3921.8577 ]
#  [ 129.87883  132.95485]
#  [3097.3906  3171.5964 ]]
# ====================
# Epoch: 1000/1000..
#  Training loss: 1738.76709..
#  torch.mean(F): 1737.50635..
#  Reg Proj: 1.07272..
#  Reg Latent: 0.18797..
#  Repulsive: 0.00004..
#  Memory: 86.87532..
#  Memory: 86.87532..
#  Output:
#  [[3839.3677  3840.0303 ]
#  [ 272.33185  272.37903]
#  [3144.6934  3145.234  ]]
# ====================
# getUncertaintyArea
# Ouputs are [[3459.3284 4143.119 ]
#  [2858.8755 3424.0586]]
# scale is 6990
# Processing...
# flag is 777
# m is 124
# i is 900
# Labeled 0/124 points.
# Labeled all 124/124 points.
# Creating student for node 01 with 2 centroids.
# Device is: cpu
# ====================
# Training Student Model
# Acc:  0.49193548387096775
# Epoch:  0 Cost:  3298.54052734375
# Acc:  0.6290322580645161
# Epoch:  300 Cost:  59.64816665649414
# Acc:  0.75
# Epoch:  600 Cost:  53.81903076171875
# Acc:  0.782258064516129
# Epoch:  900 Cost:  48.01304626464844
# Acc:  0.7983870967741935
# Epoch:  1200 Cost:  47.1700325012207
# Acc:  0.8387096774193549
# Epoch:  1500 Cost:  37.831504821777344
# Acc:  0.8709677419354839
# Epoch:  1800 Cost:  32.32065963745117
# Acc:  0.5241935483870968
# Epoch:  2100 Cost:  69.10845184326172
# Acc:  0.5080645161290323
# Epoch:  2400 Cost:  69.30171203613281
# Acc:  0.5080645161290323
# Epoch:  2700 Cost:  69.30171203613281

# %%
# Report some tree stats.
leaves = ktree.get_leaves()
number_of_nodes = ktree.number_of_nodes

height = max([len(leaf.index) for leaf in leaves])
print(f"Tree height is {height}.")

leaf_sizes = [len(leaf.data) for leaf in leaves]
print(f"Created {len(leaves)} leaves with sizes")
print(leaf_sizes)
print(number_of_nodes)
# Out:
# Tree height is 3.
# Created 7 leaves with sizes
# [122, 162, 118, 129, 75, 120, 273]
# 10

# %%
from src.utils import accuracy as acc

k = [1,2,5,10,100,500,1000]

for different_k in k:
    acc.random_queries(ktree, k = different_k)
    acc.serialised_queries(ktree, k = different_k)
# Out:
# The number of queries per layer are:
# [300. 181.]
# The percentage of correct predictions per layer is:
# [87.         79.33333333]
# The number of queries per layer are:
# [300. 174.]
# The percentage of correct predictions per layer is:
# [86. 81.]
# The number of queries per layer are:
# [300. 182.]
# The percentage of correct predictions per layer is:
# [85.66666667 79.        ]
# The number of queries per layer are:
# [300. 185.]
# The percentage of correct predictions per layer is:
# [88.         77.33333333]
# The mean percentage of correct predictions per layer is:
# [86.66666667 79.16666667]
# The number of queries per layer are:
# [484. 292.]
# The percentage of correct predictions per layer is:
# [85.8 77.2]
# The number of queries per layer are:
# [300. 189.]
# The percentage of correct predictions per layer is:
# [89.66666667 83.        ]
# The number of queries per layer are:
# [300. 182.]
# The percentage of correct predictions per layer is:
# [88.66666667 84.66666667]
# The number of queries per layer are:
# [300. 187.]
# The percentage of correct predictions per layer is:
# [87.66666667 82.33333333]
# The number of queries per layer are:
# [300. 190.]
# The percentage of correct predictions per layer is:
# [89.66666667 81.33333333]
# The mean percentage of correct predictions per layer is:
# [88.91666667 82.83333333]
# The number of queries per layer are:
# [484. 300.]
# The percentage of correct predictions per layer is:
# [87.4 80.2]
# The number of queries per layer are:
# [300. 200.]
# The percentage of correct predictions per layer is:
# [93.33333333 87.33333333]
# The number of queries per layer are:
# [300. 188.]
# The percentage of correct predictions per layer is:
# [90.66666667 88.66666667]
# The number of queries per layer are:
# [300. 193.]
# The percentage of correct predictions per layer is:
# [89.66666667 86.        ]
# The number of queries per layer are:
# [300. 199.]
# The percentage of correct predictions per layer is:
# [92.66666667 86.66666667]
# The mean percentage of correct predictions per layer is:
# [91.58333333 87.16666667]
# The number of queries per layer are:
# [484. 312.]
# The percentage of correct predictions per layer is:
# [90.  84.8]
# The number of queries per layer are:
# [300. 208.]
# The percentage of correct predictions per layer is:
# [96.         92.66666667]
# The number of queries per layer are:
# [300. 196.]
# The percentage of correct predictions per layer is:
# [93.66666667 92.        ]
# The number of queries per layer are:
# [300. 202.]
# The percentage of correct predictions per layer is:
# [92.66666667 90.33333333]
# The number of queries per layer are:
# [300. 207.]
# The percentage of correct predictions per layer is:
# [95.33333333 91.33333333]
# The mean percentage of correct predictions per layer is:
# [94.41666667 91.58333333]
# The number of queries per layer are:
# [484. 326.]
# The percentage of correct predictions per layer is:
# [92.8 88.6]
# The number of queries per layer are:
# [300. 220.]
# The percentage of correct predictions per layer is:
# [100. 100.]
# The number of queries per layer are:
# [300. 213.]
# The percentage of correct predictions per layer is:
# [99.33333333 99.33333333]
# The number of queries per layer are:
# [300. 222.]
# The percentage of correct predictions per layer is:
# [99.33333333 99.33333333]
# The number of queries per layer are:
# [300. 221.]
# The percentage of correct predictions per layer is:
# [100. 100.]
# The mean percentage of correct predictions per layer is:
# [99.66666667 99.66666667]
# The number of queries per layer are:
# [484. 342.]
# The percentage of correct predictions per layer is:
# [96.6 96.6]
# The number of queries per layer are:
# [300. 220.]
# The percentage of correct predictions per layer is:
# [100. 100.]
# The number of queries per layer are:
# [300. 215.]
# The percentage of correct predictions per layer is:
# [100. 100.]
# The number of queries per layer are:
# [300. 224.]
# The percentage of correct predictions per layer is:
# [100. 100.]
# The number of queries per layer are:
# [300. 221.]
# The percentage of correct predictions per layer is:
# [100. 100.]
# The mean percentage of correct predictions per layer is:
# [100. 100.]
# The number of queries per layer are:
# [484. 343.]
# The percentage of correct predictions per layer is:
# [96.8 96.8]
# The number of queries per layer are:
# [300. 220.]
# The percentage of correct predictions per layer is:
# [100. 100.]
# The number of queries per layer are:
# [300. 215.]
# The percentage of correct predictions per layer is:
# [100. 100.]
# The number of queries per layer are:
# [300. 224.]
# The percentage of correct predictions per layer is:
# [100. 100.]
# The number of queries per layer are:
# [300. 221.]
# The percentage of correct predictions per layer is:
# [100. 100.]
# The mean percentage of correct predictions per layer is:
# [100. 100.]
# The number of queries per layer are:
# [484. 343.]
# The percentage of correct predictions per layer is:
# [96.8 96.8]

# %%
import numpy as np
import matplotlib.pyplot as plt
mean_acc_per_layer = np.zeros(height)
times=0
while times < 4:
    # now lets create randomly N points in the space 0-300, 0-300
    n = 300
    random_p = torch.zeros(n, 2)
    x_lim = [min(data[:, 0]), max(data[:, 0])]
    y_lim = [min(data[:, 1]), max(data[:, 1])]


    for i in range(n):
        random_p[i] = torch.Tensor([np.random.randint(x_lim[0],x_lim[1]), np.random.randint(y_lim[0],y_lim[1])])
        
    infer_points = random_p.to(device)
    plt.scatter(infer_points[:,0], infer_points[:,1])

    correct_predictions_per_layer = np.zeros(height)
    accuracy_per_layer = np.zeros(height)

    qp = infer_points
    for i, query_point in enumerate(qp):
        preds_per_layer = ktree.query_verbose(query_point)["predictions per layer"]
        k_nearest_neighbors = ktree.root.query(query_point, k=1)

        for j, pred in enumerate(preds_per_layer):
            if any(np.array_equal(pred[0], k_nearest_neighbors[ki]) for ki in range(1)):
                correct_predictions_per_layer[j] += 1

    accuracy_per_layer = correct_predictions_per_layer / len(infer_points) * 100
    mean_acc_per_layer += accuracy_per_layer
    times += 1
    print(f"The percentage of correct predictions per layer is: ")
    print(accuracy_per_layer)

print(f"The mean percentage of correct predictions is: ")
print(mean_acc_per_layer/times)
# Out:
# The percentage of correct predictions per layer is:
# [88.         69.66666667 44.66666667]
# The percentage of correct predictions per layer is:
# [91.         71.33333333 47.33333333]
# The percentage of correct predictions per layer is:
# [91.33333333 70.         43.        ]
# The percentage of correct predictions per layer is:
# [89.66666667 66.33333333 40.66666667]
# The mean percentage of correct predictions is:
# [90.         69.33333333 43.91666667]

# %%
import numpy as np
import matplotlib.pyplot as plt
mean_acc_per_layer = np.zeros(height)
times=0
while times < 4:
    # now lets create randomly N points in the space 0-300, 0-300
    n = 300
    random_p = torch.zeros(n, 2)
    x_lim = [min(data[:, 0]), max(data[:, 0])]
    y_lim = [min(data[:, 1]), max(data[:, 1])]


    for i in range(n):
        random_p[i] = torch.Tensor([np.random.randint(x_lim[0],x_lim[1]), np.random.randint(y_lim[0],y_lim[1])])
        
    infer_points = random_p.to(device)
    plt.scatter(infer_points[:,0], infer_points[:,1])

    correct_predictions_per_layer = np.zeros(height)
    accuracy_per_layer = np.zeros(height)

    qp = infer_points
    for i, query_point in enumerate(qp):
        preds_per_layer = ktree.query_verbose(query_point)["predictions per layer"]
        k_nearest_neighbors = ktree.root.query(query_point, k=2)

        for j, pred in enumerate(preds_per_layer):
            if any(np.array_equal(pred[0], k_nearest_neighbors[ki]) for ki in range(2)):
                 correct_predictions_per_layer[j] += 1

    accuracy_per_layer = correct_predictions_per_layer / len(infer_points) * 100
    mean_acc_per_layer += accuracy_per_layer
    times += 1
    print(f"The percentage of correct predictions per layer is: ")
    print(accuracy_per_layer)

print(f"The mean percentage of correct predictions is: ")
print(mean_acc_per_layer/times)
# Out:
# The percentage of correct predictions per layer is:
# [94.         73.33333333 49.66666667]
# The percentage of correct predictions per layer is:
# [88.66666667 72.33333333 44.66666667]
# The percentage of correct predictions per layer is:
# [92.66666667 75.66666667 46.        ]
# The percentage of correct predictions per layer is:
# [90.66666667 67.66666667 37.33333333]
# The mean percentage of correct predictions is:
# [91.5        72.25       44.41666667]

# %%
import numpy as np
import matplotlib.pyplot as plt
mean_acc_per_layer = np.zeros(height)
times=0
while times < 4:
    # now lets create randomly N points in the space 0-300, 0-300
    n = 300
    random_p = torch.zeros(n, 2)
    x_lim = [min(data[:, 0]), max(data[:, 0])]
    y_lim = [min(data[:, 1]), max(data[:, 1])]


    for i in range(n):
        random_p[i] = torch.Tensor([np.random.randint(x_lim[0],x_lim[1]), np.random.randint(y_lim[0],y_lim[1])])
        
    infer_points = random_p.to(device)
    plt.scatter(infer_points[:,0], infer_points[:,1])

    correct_predictions_per_layer = np.zeros(height)
    accuracy_per_layer = np.zeros(height)

    qp = infer_points
    for i, query_point in enumerate(qp):
        preds_per_layer = ktree.query_verbose(query_point)["predictions per layer"]
        k_nearest_neighbors = ktree.root.query(query_point, k=5)

        for j, pred in enumerate(preds_per_layer):
            if any(np.array_equal(pred[0], k_nearest_neighbors[ki]) for ki in range(5)):
                 correct_predictions_per_layer[j] += 1

    accuracy_per_layer = correct_predictions_per_layer / len(infer_points) * 100
    mean_acc_per_layer += accuracy_per_layer
    times += 1
    print(f"The percentage of correct predictions per layer is: ")
    print(accuracy_per_layer)

print(f"The mean percentage of correct predictions is: ")
print(mean_acc_per_layer/times)
# Out:
# The percentage of correct predictions per layer is:
# [92.33333333 79.33333333 49.33333333]
# The percentage of correct predictions per layer is:
# [91.33333333 75.33333333 50.66666667]
# The percentage of correct predictions per layer is:
# [93.         77.33333333 53.66666667]
# The percentage of correct predictions per layer is:
# [93.66666667 76.         46.        ]
# The mean percentage of correct predictions is:
# [92.58333333 77.         49.91666667]

# %%
import numpy as np
import matplotlib.pyplot as plt
mean_acc_per_layer = np.zeros(height)
times=0
while times < 4:
    # now lets create randomly N points in the space 0-300, 0-300
    n = 300
    random_p = torch.zeros(n, 2)
    x_lim = [min(data[:, 0]), max(data[:, 0])]
    y_lim = [min(data[:, 1]), max(data[:, 1])]


    for i in range(n):
        random_p[i] = torch.Tensor([np.random.randint(x_lim[0],x_lim[1]), np.random.randint(y_lim[0],y_lim[1])])
        
    infer_points = random_p.to(device)
    plt.scatter(infer_points[:,0], infer_points[:,1])

    correct_predictions_per_layer = np.zeros(height)
    accuracy_per_layer = np.zeros(height)

    qp = infer_points
    for i, query_point in enumerate(qp):
        preds_per_layer = ktree.query_verbose(query_point)["predictions per layer"]
        k_nearest_neighbors = ktree.root.query(query_point, k=10)

        for j, pred in enumerate(preds_per_layer):
            if any(np.array_equal(pred[0], k_nearest_neighbors[ki]) for ki in range(10)):
                 correct_predictions_per_layer[j] += 1

    accuracy_per_layer = correct_predictions_per_layer / len(infer_points) * 100
    mean_acc_per_layer += accuracy_per_layer
    times += 1
    print(f"The percentage of correct predictions per layer is: ")
    print(accuracy_per_layer)

print(f"The mean percentage of correct predictions is: ")
print(mean_acc_per_layer/times)
# Out:
# The percentage of correct predictions per layer is:
# [92.33333333 78.66666667 53.33333333]
# The percentage of correct predictions per layer is:
# [95.66666667 82.         57.        ]
# The percentage of correct predictions per layer is:
# [96.33333333 82.33333333 54.        ]
# The percentage of correct predictions per layer is:
# [95.66666667 84.66666667 54.        ]
# The mean percentage of correct predictions is:
# [95.         81.91666667 54.58333333]

# %%
import numpy as np
import matplotlib.pyplot as plt
mean_acc_per_layer = np.zeros(height)
times=0
while times < 4:
    # now lets create randomly N points in the space 0-300, 0-300
    n = 300
    random_p = torch.zeros(n, 2)
    x_lim = [min(data[:, 0]), max(data[:, 0])]
    y_lim = [min(data[:, 1]), max(data[:, 1])]


    for i in range(n):
        random_p[i] = torch.Tensor([np.random.randint(x_lim[0],x_lim[1]), np.random.randint(y_lim[0],y_lim[1])])
        
    infer_points = random_p.to(device)
    plt.scatter(infer_points[:,0], infer_points[:,1])

    correct_predictions_per_layer = np.zeros(height)
    accuracy_per_layer = np.zeros(height)

    qp = infer_points
    for i, query_point in enumerate(qp):
        preds_per_layer = ktree.query_verbose(query_point)["predictions per layer"]
        k_nearest_neighbors = ktree.root.query(query_point, k=50)

        for j, pred in enumerate(preds_per_layer):
            if any(np.array_equal(pred[0], k_nearest_neighbors[ki]) for ki in range(50)):
                 correct_predictions_per_layer[j] += 1

    accuracy_per_layer = correct_predictions_per_layer / len(infer_points) * 100
    mean_acc_per_layer += accuracy_per_layer
    times += 1
    print(f"The percentage of correct predictions per layer is: ")
    print(accuracy_per_layer)

print(f"The mean percentage of correct predictions is: ")
print(mean_acc_per_layer/times)
# Out:
# The percentage of correct predictions per layer is:
# [97.66666667 96.         64.66666667]
# The percentage of correct predictions per layer is:
# [99.33333333 95.33333333 67.66666667]
# The percentage of correct predictions per layer is:
# [99.         95.33333333 64.33333333]
# The percentage of correct predictions per layer is:
# [99.         97.         68.66666667]
# The mean percentage of correct predictions is:
# [98.75       95.91666667 66.33333333]

# %%
import numpy as np
import matplotlib.pyplot as plt
mean_acc_per_layer = np.zeros(height)
times=0
while times < 4:
    # now lets create randomly N points in the space 0-300, 0-300
    n = 300
    random_p = torch.zeros(n, 2)
    x_lim = [min(data[:, 0]), max(data[:, 0])]
    y_lim = [min(data[:, 1]), max(data[:, 1])]


    for i in range(n):
        random_p[i] = torch.Tensor([np.random.randint(x_lim[0],x_lim[1]), np.random.randint(y_lim[0],y_lim[1])])
        
    infer_points = random_p.to(device)
    plt.scatter(infer_points[:,0], infer_points[:,1])

    correct_predictions_per_layer = np.zeros(height)
    accuracy_per_layer = np.zeros(height)

    qp = infer_points
    for i, query_point in enumerate(qp):
        preds_per_layer = ktree.query_verbose(query_point)["predictions per layer"]
        k_nearest_neighbors = ktree.root.query(query_point, k=100)

        for j, pred in enumerate(preds_per_layer):
            if any(np.array_equal(pred[0], k_nearest_neighbors[ki]) for ki in range(100)):
                 correct_predictions_per_layer[j] += 1

    accuracy_per_layer = correct_predictions_per_layer / len(infer_points) * 100
    mean_acc_per_layer += accuracy_per_layer
    times += 1
    print(f"The percentage of correct predictions per layer is: ")
    print(accuracy_per_layer)

print(f"The mean percentage of correct predictions is: ")
print(mean_acc_per_layer/times)
# Out:
# The percentage of correct predictions per layer is:
# [100.          99.          69.33333333]
# The percentage of correct predictions per layer is:
# [100.         100.          70.66666667]
# The percentage of correct predictions per layer is:
# [100.         100.          69.33333333]
# The percentage of correct predictions per layer is:
# [100.          99.66666667  68.66666667]
# The mean percentage of correct predictions is:
# [100.          99.66666667  69.5       ]
