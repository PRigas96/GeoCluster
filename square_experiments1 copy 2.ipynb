# %%
from itertools import product, combinations
import matplotlib.pyplot as plt
import numpy as np
from src import k_tree
from src.utils import data as dt
import torch
from src.k_tree import Ktree
from src.utils.data import loadData, loadData_3d
from src.metrics import Linf_simple

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
device = "cpu"
data, _ = loadData(10000)
#device = "cpu"
#device = "cpu"
#data, _ = loadData(100)
#data = squares


#data = rects
learning_rate = 5e-3 # 1e-2, 5e-3
k = 3
teacher_args = {
    "optimizer_lr": learning_rate,
    "epochs": 400, # 300
    "times": 20,
    "alpha": 0.1, #  projection loss 0.1
    "beta": 0.1, # latent loss 0.1
    "gamma": 0.011, # repulsive loss 0.01
    #"gamma": 0.4, # repulsive loss 0.01
    "delta": 0.1, # fuzzy scale 0.01
    "f_clk": 10, # 20
    "scale": 1, # fuzzy scale 
    "scale_flag": False,
    "number_of_centroids": k,
    "latent_size": 200,
    "encoder_activation": False,
    "encoder_depth": 5,
    "predictor_width": 5*100,
    "predictor_depth": 5,
}
n = 30
un_args = {
    "N": n,
    "M": n**2-1, # 10000 - 1
    "epsilon": 0.15 # here a layer value should be somehow included. As layers get denser  epilson should be smaller
}
student_args = {
    "optimizer_lr": 5e-3,
    "epochs": 3000, # 30000, 3000
    "width": 200,
    "depth": 5,
}


thresshold = 100*k
metric = Linf_simple
ktree = Ktree(thresshold, data, metric,teacher_args, un_args, student_args,device=device)
ktree.create_tree(plot=False)
#path = 'models/squares/100/class0_student_config.pt'
#ktree.root.create_student_from_config(path)
# Out:
# Loading data...
# Data loaded.
#
# ====================
# Creating student for node 0 that has 9999 data, which is more than the threshold 300.
# Bounding box for node 0: [[-5, 7008], [-8, 7008]]
# Creating teacher for node 0 with 3 centroids.
# ====================
# Training Teacher Model
# Shuffling data
# /home/geoten/Projects/GeoCluster/src/geometry.py:61: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   rotation = torch.tensor(rotation)
# ====================
# Epoch: 20/400..
#  Training loss: 1892.29150..
#  torch.mean(F): 1827.23987..
#  Reg Proj: 64.86348..
#  Reg Latent: 0.18811..
#  Repulsive: 0.00002..
#  Memory: 182.72399..
#  Memory: 182.72399..
#  Output:
#  [[3209.6865 3940.4114]
#  [1748.1882 2144.4216]
#  [5961.844  7332.3174]]
# ====================
# Epoch: 40/400..
#  Training loss: 3059.59766..
#  torch.mean(F): 2333.91382..
#  Reg Proj: 725.50625..
#  Reg Latent: 0.17759..
#  Repulsive: 0.00002..
#  Memory: 233.39138..
#  Memory: 233.39138..
#  Output:
#  [[ 3098.8228  6581.584 ]
#  [ 2050.4856  4354.0034]
#  [ 5005.6514 10635.531 ]]
# ====================
# Epoch: 60/400..
#  Training loss: 1859.34753..
#  torch.mean(F): 1859.17603..
#  Reg Proj: 0.00000..
#  Reg Latent: 0.17150..
#  Repulsive: 0.00003..
#  Memory: 185.91760..
#  Memory: 185.91760..
#  Output:
#  [[3702.9426 2242.5664]
#  [2204.391  1334.8387]
#  [5837.5776 3536.0186]]
# ====================
# Epoch: 80/400..
#  Training loss: 1688.07910..
#  torch.mean(F): 1687.91272..
#  Reg Proj: 0.00000..
#  Reg Latent: 0
#  Memory: 170.55659..
#  Memory: 170.55659..
#  Output:
#  [[2848.71   2567.7427]
#  [3292.7043 2968.1492]
#  [3740.9475 3372.2844]]
# ====================
# Epoch: 380/400..
#  Training loss: 1715.04944..
#  torch.mean(F): 1714.72620..
#  Reg Proj: 0.26745..
#  Reg Latent: 0.05564..
#  Repulsive: 0.00011..
#  Memory: 171.47262..
#  Memory: 171.47262..
#  Output:
#  [[2987.4863 3040.9656]
#  [3428.1724 3489.4612]
#  [4014.1533 4085.8838]]
# ====================
# Epoch: 400/400..
#  Training loss: 1733.60107..
#  torch.mean(F): 1733.12158..
#  Reg Proj: 0.42853..
#  Reg Latent: 0.05090..
#  Repulsive: 0.00008..
#  Memory: 173.31216..
#  Memory: 173.31216..
#  Output:
#  [[2716.2996 2608.7546]
#  [3355.3647 3222.362 ]
#  [4200.6904 4034.1868]]
# ====================
# getUncertaintyArea
# Ouputs are [[2638.4683 2844.8545]
#  [3128.2776 3373.0532]
#  [3550.178  3827.9297]]
# scale is 7012
# Processing...
# flag is 1
# m is 900
# i is 900
# Labeled 0/900 points.
# Labeled all 900/900 points.
# Creating student for node 00 with 3 centroids.
# Device is: cpu
# ====================
# Training Student Model
# Acc:  0.5111111111111111
# Epoch:  0 Cost:  5449.28076171875
# Acc:  0.7655555555555555
# Epoch:  300 Cost:  63.49924850463867
# Acc:  0.8722222222222222
# Epoch:  600 Cost:  32.05179977416992
# Acc:  0.9011111111111111
# Epoch:  900 Cost:  26.146554946899414
# Acc:  0.8766666666666667
# Epoch:  1200 Cost:  27.758440017700195
# Acc:  0.82
# Epoch:  1500 Cost:  33.49058151245117
# Acc:  0.8822222222222222
# Epoch:  1800 Cost:  23.71611785888672
# Acc:  0.9488888888888889
# Epoch:  2100 Cost:  14.680624008178711
# Acc:  0.7477777777777778
# Epoch:  2400 Cost:  52.117462158203125
# Acc:  0.9744444444444444
# Epoch:  2700 Cost:  13.669490814208984
#
# ====================
# Creating student for node 01 that has 2826 data, which is more than the threshold 300.
# Bounding box for node 01: [[-3, 5225], [-8, 5204]]
# Creating teacher for node 01 with 3 centroids.
# ====================
# Training Teacher Model
# Shuffling data
# ====================
# Epoch: 20/400..
#  Training loss: 1634.35742..
#  torch.mean(F): 1633.48389..
#  Reg Proj: 0.00004..
#  Reg Latent: 0.87334..
#  Repulsive: 0.00023..
#  Memory: 163.34839..
#  Memory: 163.34839..
#  Output:
#  [[ 739.6898   696.68274]
#  [ 593.53394  570.59705]
#  [1203.8486  1151.88   ]]
# ====================
# Epoch: 40/400..
#  Training loss: 1514.59412..
#  torch.mean(F): 1394.69873..
#  Reg Proj: 117.44836..
#  Reg Latent: 2.44706..
#  Repulsive: 0.00002..
#  Memory: 139.46987..
#  Memory: 139.46987..
#  Output:
#  [[  761.09106  1897.3763 ]
#  [ 1760.5292   4380.8174 ]
#  [ 4182.1875  10410.886  ]]
# ====================
# Epoch: 60/400..
#  Training loss: 1123.94006..
#  torch.mean(F): 1122.19556..
#  Reg Proj: 0.02507..
#  Reg Latent: 1.71938..
#  Repulsive: 0.00008..
#  Memory: 112.21956..
#  Memory: 112.21956..
#  Output:
#  [[ 876.88165 1134.8418 ]
#  [1383.4717  1797.2059 ]
#  [[ 737.9041  785.3523]
#  [1402.3219 1492.1101]
#  [1940.8579 2064.7937]]
# ====================
# Epoch: 260/400..
#  Training loss: 1117.53711..
#  torch.mean(F): 1115.83484..
#  Reg Proj: 1.22171..
#  Reg Latent: 0.48055..
#  Repulsive: 0.00006..
#  Memory: 111.58348..
#  Memory: 111.58348..
#  Output:
#  [[1096.6454 1155.9089]
#  [2072.3855 2183.709 ]
#  [2969.2478 3128.529 ]]
# ====================
# Epoch: 280/400..
#  Training loss: 1074.29236..
#  torch.mean(F): 1073.81970..
#  Reg Proj: 0.06819..
#  Reg Latent: 0.40438..
#  Repulsive: 0.00006..
#  Memory: 107.38197..
#  Memory: 107.38197..
#  Output:
#  [[ 731.1529  653.8128]
#  [1558.2407 1393.4321]
#  [2601.494  2325.5137]]
# ====================
# Epoch: 300/400..
#  Training loss: 1159.64392..
#  torch.mean(F): 1159.39246..
#  Reg Proj: 0.00042..
#  Reg Latent: 0.25098..
#  Repulsive: 0.00011..
#  Memory: 115.93925..
#  Memory: 115.93925..
#  Output:
#  [[ 689.07227  641.6883 ]
#  [1284.6608  1195.8049 ]
#  [1733.2686  1613.1786 ]]
# ====================
# Epoch: 320/400..
#  Training loss: 1166.19141..
#  torch.mean(F): 1165.49133..
#  Reg Proj: 0.51398..
#  Reg Latent: 0.18595..
#  Repulsive: 0.00006..
#  Memory: 116.54913..
#  Memory: 116.54913..
#  Output:
#  [[ 993.4507  947.4771]
#  [2129.1802 2029.4691]
#  [2834.4502 2701.603 ]]
# ====================
# Epoch: 340/400..
#  Training loss: 1121.87036..
#  torch.mean(F): 1118.29358..
#  Reg Proj: 3.27601..
#  Reg Latent: 0.30074..
#  Repulsive: 0.00004..
#  Memory: 111.82936..
#  Memory: 111.82936..
#  Output:
#  [[1225.2666 1644.0522]
#  [1984.644  2662.4856]
#  [3227.364  4329.5522]]
# ====================
# Epoch: 360/400..
#  Training loss: 1188.68726..
#  torch.mean(F): 1185.69580..
#  Reg Proj: 2.55661..
#  Reg Latent: 0.43481..
#  Repulsive: 0.00004..
#  Memory: 118.56958..
#  Memory: 118.56958..
#  Output:
#  [[ 918.5699  902.5355]
#  [1873.4789 1840.2179]
#  [3567.56   3503.8794]]
# ====================
# Epoch: 380/400..
#  Training loss: 1434.79333..
#  torch.mean(F): 1434.72107..
#  Reg Proj: 0.00017..
#  Reg Latent: 0.07198..
#  Repulsive: 0.00010..
#  Memory: 143.47211..
#  Memory: 143.47211..
#  Output:
#  [[ 304.91467  310.93143]
#  [ 673.2864   686.5453 ]
#  [1476.7866  1505.0442 ]]
# ====================
# Epoch: 400/400..
#  Training loss: 1089.85046..
#  torch.mean(F): 1089.69458..
#  Reg Proj: 0.07528..
#  Reg Latent: 0.08042..
#  Repulsive: 0.00007..
#  Memory: 108.96946..
#  Memory: 108.96946..
#  Output:
#  [[ 862.5371  923.478 ]
#  [1475.3553 1579.3234]
#  [2348.3428 2513.228 ]]
# ====================
# getUncertaintyArea
# Ouputs are [[ 736.3085  665.8943]
#  [1607.4845 1453.0233]
#  [2277.0051 2057.8708]]
# scale is 5228
# Processing...
# flag is 669
# m is 232
# i is 900
# Labeled 0/232 points.
# Labeled all 232/232 points.
# Creating student for node 01 with 3 centroids.
# Device is: cpu
# ====================
# Training Student Model
# Acc:  0
#  Memory: 120.46913..
#  Output:
#  [[6203.191  6352.0435]
#  [5254.928  5380.6587]
#  [4432.062  4538.0024]]
# ====================
# Epoch: 320/400..
#  Training loss: 1173.20825..
#  torch.mean(F): 1168.75415..
#  Reg Proj: 0.05415..
#  Reg Latent: 4.39983..
#  Repulsive: 0.00007..
#  Memory: 116.87542..
#  Memory: 116.87542..
#  Output:
#  [[6387.687  5876.691 ]
#  [5549.722  5105.6074]
#  [4710.584  4333.617 ]]
# ====================
# Epoch: 340/400..
#  Training loss: 1363.65405..
#  torch.mean(F): 1359.13428..
#  Reg Proj: 0.01111..
#  Reg Latent: 4.50870..
#  Repulsive: 0.00006..
#  Memory: 135.91343..
#  Memory: 135.91343..
#  Output:
#  [[6984.273  6409.8105]
#  [6012.9053 5518.371 ]
#  [5101.5444 4681.97  ]]
# ====================
# Epoch: 360/400..
#  Training loss: 1317.79333..
#  torch.mean(F): 1312.01758..
#  Reg Proj: 1.60072..
#  Reg Latent: 4.17503..
#  Repulsive: 0.00004..
#  Memory: 131.20176..
#  Memory: 131.20176..
#  Output:
#  [[5315.077  5691.841 ]
#  [4298.1704 4602.8286]
#  [3003.3672 3216.377 ]]
# ====================
# Epoch: 380/400..
#  Training loss: 1321.28809..
#  torch.mean(F): 1315.88672..
#  Reg Proj: 1.07652..
#  Reg Latent: 4.32486..
#  Repulsive: 0.00006..
#  Memory: 131.58867..
#  Memory: 131.58867..
#  Output:
#  [[5768.1167 5087.4116]
#  [4621.612  4076.246 ]
#  [3799.364  3351.047 ]]
# ====================
# Epoch: 400/400..
#  Training loss: 1213.02075..
#  torch.mean(F): 1208.44250..
#  Reg Proj: 0.04782..
#  Reg Latent: 4.53026..
#  Repulsive: 0.00006..
#  Memory: 120.84425..
#  Memory: 120.84425..
#  Output:
#  [[6334.448  6251.092 ]
#  [5221.4307 5152.63  ]
#  [4495.192  4435.989 ]]
# ====================
# getUncertaintyArea
# Ouputs are [[6071.2603 5878.423 ]
#  [5043.1694 4882.9097]
#  [4291.692  4155.268 ]]
# scale is 5682
# Processing...
# flag is 660
# m is 241
# i is 900
# Labeled 0/241 points.
# Labeled all 241/241 points.
# Creating student for node 02 with 3 centroids.
# Device is: cpu
# ====================
# Training Student Model
# Acc:  0.5684647302904564
# Epoch:  0 Cost:  2699.056884765625
# Acc:  0.5726141078838174
# Epoch:  300 Cost:  84.06161499023438
# Acc:  0.5643153526970954
# Epoch:  600 Cost:  88.83030700683594
# Acc:  0.5643153526970954
# Epoch:  900 Cost:  92.85143280029297
# Acc:  0.5850622406639004
# Epoch:  1200 Cost:  90.60160064697266
# Acc:  0.5601659751037344
# Epoch:  1500 Cost:  98.698486328125
# Acc:  0.5684647302904564
# Epoch:  1800 Cost:  95.9369888305664
# Acc:  0.5684647302904564
# Epoch:  2100 Cost:  95.93697357177734
# Acc:  0.5684647302904564
# Epoch:  2400 Cost:  95.9369888305664
# Acc:  0.5684647302904564
# Epoch:  2700 Cost:  95.93697357177734
#
# ====================
# Creating student for node 000 that has 917 data, which is more than the threshold 300.
# Bounding box for node 000: [[-5, 5936], [-5, 5822]]
# Creating teacher for node 000 with 3 centroids.
# ====================
# Training Teacher Model
# ====================
# Epoch:
#  Output:
#  [[9498.84   9468.674 ]
#  [4506.3125 4491.109 ]
#  [2926.4539 2915.1897]]
# ====================
# Epoch: 300/400..
#  Training loss: 1652.02710..
#  torch.mean(F): 1631.06421..
#  Reg Proj: 20.12561..
#  Reg Latent: 0.83734..
#  Repulsive: 0.00002..
#  Memory: 163.10642..
#  Memory: 163.10642..
#  Output:
#  [[5412.269   5215.3306 ]
#  [3129.8232  3015.7104 ]
#  [ 527.4386   508.37494]]
# ====================
# Epoch: 320/400..
#  Training loss: 2006.25696..
#  torch.mean(F): 1985.27673..
#  Reg Proj: 20.31290..
#  Reg Latent: 0.66736..
#  Repulsive: 0.00003..
#  Memory: 198.52767..
#  Memory: 198.52767..
#  Output:
#  [[4323.5776  2933.1516 ]
#  [2885.5088  1957.7241 ]
#  [ 364.0456   246.90988]]
# ====================
# Epoch: 340/400..
#  Training loss: 1957.26196..
#  torch.mean(F): 1933.32764..
#  Reg Proj: 23.32858..
#  Reg Latent: 0.60566..
#  Repulsive: 0.00004..
#  Memory: 193.33276..
#  Memory: 193.33276..
#  Output:
#  [[2941.243   2852.4788 ]
#  [1818.1892  1763.4219 ]
#  [ 305.98352  296.68817]]
# ====================
# Epoch: 360/400..
#  Training loss: 2193.12085..
#  torch.mean(F): 2171.77026..
#  Reg Proj: 20.77729..
#  Reg Latent: 0.57326..
#  Repulsive: 0.00003..
#  Memory: 217.17703..
#  Memory: 217.17703..
#  Output:
#  [[3806.6746  3760.6716 ]
#  [2129.118   2103.38   ]
#  [ 405.9934   401.08624]]
# ====================
# Epoch: 380/400..
#  Training loss: 1826.50586..
#  torch.mean(F): 1806.03284..
#  Reg Proj: 19.94601..
#  Reg Latent: 0.52695..
#  Repulsive: 0.00004..
#  Memory: 180.60328..
#  Memory: 180.60328..
#  Output:
#  [[3193.3013  2893.8445 ]
#  [1876.9299  1700.4513 ]
#  [ 536.69275  484.3509 ]]
# ====================
# Epoch: 400/400..
#  Training loss: 1812.75122..
#  torch.mean(F): 1798.50293..
#  Reg Proj: 13.73586..
#  Reg Latent: 0.51241..
#  Repulsive: 0.00004..
#  Memory: 179.85029..
#  Memory: 179.85029..
#  Output:
#  [[3382.8872 3529.2861]
#  [2084.7732 2175.2092]
#  [ 834.6999  872.5826]]
#
# ====================
# Creating student for node 002 that has 1636 data, which is more than the threshold 300.
# Bounding box for node 002: [[23, 6998], [10, 7007]]
# Creating teacher for node 002 with 3 centroids.
# ====================
# Training Teacher Model
# Shuffling data
# ====================
# Epoch: 20/400..
#  Training loss: 2363.09912..
#  torch.mean(F): 2352.73120..
#  Reg Proj: 10.23640..
#  Reg Latent: 0.13152..
#  Repulsive: 0.00004..
#  Memory: 235.27312..
#  Memory: 235.27312..
#  Output:
#  [[1888.2225 2474.2126]
#  [2712.4055 3553.576 ]
#  [4641.5806 6080.586 ]]
# ====================
# Epoch: 40/400..
#  Training loss: 2261.06470..
#  torch.mean(F): 2251.19531..
#  Reg Proj: 9.71845..
#  Reg Latent: 0.15096..
#  Repulsive: 0.00003..
#  Memory: 225.11953..
#  Memory: 225.11953..
#  Output:
#  [[2616.8115 1806.3562]
#  [3840.2976 2650.4382]
#  [6551.54   4521.1553]]
# ====================
# Epoch: 60/400..
#  Training loss: 3065.13940..
#  torch.mean(F): 3021.90039..
#  Reg Proj: 43.09505..
#  Reg Latent: 0.14397..
#  Repulsive: 0.00006..
#  Memory: 302.19004..
#  Memory: 302.19004..
#  Output:
#  [[ 543.092   599.7513]
#  [1097.4963 1211.7406]
#  [2311.5725 2552.049 ]]
# ====================
# Epoch: 80/400..
#  Training loss: 2016.88501..
#  torch.mean(F): 1984.73682..
#  Reg Proj: 32.00011..
#  Reg Latent: 0.14807..
#  Repulsive: 0.00004..
#  Memory: 198.47368..
#  Memory: 198.47368..
#  Output:
#  [[ 609.13776  577.69727]
#  [1962.0256  1860.857  ]
#  [3487.968   3308.191  ]]
# ====================
# Epoch: 100/400..
#  Training loss: 2066.89966..
#  torch.mean(F): 2036.83459..
#  Reg Proj: 29.91513..
#  Reg Latent: 0.14978..
#  Repulsive: 0.00004..
#  Memory: 203.68346..
#  Memory: 203.68346..
#  Output:
#  [[ 703.6052  684.8485]
#  [1757.9385 1711.057 ]
#  [3396.363  3305.8142]]
# ====================
# Epoch: 120/400..
#  Training loss: 2440.82129..
#  torch.mean(F): 2419.11060..
#  Reg Proj: 21.56888..
#  Reg Latent: 0.14181..
#  Repulsive: 0.00002..
#  Memory: 241.91106..
#  Memory: 241.91106..
#  Output:
#  [[3623.5398 5259.0815]
#  [1104.2688 1602.3931]
#  [5943.2437 8625.43  ]]
# ====================
# Epoch: 140/400..
#  Training loss: 2719.47217..
#  torch.mean(F): 2666.90234..
#  Reg Proj: 52.47269..
#  Reg Latent: 0.09724..
#  Repulsive: 0.00001..
#  Memory: 266.69023..
#  Memory: 266.69023..
#  Output:
#  [[ 6755.823   4702.5244]
#  [ 3197.3127  2225.5884]
#  [15096.849  10509.116 ]]
# ====================
# Epoch: 160/400..
#  Training loss: 2561.86572..
#  torch.mean(F): 2501.85815..
#  Reg Proj: 59.92142..
#  Reg Latent: 0.08622..
#  Repulsive: 0.00001..
#  Memory: 250.18582..
#  Memory: 250.18582..
#  Output:
#  [[ 6902.0146  5573.4834]
#  [ 3294.633   2660.472 ]
#  [15393.453  12430.558 ]]
# ====================
# Epoch: 180/400..
#  Training loss: 1786.39612..
#  torch.mean(F): 1766.91870..
#  Reg Proj: 19.36582..
#  Reg Latent: 0.11160..
#  Repulsive: 0.00002..
#  Memory: 176.69187..
#  Memory: 176.69187..
#  Output:
#  [[4661.0415 5321.753 ]
#  [3453.544  3943.058 ]
#  [8644.193  9869.536 ]]
# ====================
# Epoch: 200/400..
#  Training loss: 2083.98999..
#  torch.mean(F): 2076.60205..
#  Reg Proj: 7.27692..
#  Reg Latent: 0.11120..
#  Repulsive: 0.00003..
#  Memory: 207.66021..
#  Memory: 207.66021..
#  Output:
#  [[3320.911  3446.5276]
#  [2394.8538 2485.4307]
#  [6488.966  6734.4404]]
# ====================
# Epoch: 220/400..
#  Training loss: 1930.34448..
#  torch.mean(F): 1868.98767..
#  Reg Proj: 61.25132..
]]
# ====================
# Epoch: 400/400..
#  Training loss: 1828.49548..
#  torch.mean(F): 1820.39417..
#  Reg Proj: 7.99524..
#  Reg Latent: 0.10603..
#  Repulsive: 0.00004..
#  Memory: 182.03942..
#  Memory: 182.03942..
#  Output:
#  [[3425.582  4133.358 ]
#  [2071.1968 2499.2676]
#  [4635.598  5593.3213]]
#
# ====================
# Creating student for node 010 that has 510 data, which is more than the threshold 300.
# Bounding box for node 010: [[-3, 2092], [-7, 2178]]
# Creating teacher for node 010 with 3 centroids.
# ====================
# Training Teacher Model
# ====================
# Epoch: 20/400..
#  Training loss: 528.28137..
#  torch.mean(F): 528.21008..
#  Reg Proj: 0.00335..
#  Reg Latent: 0.06776..
#  Repulsive: 0.00020..
#  Memory: 52.82101..
#  Memory: 52.82101..
#  Output:
#  [[ 242.26169  523.66864]
#  [ 492.80826 1064.9315 ]
#  [ 368.97452  798.78357]]
# ====================
# ...
#  Reg Proj: 34.95601..
#  Reg Latent: 0.02731..
#  Repulsive: 0.00006..
#  Memory: 199.53882..
#  Memory: 199.53882..
#  Output:
#  [[ 488.32004  493.81982]
#  [1591.1123  1609.239  ]
#  [-393.61053 -398.05338]]
# ====================
# Epoch: 200/400..
#  Training loss: 1371.36023..
#  torch.mean(F): 1356.65906..
#  Reg Proj: 14.68159..
#  Reg Latent: 0.01951..
#  Repulsive: 0.00004..
#  Memory: 135.66591..
#  Memory: 135.66591..
#  Output:
#  [[1329.4803  1552.4463 ]
#  [2389.7324  2790.369  ]
#  [-154.98474 -180.90707]]
# ====================
# Epoch: 220/400..
#  Training loss: 1568.26294..
#  torch.mean(F): 1562.12695..
#  Reg Proj: 6.11902..
#  Reg Latent: 0.01703..
#  Repulsive: 0.00003..
#  Memory: 156.21270..
#  Memory: 156.21270..
#  Output:
#  [[1581.9982 2549.5125]
#  [2424.6177 3906.8953]
#  [-318.6931 -513.3161]]
# ====================
# Epoch: 240/400..
#  Training loss: 1331.67529..
#  torch.mean(F): 1324.74805..
#  Reg Proj: 6.91086..
#  Reg Latent: 0.01638..
#  Repulsive: 0.00002..
#  Memory: 132.47480..
#  Memory: 132.47480..
#  Output:
#  [[2762.1777  2319.0967 ]
#  [4723.2485  3964.6226 ]
#  [-768.011   -644.31805]]
# ====================
# Epoch: 260/400..
#  Training loss: 1492.88733..
#  torch.mean(F): 1486.73096..
#  Reg Proj: 6.13881..
#  Reg Latent: 0.01764..
#  Repulsive: 0.00003..
#  Memory: 148.67310..
#  Memory: 148.67310..
#  Output:
#  [[2018.8115  2202.8535 ]
#  [3252.2893  3550.137  ]
#  [-503.72522 -550.3213 ]]
# ====================
# Epoch: 280/400..
#  Training loss: 1297.76270..
#  torch.mean(F): 1294.51013..
#  Reg Proj: 3.23623..
#  Reg Latent: 0.01635..
#  Repulsive: 0.00003..
#  Memory: 129.45101..
#  Memory: 129.45101..
#  Output:
#  [[2311.699   2639.032  ]
#  [3764.1436  4297.2593 ]
#  [-318.46768 -363.59634]]
# ====================
# Epoch: 300/400..
#  Training loss: 1369.45068..
#  torch.mean(F): 1362.33240..
#  Reg Proj: 7.10337..
#  Reg Latent: 0.01495..
#  Repulsive: 0.00003..
#  Memory: 136.23324..
#  Memory: 136.23324..
#  Output:
#  [[2219.9062  2253.7441 ]
#  [3648.5623  3704.1814 ]
#  [-705.79565 -716.5299 ]]
# ====================
# Epoch: 320/400..
#  Training loss: 1621.23181..
#  torch.mean(F): 1611.87305..
#  Reg Proj: 9.34537..
#  Reg Latent: 0.01337..
#  Repulsive: 0.00003..
#  Memory: 161.18730..
#  Memory: 161.18730..
#  Output:
#  [[1849.3822  2119.7244 ]
#  [3040.5168  3484.9165 ]
#  [ -99.34948 -113.85534]]
# ====================
# Epoch: 340/400..
#  Training loss: 1415.86890..
#  torch.mean(F): 1399.18762..
#  Reg Proj: 16.66878..
#  Reg Latent: 0.01248..
#  Repulsive: 0.00001..
#  Memory: 139.91876..
#  Memory: 139.91876..
#  Output:
#  [[ 2518.2815  2764.909 ]
#  [ 6927.427   7605.052 ]
#  [-1143.5519 -1255.1105]]
# ====================
# Epoch: 360/400..
#  Training loss: 2272.80957..
#  torch.mean(F): 2231.78467..
#  Reg Proj: 41.01244..
#  Reg Latent: 0.01254..
#  Repulsive: 0.00001..
#  Memory: 223.17847..
#  Memory: 223.17847..
#  Output:
#  [[ 3310.4404  3633.5496]
#  [ 8700.585   9549.636 ]
#  [-3146.4954 -3453.5225]]
# ====================
# Epoch: 380/400..
#  Training loss: 2081.01270..
#  torch.mean(F): 2054.08398..
#  Reg Proj: 26.91311..
#  Reg Latent: 0.01563..
#  Repulsive: 0.00001..
#  Memory: 205.40840..
#  Memory: 205.40840..
#  Output:
#  [[ 3060.5447  3517.3914]
#  [ 7479.0923  8596.279 ]
#  [-1942.7494 -2233.127 ]]
# ====================
# Epoch: 400/400..
#  Training loss: 1310.80286..
#  torch.mean(F): 1307.90527..
#  Reg Proj: 2.88548..
#  Reg Latent: 0.01212..
#  Repulsive: 0.00002..
#  Memory: 130.79053..
#  Memory: 130.79053..
#  Output:
#  [[2463.423   2188.447  ]
#  [5669.152   5036.017  ]
#  [-206.97429 -183.76265]]
#
# ====================
# Creating student for node 0200 that has 393 data, which is more than the threshold 300.
# Bounding box for node 0200: [[4622, 7004], [4661, 7007]]
# Creating teacher for node 0200 with 3 centroids.
# ====================
# Training Teacher Model
# ====================
# Epoch: 20/400..
#  Training loss: 3253.75171..
#  torch.mean(F): 3166.92749..
#  Reg Proj: 86.60807..
#  Reg Latent: 0.21602..
#  Repulsive: 0.00000..
#  Memory: 316.69275..
#  Memory: 316.69275..
#  Output:
#  [[ 9241.525   6883.6875]
#  [ 3395.9326  2528.2678]
#  [44723.3    33312.227 ]]
# ====================
# Epoch: 40/400..
#  Training loss: 3724.23877..
#  torch.mean(F): 3697.78955..
#  Reg Proj: 26.22950..
#  Reg Latent: 0.21965..
#  Repulsive: 0.00001..
#  Memory: 369.77896..
#  Memory: 369.77896..
#  Output:
#  [[ 4100.89     2372.8315 ]
#  [  907.72345   522.8898 ]
#  [13019.668    7535.2373 ]]
# ====================
# Epoch: 60/400..
#  Training loss: 892.76556..
#  torch.mean(F): 845.31042..
#  Reg Proj: 47.19634..
#  Reg Latent: 0.25877..
#  Repulsive: 0.00001..
#  Memory: 84.53104..
#  Memory: 84.53104..
#  Output:
#  [[ 5853.606   5515.511 ]
#  [ 1283.6138  1211.7972]
#  [21950.287  20679.57  ]]
# ====================
# Epoch: 80/400..
#  Training loss: 1443.25720..
#  torch.mean(F): 1387.55676..
#  Reg Proj: 55.43427..
#  Reg Latent: 0.26607..
#  Repulsive: 0.00001..
#  Memory: 138.75568..
#  Memory: 138.75568..
#  Output:
#  [[ 7029.7817  4682.9854]
#  [ 3930.1848  2619.4167]
#  [32684.07   21769.102 ]]
# ====================
# Epoch: 100/400..
#  Training loss: 716.94232..
#  torch.mean(F): 678.40552..
#  Reg Proj: 38.27567..
#  Reg Latent: 0.26111..
#  Repulsive: 0.00001..
#  Memory: 67.84055..
#  Memory: 67.84055..
#  Output:
#  [[ 2348.3145  2253.5842]
#  [ 6392.1787  6133.9443]
#  [19357.717  18574.521 ]]
# ====================
# Epoch: 120/400..
#  Training loss: 872.14044..
#  torch.mean(F): 830.65778..
#  Reg Proj: 41.26401..
#  Reg Latent: 0.21864..
#  Repulsive: 0.00001..
#  Memory: 83.06578..
#  Memory: 83.06578..
#  Output:
#  [[ -416.13818  -427.0297 ]
#  [ 6361.3726   6518.051  ]
#  [13804.868   14144.924  ]]
# ====================
# Epoch: 140/400..
#  Training loss: 867.58710..
#  torch.mean(F): 843.70270..
#  Reg Proj: 23.71697..
#  Reg Latent: 0.16742..
#  Repulsive: 0.00002..
#  Memory: 84.37027..
#  Memory: 84.37027..
#  Output:
#  [[-160.88525 -151.05513]
#  [2814.3652  2638.504  ]
#  [5872.5264  5505.3066 ]]
# ====================
# Epoch: 160/400..
#  Training loss: 1050.30432..
#  torch.mean(F): 1021.93390..
#  Reg Proj: 28.21259..
#  Reg Latent: 0.15782..
#  Repulsive: 0.00001..
#  Memory: 102.19339..
#  Memory: 102.19339..
#  Output:
#  [[  -85.97614   -94.86654]
#  [ 5283.702    5768.24   ]
#  [11504.707   12557.926  ]]
# ====================
# Epoch: 180/400..
#  Training loss: 1042.46912..
#  torch.mean(F): 1004.92194..
#  Reg Proj: 37.39691..
#  Reg Latent: 0.15030..
#  Repulsive: 0.00001..
#  Memory: 100.49219..
#  Memory: 100.49219..
#  Output:
#  [[  210.09026   174.81105]
#  [ 7005.9014   5830.1865 ]
#  [18308.377   15235.696  ]]
# ====================
# Epoch: 200/400..
#  Training loss: 736.17517..
#  torch.mean(F): 702.60144..
#  Reg Proj: 33.41874..
#  Reg Latent: 0.15494..
#  Repulsive: 0.00001..
#  Memory: 70.26014..
#  Memory: 70.26014..
#  Output:
#  [[  283.541     244.97453]
#  [ 6490.8984   5610.7725 ]
#  [15767.843   13630.062  ]]
# ====================
# Epoch: 220/400..
#  Training loss: 1192.19434..
#  torch.mean(F): 1163.98059..
#  Reg Proj: 28.05396..
#  Reg Latent: 0.15980..
#  Repulsive: 0.00001..
#  Memory: 116.39806..
#  Memory: 116.39806..
#  Output:
#  [[  280.61047   291.6043 ]
#  [ 5251.4077   5458.097  ]
#  [12392.2295  12880.11   ]]
# ====================
# Epoch: 240/400..
#  Training loss: 1038.60901..
#  torch.mean(F): 1005.98718..
#  Reg Proj: 32.46098..
#  Reg Latent: 0.16092..
#  Repulsive: 0.00001..
#  Memory: 100.59872..
#  Memory: 100.59872..
#  Output:
#  [[  378.5668    374.59296]
#  [ 6652.3545   6583.9985 ]
#  [14630.343   14479.656  ]]
# ====================
# Epoch: 260/400..
#  Training loss: 1552.75745..
#  torch.mean(F): 1528.33618..
#  Reg Proj: 24.26348..
#  Reg Latent: 0.15785..
#  Repulsive: 0.00001..
#  Memory: 152.83362..
#  Memory: 152.83362..
#  Output:
#  [[  337.05612   357.20352]
#  [ 4852.1895   5142.4316 ]
#  [10774.333   11418.5625 ]]
# ====================
# Epoch: 280/400..
#  Training loss: 666.02252..
#  torch.mean(F): 638.51154..
#  Reg Proj: 27.35478..
#  Reg Latent: 0.15619..
#  Repulsive: 0.00001..
#  Memory: 63.85115..
#  Memory: 63.85115..
#  Output:
#  [[  440.35333   454.6229 ]
#  [ 5811.8076   5999.8726 ]
#  [12317.167   12715.747  ]]
# ====================
# Epoch: 300/400..
#  Training loss: 1311.23193..
#  torch.mean(F): 1288.74963..
#  Reg Proj: 22.33603..
#  Reg Latent: 0.14620..
#  Repulsive: 0.00001..
#  Memory: 128.87496..
#  Memory: 128.87496..
#  Output:
#  [[  439.0613    430.01974]
#  [ 5279.4624   5171.1704 ]
#  [10467.771   10253.329  ]]
# ====================
# Epoch: 320/400..
#  Training loss: 1719.84180..
#  torch.mean(F): 1691.27991..
#  Reg Proj: 28.40837..
#  Reg Latent: 0.15359..
#  Repulsive: 0.00001..
#  Memory: 169.12799..
#  Memory: 169.12799..
#  Output:
#  [[  581.90796   596.40515]
#  [ 7209.0063   7389.117  ]
#  [12683.439   13001.894  ]]
# ====================
# Epoch: 340/400..
#  Training loss: 637.06152..
#  torch.mean(F): 614.38922..
#  Reg Proj: 22.51897..
#  Reg Latent: 0.15332..
#  Repulsive: 0.00001..
#  Memory: 61.43892..
#  Memory: 61.43892..
#  Output:
#  [[  565.873     550.50244]
#  [ 6040.498    5875.1016 ]
#  [10741.515   10444.293  ]]
# ====================
# Epoch: 360/400..
#  Training loss: 791.19635..
#  torch.mean(F): 768.17035..
#  Reg Proj: 22.87115..
#  Reg Latent: 0.15485..
#  Repulsive: 0.00001..
#  Memory: 76.81703..
#  Memory: 76.81703..
#  Output:
#  [[  625.10187   650.32184]
#  [ 6243.9893   6496.406  ]
#  [10647.449   11078.975  ]]
# ====================
# Epoch: 380/400..
#  Training loss: 751.26196..
#  torch.mean(F): 730.86127..
#  Reg Proj: 20.24778..
#  Reg Latent: 0.15291..
#  Repulsive: 0.00001..
#  Memory: 73.08613..
#  Memory: 73.08613..
#  Output:
#  [[  616.6185    661.83966]
#  [ 5602.1035   6012.576  ]
#  [ 9372.673   10055.256  ]]
# ====================
# Epoch: 400/400..
#  Training loss: 1416.10864..
#  torch.mean(F): 1398.83423..
#  Reg Proj: 17.11907..
#  Reg Latent: 0.15539..
#  Repulsive: 0.00002..
#  Memory: 139.88342..
#  Memory: 139.88342..
#  Output:
#  [[ 561.24963  446.95966]
#  [4420.888   3519.9187 ]
#  [7439.6753  5924.408  ]]
#
# ====================
# Creating student for node 0202 that has 373 data, which is more than the threshold 300.
# Bounding box for node 0202: [[3997, 7005], [4034, 6996]]
# Creating teacher for node 0202 with 3 centroids.
# ====================
# Training Teacher Model
# ====================
# Epoch: 20/400..
#  Training loss: 2783.79517..
#  torch.mean(F): 2763.35181..
#  Reg Proj: 20.33532..
#  Reg Latent: 0.10816..
#  Repulsive: 0.00002..
#  Memory: 276.33518..
#  Memory: 276.33518..
#  Output:
#  [[10741.151   7057.8467]
#  [14088.514   9257.613 ]
#  [ 8433.576   5541.8125]]
# ====================
# Epoch: 40/400..
#  Training loss: 1758.82300..
#  torch.mean(F): 1629.20789..
#  Reg Proj: 129.53589..
#  Reg Latent: 0.07919..
#  Repulsive: 0.00001..
#  Memory: 162.92079..
#  Memory: 162.92079..
#  Output:
#  [[ 4427.8633  7214.621 ]
#  [ 7963.8843 12976.02  ]
#  [-2651.2822 -4319.956 ]]
# ====================
# Epoch: 60/400..
#  Training loss: 3011.79980..
#  torch.mean(F): 2959.18628..
#  Reg Proj: 52.52162..
#  Reg Latent: 0.09169..
#  Repulsive: 0.00002..
#  Memory: 295.91863..
#  Memory: 295.91863..
#  Output:
#  [[  355.38684   701.09705]
#  [ 2709.6348   5347.959  ]
#  [ -800.5152  -1580.157  ]]
# ====================
# Epoch: 80/400..
#  Training loss: 1367.18335..
#  torch.mean(F): 1280.43945..
#  Reg Proj: 86.65626..
#  Reg Latent: 0.08767..
#  Repulsive: 0.00002..
#  Memory: 128.04395..
#  Memory: 128.04395..
#  Output:
#  [[  858.27826   568.69934]
#  [ 6919.3223   4585.3193 ]
#  [-1433.5582   -950.0274 ]]
# ====================
# Epoch: 100/400..
#  Training loss: 3196.70630..
#  torch.mean(F): 3157.39771..
#  Reg Proj: 39.21957..
#  Reg Latent: 0.08904..
#  Repulsive: 0.00004..
#  Memory: 315.73977..
#  Memory: 315.73977..
#  Output:
#  [[ 426.9346   379.23245]
#  [3354.471   2980.137  ]
#  [-320.28116 -284.5391 ]]
# ====================
# Epoch: 120/400..
#  Training loss: 2447.91333..
#  torch.mean(F): 2425.33374..
#  Reg Proj: 22.49354..
#  Reg Latent: 0.08587..
#  Repulsive: 0.00003..
#  Memory: 242.53337..
#  Memory: 242.53337..
#  Output:
#  [[1004.2834   968.49384]
#  [7490.251   7223.8496 ]
#  [ 201.2181   194.13057]]
# ====================
# Epoch: 140/400..
#  Training loss: 2012.30042..
#  torch.mean(F): 1991.06262..
#  Reg Proj: 21.15298..
#  Reg Latent: 0.08471..
#  Repulsive: 0.00009..
#  Memory: 199.10626..
#  Memory: 199.10626..
#  Output:
#  [[ 551.9438   716.8549 ]
#  [3902.204   5068.5396 ]
#  [ 328.60187  426.93723]]
# ====================
# Epoch: 160/400..
#  Training loss: 1729.07227..
#  torch.mean(F): 1707.86011..
#  Reg Proj: 21.13234..
#  Reg Latent: 0.07969..
#  Repulsive: 0.00011..
#  Memory: 170.78601..
#  Memory: 170.78601..
#  Output:
#  [[ 698.5855   690.1688 ]
#  [4642.669   4587.1475 ]
#  [ 468.7251   463.22928]]
# ====================
# Epoch: 180/400..
#  Training loss: 2417.78491..
#  torch.mean(F): 2396.33594..
#  Reg Proj: 21.37144..
#  Reg Latent: 0.07751..
#  Repulsive: 0.00018..
#  Memory: 239.63359..
#  Memory: 239.63359..
#  Output:
#  [[ 609.71576  633.2148 ]
#  [3862.4026  4010.467  ]
#  [ 484.87717  503.3201 ]]
# ====================
# Epoch: 200/400..
#  Training loss: 1978.99829..
#  torch.mean(F): 1959.34277..
#  Reg Proj: 19.57930..
#  Reg Latent: 0.07609..
#  Repulsive: 0.00006..
#  Memory: 195.93428..
#  Memory: 195.93428..
#  Output:
#  [[1240.7496 1081.1499]
#  [7300.318  6358.8936]
#  [ 852.4129  741.9865]]
# ====================
# Epoch: 220/400..
#  Training loss: 2120.82178..
#  torch.mean(F): 2100.45044..
#  Reg Proj: 20.29896..
#  Reg Latent: 0.07207..
#  Repulsive: 0.00020..
#  Memory: 210.04504..
#  Memory: 210.04504..
#  Output:
#  [[ 826.7523   727.60284]
#  [4504.309   3964.7559 ]
#  [ 709.3599   624.5646 ]]
# ====================
# Epoch: 240/400..
#  Training loss: 1034.49622..
#  torch.mean(F): 1015.15002..
#  Reg Proj: 19.27127..
#  Reg Latent: 0.07472..
#  Repulsive: 0.00018..
#  Memory: 101.51500..
#  Memory: 101.51500..
#  Output:
#  [[1009.0543  1064.3103 ]
#  [5186.6235  5469.5117 ]
#  [ 890.29114  938.5061 ]]
# ====================
# Epoch: 260/400..
#  Training loss: 1626.40723..
#  torch.mean(F): 1608.07959..
#  Reg Proj: 18.24270..
#  Reg Latent: 0.08481..
#  Repulsive: 0.00017..
#  Memory: 160.80796..
#  Memory: 160.80796..
#  Output:
#  [[1297.0242 1339.0464]
#  [6419.2134 6628.886 ]
#  [1161.7281 1200.1846]]
# ====================
# Epoch: 280/400..
#  Training loss: 969.77179..
#  torch.mean(F): 951.44196..
#  Reg Proj: 18.24545..
#  Reg Latent: 0.08368..
#  Repulsive: 0.00075..
#  Memory: 95.14420..
#  Memory: 95.14420..
#  Output:
#  [[1116.9484 1204.978 ]
#  [5197.4604 5609.483 ]
#  [1143.1526 1234.55  ]]
# ====================
# Epoch: 300/400..
#  Training loss: 801.99695..
#  torch.mean(F): 784.35248..
#  Reg Proj: 17.56868..
#  Reg Latent: 0.07563..
#  Repulsive: 0.00018..
#  Memory: 78.43525..
#  Memory: 78.43525..
#  Output:
#  [[1272.6976 1289.0701]
#  [5584.0947 5656.656 ]
#  [1402.1587 1420.6063]]
# ====================
# Epoch: 320/400..
#  Training loss: 1460.96704..
#  torch.mean(F): 1444.49426..
#  Reg Proj: 16.39476..
#  Reg Latent: 0.07788..
#  Repulsive: 0.00011..
#  Memory: 144.44943..
#  Memory: 144.44943..
#  Output:
#  [[1465.1991 1550.3359]
#  [6167.751  6528.088 ]
#  [1674.844  1773.4243]]
# ====================
# Epoch: 340/400..
#  Training loss: 906.53967..
#  torch.mean(F): 890.39587..
#  Reg Proj: 16.06547..
#  Reg Latent: 0.07823..
#  Repulsive: 0.00007..
#  Memory: 89.03959..
#  Memory: 89.03959..
#  Output:
#  [[1495.8673 1434.1342]
#  [5944.3823 5700.5303]
#  [1871.3363 1795.1923]]
# ====================
# Epoch: 360/400..
#  Training loss: 1320.91296..
#  torch.mean(F): 1305.81689..
#  Reg Proj: 15.02560..
#  Reg Latent: 0.07045..
#  Repulsive: 0.00005..
#  Memory: 130.58169..
#  Memory: 130.58169..
#  Output:
#  [[1647.7515 1616.701 ]
#  [6296.8936 6178.7   ]
#  [2148.833  2108.7136]]
# ====================
# Epoch: 380/400..
#  Training loss: 1245.42224..
#  torch.mean(F): 1231.35632..
#  Reg Proj: 13.99223..
#  Reg Latent: 0.07374..
#  Repulsive: 0.00004..
#  Memory: 123.13563..
#  Memory: 123.13563..
#  Output:
#  [[1551.8162 1786.9446]
#  [5641.2905 6495.3735]
#  [2177.276  2506.365 ]]
# ====================
# Epoch: 400/400..
#  Training loss: 1457.94189..
#  torch.mean(F): 1442.96704..
#  Reg Proj: 14.89937..
#  Reg Latent: 0.07545..
#  Repulsive: 0.00004..
#  Memory: 144.29670..
#  Memory: 144.29670..
#  Output:
#  [[1493.086  1376.7467]
#  [5081.3193 4684.2734]
#  [2316.5227 2134.9712]]

# %%
# Report some tree stats.
leaves = ktree.get_leaves()
number_of_nodes = ktree.number_of_nodes

height = max([len(leaf.index) for leaf in leaves])
print(f"Tree height is {height}.")

leaf_sizes = [len(leaf.data) for leaf in leaves]
print(f"Created {len(leaves)} leaves with sizes")
print(leaf_sizes)
print(number_of_nodes)
# Out:
# Tree height is 5.
# Created 18 leaves with sizes
# [917, 1246, 1636, 132, 201, 177, 109, 196, 289, 294, 280, 276, 872, 393, 161, 373, 1342, 1105]
# 28

# %%
from src.utils import accuracy as acc


k = [1,2,5,10,100,500,1000]

for different_k in k:
    print(f"Current k is: {different_k}")
    acc.random_queries(ktree, k = different_k)
# Out:
# Current k is: 1
# The number of queries per layer are:
# [300. 285.  80.  24.]
# The percentage of correct predictions per layer is:
# [95.         79.33333333 78.33333333 78.33333333]
# The number of queries per layer are:
# [300. 286.  77.  21.]
# The percentage of correct predictions per layer is:
# [95.33333333 75.66666667 73.33333333 73.33333333]
# The number of queries per layer are:
# [300. 292.  88.  36.]
# The percentage of correct predictions per layer is:
# [97.33333333 82.         79.66666667 79.        ]
# The number of queries per layer are:
# [300. 285.  78.  25.]
# The percentage of correct predictions per layer is:
# [95.         80.         78.33333333 78.33333333]
# The mean percentage of correct predictions per layer is:
# [95.66666667 79.25       77.41666667 77.25      ]
# Current k is: 2
# The number of queries per layer are:
# [300. 288.  80.  24.]
# The percentage of correct predictions per layer is:
# [96.         80.66666667 80.         80.        ]
# The number of queries per layer are:
# [300. 287.  78.  26.]
# The percentage of correct predictions per layer is:
# [95.66666667 76.66666667 76.         76.        ]
# The number of queries per layer are:
# [300. 293.  88.  36.]
# The percentage of correct predictions per layer is:
# [97.66666667 83.66666667 81.33333333 80.66666667]
# The number of queries per layer are:
# [300. 286.  78.  26.]
# The percentage of correct predictions per layer is:
# [95.33333333 80.66666667 79.66666667 79.66666667]
# The mean percentage of correct predictions per layer is:
# [96.16666667 80.41666667 79.25       79.08333333]
# Current k is: 5
# The number of queries per layer are:
# [300. 293.  82.  26.]
# The percentage of correct predictions per layer is:
# [97.66666667 83.         82.33333333 82.33333333]
# The number of queries per layer are:
# [300. 288.  78.  26.]
# The percentage of correct predictions per layer is:
# [96.         78.33333333 77.66666667 77.66666667]
# The number of queries per layer are:
# [300. 294.  88.  38.]
# The percentage of correct predictions per layer is:
# [98.         85.         83.33333333 83.        ]
# The number of queries per layer are:
# [300. 289.  78.  27.]
# The percentage of correct predictions per layer is:
# [96.33333333 84.         83.66666667 83.66666667]
# The mean percentage of correct predictions per layer is:
# [97.         82.58333333 81.75       81.66666667]
# Current k is: 10
# The number of queries per layer are:
# [300. 294.  82.  26.]
# The percentage of correct predictions per layer is:
# [98.         84.33333333 83.66666667 83.66666667]
# The number of queries per layer are:
# [300. 291.  78.  27.]
# The percentage of correct predictions per layer is:
# [97.         80.33333333 80.         80.        ]
# The number of queries per layer are:
# [300. 296.  88.  39.]
# The percentage of correct predictions per layer is:
# [98.66666667 86.66666667 85.33333333 85.        ]
# The number of queries per layer are:
# [300. 292.  78.  28.]
# The percentage of correct predictions per layer is:
# [97.33333333 85.         85.         85.        ]
# The mean percentage of correct predictions per layer is:
# [97.75       84.08333333 83.5        83.41666667]
# Current k is: 100
# The number of queries per layer are:
# [300. 296.  82.  26.]
# The percentage of correct predictions per layer is:
# [98.66666667 92.         92.         92.        ]
# The number of queries per layer are:
# [300. 298.  78.  27.]
# The percentage of correct predictions per layer is:
# [99.33333333 88.33333333 88.         88.        ]
# The number of queries per layer are:
# [300. 299.  89.  40.]
# The percentage of correct predictions per layer is:
# [99.66666667 93.33333333 93.33333333 93.33333333]
# The number of queries per layer are:
# [300. 299.  78.  28.]
# The percentage of correct predictions per layer is:
# [99.66666667 90.33333333 90.33333333 90.33333333]
# The mean percentage of correct predictions per layer is:
# [99.33333333 91.         90.91666667 90.91666667]
# Current k is: 500
# The number of queries per layer are:
# [300. 298.  82.  26.]
# The percentage of correct predictions per layer is:
# [99.33333333 99.         99.         99.        ]
# The number of queries per layer are:
# [300. 299.  78.  28.]
# The percentage of correct predictions per layer is:
# [99.66666667 99.66666667 99.66666667 99.66666667]
# The number of queries per layer are:
# [300. 300.  89.  40.]
# The percentage of correct predictions per layer is:
# [100. 100. 100. 100.]
# The number of queries per layer are:
# [300. 300.  78.  28.]
# The percentage of correct predictions per layer is:
# [100. 100. 100. 100.]
# The mean percentage of correct predictions per layer is:
# [99.75       99.66666667 99.66666667 99.66666667]
# Current k is: 1000
# The number of queries per layer are:
# [300. 300.  82.  26.]
# The percentage of correct predictions per layer is:
# [100. 100. 100. 100.]
# The number of queries per layer are:
# [300. 299.  78.  28.]
# The percentage of correct predictions per layer is:
# [99.66666667 99.66666667 99.66666667 99.66666667]
# The number of queries per layer are:
# [300. 300.  89.  40.]
# The percentage of correct predictions per layer is:
# [100. 100. 100. 100.]
# The number of queries per layer are:
# [300. 300.  78.  28.]
# The percentage of correct predictions per layer is:
# [100. 100. 100. 100.]
# The mean percentage of correct predictions per layer is:
# [99.91666667 99.91666667 99.91666667 99.91666667]

# %%
import numpy as np
import matplotlib.pyplot as plt
mean_acc_per_layer = np.zeros(height)
times=0
while times < 4:
    # now lets create randomly N points in the space 0-300, 0-300
    n = 300
    random_p = torch.zeros(n, 2)
    x_lim = [min(data[:, 0]), max(data[:, 0])]
    y_lim = [min(data[:, 1]), max(data[:, 1])]


    for i in range(n):
        random_p[i] = torch.Tensor([np.random.randint(x_lim[0],x_lim[1]), np.random.randint(y_lim[0],y_lim[1])])
        
    infer_points = random_p.to(device)
    plt.scatter(infer_points[:,0], infer_points[:,1])

    correct_predictions_per_layer = np.zeros(height)
    accuracy_per_layer = np.zeros(height)

    qp = infer_points
    for i, query_point in enumerate(qp):
        preds_per_layer = ktree.query_verbose(query_point)["predictions per layer"]
        k_nearest_neighbors = ktree.root.query(query_point, k=1)

        for j, pred in enumerate(preds_per_layer):
            if any(np.array_equal(pred, k_nearest_neighbors[ki]) for ki in range(1)):
                correct_predictions_per_layer[j] += 1

    accuracy_per_layer = correct_predictions_per_layer / len(infer_points) * 100
    mean_acc_per_layer += accuracy_per_layer
    times += 1
    print(f"The percentage of correct predictions per layer is: ")
    print(accuracy_per_layer)

print(f"The mean percentage of correct predictions is: ")
print(mean_acc_per_layer/times)
# Out:
# The percentage of correct predictions per layer is:
# [0. 0. 0. 0. 0. 0.]
# The percentage of correct predictions per layer is:
# [0. 0. 0. 0. 0. 0.]
# The percentage of correct predictions per layer is:
# [0. 0. 0. 0. 0. 0.]
# The percentage of correct predictions per layer is:
# [0. 0. 0. 0. 0. 0.]
# The mean percentage of correct predictions is:
# [0. 0. 0. 0. 0. 0.]

# %%
import numpy as np
import matplotlib.pyplot as plt
mean_acc_per_layer = np.zeros(height)
times=0
while times < 4:
    # now lets create randomly N points in the space 0-300, 0-300
    n = 300
    random_p = torch.zeros(n, 2)
    x_lim = [min(data[:, 0]), max(data[:, 0])]
    y_lim = [min(data[:, 1]), max(data[:, 1])]


    for i in range(n):
        random_p[i] = torch.Tensor([np.random.randint(x_lim[0],x_lim[1]), np.random.randint(y_lim[0],y_lim[1])])
        
    infer_points = random_p.to(device)
    plt.scatter(infer_points[:,0], infer_points[:,1])

    correct_predictions_per_layer = np.zeros(height)
    accuracy_per_layer = np.zeros(height)

    qp = infer_points
    for i, query_point in enumerate(qp):
        preds_per_layer = ktree.query_verbose(query_point)["predictions per layer"]
        k_nearest_neighbors = ktree.root.query(query_point, k=2)

        for j, pred in enumerate(preds_per_layer):
            if any(np.array_equal(pred, k_nearest_neighbors[ki]) for ki in range(2)):
                correct_predictions_per_layer[j] += 1

    accuracy_per_layer = correct_predictions_per_layer / len(infer_points) * 100
    mean_acc_per_layer += accuracy_per_layer
    times += 1
    print(f"The percentage of correct predictions per layer is: ")
    print(accuracy_per_layer)

print(f"The mean percentage of correct predictions is: ")
print(mean_acc_per_layer/times)
# Out:
# The percentage of correct predictions per layer is:
# [0. 0. 0. 0. 0. 0.]
# The percentage of correct predictions per layer is:
# [0. 0. 0. 0. 0. 0.]
# The percentage of correct predictions per layer is:
# [0. 0. 0. 0. 0. 0.]
# The percentage of correct predictions per layer is:
# [0. 0. 0. 0. 0. 0.]
# The mean percentage of correct predictions is:
# [0. 0. 0. 0. 0. 0.]

# %%
import numpy as np
import matplotlib.pyplot as plt
mean_acc_per_layer = np.zeros(height)
times=0

while times < 1:
    nop =  500
    random_p = torch.zeros(nop, 2)
    x_lim = [min(data[:, 0]), max(data[:, 0])]
    y_lim = [min(data[:, 1]), max(data[:, 1])]
    num = int(np.sqrt(nop))
    for i, x in enumerate(np.linspace(x_lim[0],x_lim[1], num)):
        for j, y in enumerate(np.linspace(y_lim[0],y_lim[1], num)):
            random_p[i*num+j] = torch.Tensor([x, y])
    
    infer_points = random_p.to(device)
    plt.scatter(infer_points[:,0], infer_points[:,1])

    correct_predictions_per_layer = np.zeros(height)
    accuracy_per_layer = np.zeros(height)

    qp = infer_points
    for i, query_point in enumerate(qp):
        preds_per_layer = ktree.query_verbose(query_point)["predictions per layer"]
        brute_force = ktree.root.query(query_point)

        for j, pred in enumerate(preds_per_layer):
            if np.array_equal(pred, brute_force):
                correct_predictions_per_layer[j] += 1

    accuracy_per_layer = correct_predictions_per_layer / len(infer_points) * 100
    mean_acc_per_layer += accuracy_per_layer
    times += 1
    print(f"The percentage of correct predictions per layer is: ")
    print(accuracy_per_layer)

print(f"The mean percentage of correct predictions is: ")
print(mean_acc_per_layer/times)
# Out:
# The percentage of correct predictions per layer is:
# [94.  84.8 64.  54.4 20.2  2.4]
# The mean percentage of correct predictions is:
# [94.  84.8 64.  54.4 20.2  2.4]
