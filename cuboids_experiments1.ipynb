# %%
from itertools import product, combinations
import matplotlib.pyplot as plt
import numpy as np
from src import k_tree
from src.utils import data as dt
import torch
from src.k_tree import Ktree
from src.utils.data import loadData, loadData_3d
from src.metrics import Linf_3d

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
device = "cpu"
data, _ = loadData_3d(10000, 100)

learning_rate = 5e-3 # 1e-2, 5e-3
k = 3
teacher_args = {
    "optimizer_lr": learning_rate,
    "epochs": 400, # 300
    "times": 20,
    "alpha": 0.1, #  projection loss 0.1
    "beta": 0.1, # latent loss 0.1
    "gamma": 0.01, # repulsive loss 0.01
    #"gamma": 0.4, # repulsive loss 0.01
    "delta": 0.2, # fuzzy scale 0.01
    "f_clk": 10, # 20
    "scale": 1, # fuzzy scale 
    "scale_flag": False,
    "number_of_centroids": k,
    "latent_size": 200,
    "encoder_activation": False,
    "encoder_depth": 5,
    "predictor_width": 5*100,
    "predictor_depth": 5,
}
n = 20
un_args = {
    "N": n,
    "M": n**3-1, # 10000 - 1
    "epsilon": 0.15 # here a layer value should be somehow included. As layers get denser  epilson should be smaller
}
student_args = {
    "optimizer_lr": 5e-3,
    "epochs": 3000, # 30000, 3000
    "width": 200,
    "depth": 5,
}

thresshold = k * 100
ktree = Ktree(thresshold, data, Linf_3d, teacher_args, un_args, student_args, device, 3)
ktree.create_tree(plot=False)
# Out:
# Loading data...
# Data loaded.
#
# ====================
# Creating student for node 0 that has 9999 data, which is more than the threshold 300.
# Bounding box for node 0: [[-6, 4007], [-8, 4007], [-8, 4008]]
# Creating teacher for node 0 with 3 centroids.
# ====================
# Training Teacher Model
# Shuffling data
# ====================
# Epoch: 20/400..
#  Training loss: 1565.29382..
#  torch.mean(F): 1564.92712..
#  Reg Proj: 0.00000..
#  Reg Latent: 0.36656..
#  Repulsive: 0.00008..
#  Memory: 312.98542..
#  Memory: 312.98542..
#  Output:
#  [[ 733.1857  1244.3877   520.14856]
#  [1393.0173  2385.347   1006.71606]
#  [1719.3788  3115.3877  1299.8488 ]]
# ====================
# Epoch: 40/400..
#  Training loss: 2885.81494..
#  torch.mean(F): 2885.67871..
#  Reg Proj: 0.00000..
#  Reg Latent: 0.13485..
#  Repulsive: 0.00157..
#  Memory: 577.13574..
#  Memory: 577.13574..
#  Output:
#  [[ 76.93006   67.429     83.85921 ]
#  [182.79964  137.96019  133.5457  ]
#  [ 48.616875  50.16146   61.205917]]
# ====================
# Epoch: 60/400..
#  Training loss: 2422.77661..
#  torch.mean(F): 2422.65186..
#  Reg Proj: 0.00000..
#  Reg Latent: 0.12459..
#  Repulsive: 0.00036..
#  Memory: 484.53037..
#  Memory: 484.53037..
#  Output:
#  [[859.92926 427.63522 598.1737 ]
#  [733.3158  377.24445 537.0754 ]
#  [319.1099  167.66264 250.00555]]
# ====================
# Epoch: 80/400..
#  Training loss: 2836.39429..
#  torch.mean(F): 2836.25391..
#  Reg Proj: 0.00000..
#  Reg Latent: 0.13940..
#  Repulsive: 0.00109..
#  Memory: 567.25078..
#  Memory: 567.25078..
#  Output:
#  [[ 78.98188   34.48483   14.272712]
#  [179.59813   64.322205  53.82795 ]
#  [229.95985   95.88112   56.038956]]
# ====================
# Epoch: 100/400..
#  Training loss: 1336.98096..
#  torch.mean(F): 1336.82764..
#  Reg Proj: 0.00000..
#  Reg Latent: 0.15313..
#  Repulsive: 0.00019..
#  Memory: 267.36553..
#  Memory: 267.36553..
#  Output:
#  [[1207.0098   997.87695 1096.7405 ]
#  [2547.357   2223.7124  2515.998  ]
#  [2694.5964  2377.8972  2710.85   ]]
# ====================
# Epoch: 120/400..
#  Training loss: 2112.90796..
#  torch.mean(F): 2112.76294..
#  Reg Proj: 0.00000..
#  Reg Latent: 0.14491..
#  Repulsive: 0.00012..
#  Memory: 422.55259..
#  Memory: 422.55259..
#  Output:
#  [[ 305.1036    500.71274   777.2874  ]
#  [ 569.8666    901.4894   1426.976   ]
#  [  39.899494   72.45985   129.58107 ]]
# ====================
# Epoch: 140/400..
#  Training loss: 2538.27393..
#  torch.mean(F): 2538.10889..
#  Reg Proj: 0.00000..
#  Reg Latent: 0.16427..
#  Repulsive: 0.00067..
#  Memory: 507.62178..
#  Memory: 507.62178..
#  Output:
#  [[360.03537 567.0554  447.79865]
#  [109.27792 229.81563 190.8798 ]
#  [297.50674 539.69543 438.75308]]
# ====================
# Epoch: 160/400..
#  Training loss: 1636.45288..
#  torch.mean(F): 1636.28003..
#  Reg Proj: 0.00000..
#  Reg Latent: 0.17276..
#  Repulsive: 0.00007..
#  Memory: 327.25601..
#  Memory: 327.25601..
#  Output:
#  [[1596.0085  1946.9143   745.3079 ]
#  [ 256.46042  535.9128   150.15326]
#  [1796.2456  2785.8394   921.49243]]
# ====================
# Epoch: 180/400..
#  Training loss: 2360.56348..
#  torch.mean(F): 2360.40723..
#  Reg Proj: 0.00000..
#  Reg Latent: 0.15566..
#  Repulsive: 0.00047..
#  Memory: 472.08145..
#  Memory: 472.08145..
#  Output:
#  [[1086.4636  1167.4552    77.59369]
#  [ 857.6546   924.20605   18.73863]
#  [ 759.8021   817.86926  133.05255]]
# ====================
# Epoch: 200/400..
#  Training loss: 2097.45239..
#  torch.mean(F): 2097.29712..
#  Reg Proj: 0.00000..
#  Reg Latent: 0.15481..
#  Repulsive: 0.00038..
#  Memory: 419.45942..
#  Memory: 419.45942..
#  Output:
#  [[1207.2225   474.44543 1052.3243 ]
#  [1053.4329   421.14328  912.4867 ]
#  [ 786.00964  311.31604  682.778  ]]
# ====================
# Epoch: 220/400..
#  Training loss: 2525.34131..
#  torch.mean(F): 2525.18115..
#  Reg Proj: 0.00000..
#  Reg Latent: 0.16020..
#  Repulsive: 0.00010..
#  Memory: 505.03623..
#  Memory: 505.03623..
#  Output:
#  [[  26.066582   15.308677  270.41858 ]
#  [ 244.75377   186.68257  1892.5449  ]
#  [ 174.1234    132.54857  1318.3014  ]]
# ====================
# Epoch: 240/400..
#  Training loss: 1825.20837..
#  torch.mean(F): 1824.90076..
#  Reg Proj: 0.00000..
#  Reg Latent: 0.30755..
#  Repulsive: 0.00008..
#  Memory: 364.98015..
#  Memory: 364.98015..
#  Output:
#  [[ 542.3114   255.80893  154.90726]
#  [2710.8816  1282.9377   771.578  ]
#  [1278.9912   605.23914  364.82242]]
# ====================
# Epoch: 260/400..
#  Training loss: 1485.39600..
#  torch.mean(F): 1484.92212..
#  Reg Proj: 0.00000..
#  Reg Latent: 0.47378..
#  Repulsive: 0.00009..
#  Memory: 296.98442..
#  Memory: 296.98442..
#  Output:
#  [[ 423.7875   335.9211   620.1151 ]
#  [1873.3793  1508.3402  2739.4568 ]
#  [ 772.51843  620.2583  1127.8173 ]]
# ====================
# Epoch: 280/400..
#  Training loss: 2734.92358..
#  torch.mean(F): 2734.52832..
#  Reg Proj: 0.00000..
#  Reg Latent: 0.39479..
#  Repulsive: 0.00054..
#  Memory: 546.90566..
#  Memory: 546.90566..
#  Output:
#  [[138.6568  351.80057 137.82797]
#  [ 64.20435 169.6678   64.33445]
#  [174.46498 462.244   168.56342]]
# ====================
# Epoch: 300/400..
#  Training loss: 1951.15991..
#  torch.mean(F): 1950.76892..
#  Reg Proj: 0.00000..
#  Reg Latent: 0.39026..
#  Repulsive: 0.00074..
#  Memory: 390.15378..
#  Memory: 390.15378..
#  Output:
#  [[ 863.1063  1857.696    936.0444 ]
#  [ 338.5218   733.23376  367.84293]
#  [ 841.5571  1813.6283   922.44617]]
# ====================
# Epoch: 320/400..
#  Training loss: 2928.71240..
#  torch.mean(F): 2928.53320..
#  Reg Proj: 0.00000..
#  Reg Latent: 0.16318..
#  Repulsive: 0.01609..
#  Memory: 585.70664..
#  Memory: 585.70664..
#  Output:
#  [[55.8207    53.283672  13.433863 ]
#  [32.502724  26.773613   4.130215 ]
#  [31.172462  28.957552   2.5384295]]
# ====================
# Epoch: 340/400..
#  Training loss: 2961.03149..
#  torch.mean(F): 2960.88208..
#  Reg Proj: 0.00000..
#  Reg Latent: 0.14685..
#  Repulsive: 0.00232..
#  Memory: 592.17642..
#  Memory: 592.17642..
#  Output:
#  [[60.11631  13.101404 28.060608]
#  [41.62478  36.14614  18.992104]
#  [97.49522  74.99921  49.393738]]
# ====================
# Epoch: 360/400..
#  Training loss: 2691.11157..
#  torch.mean(F): 2690.95703..
#  Reg Proj: 0.00000..
#  Reg Latent: 0.15198..
#  Repulsive: 0.00235..
#  Memory: 538.19141..
#  Memory: 538.19141..
#  Output:
#  [[286.71497 283.47308 173.90988]
#  [279.41888 266.2085  163.42322]
#  [377.64224 373.9023  230.1496 ]]
# ====================
# Epoch: 380/400..
#  Training loss: 1824.78064..
#  torch.mean(F): 1824.61523..
#  Reg Proj: 0.00000..
#  Reg Latent: 0.16530..
#  Repulsive: 0.00016..
#  Memory: 364.92305..
#  Memory: 364.92305..
#  Output:
#  [[ 708.49445  291.69052  465.2549 ]
#  [2052.4602   808.62286 1341.0084 ]
#  [ 969.63525  381.34116  640.9157 ]]
# ====================
# Epoch: 400/400..
#  Training loss: 2665.23315..
#  torch.mean(F): 2665.09668..
#  Reg Proj: 0.00000..
#  Reg Latent: 0.13584..
#  Repulsive: 0.00082..
#  Memory: 533.01934..
#  Memory: 533.01934..
#  Output:
#  [[325.83017 411.05783 314.35175]
#  [213.13242 272.89835 184.42592]
#  [166.78046 206.8139  180.37332]]
# ====================
# getUncertaintyArea
# Ouputs are [[1383.8741 1517.7677 1501.8116]
#  [2501.0112 2727.9155 2719.3013]
#  [1222.1532 1354.0276 1323.2926]]
# scale is 4016
# dx is 4013.0, dy is 4015.0, dz is 4016.0
# z is torch.Size([8000])
# Processing...
# flag is 3575
# m is 4426
# i is 8000
# Labeled 0/4426 points.
# Labeled 1000/4426 points.
# Labeled 2000/4426 points.
# Labeled 3000/4426 points.
# Labeled 4000/4426 points.
# Labeled all 4426/4426 points.
# Creating student for node 0 with 3 centroids.
# Device is: cpu
# ====================
# Training Student Model
# Acc:  0.25485765928603704
# Epoch:  0 Cost:  3191.325439453125
# Acc:  0.7790329868956168
# Epoch:  300 Cost:  59.803016662597656
# Acc:  0.7971079981924989
# Epoch:  600 Cost:  51.235877990722656
# Acc:  0.8671486669679168
# Epoch:  900 Cost:  35.99205017089844
# Acc:  0.7794848621780388
# Epoch:  1200 Cost:  40.581905364990234
# Acc:  0.868278355173972
# Epoch:  1500 Cost:  27.771265029907227
# Acc:  0.8210573881608676
# Epoch:  1800 Cost:  33.323795318603516
# Acc:  0.7022141888838681
# Epoch:  2100 Cost:  69.14567565917969
# Acc:  0.8429733393583371
# Epoch:  2400 Cost:  57.5500602722168
# Acc:  0.824672390420244
# Epoch:  2700 Cost:  50.19497299194336
#
# ====================
# Creating student for node 00 that has 3728 data, which is more than the threshold 300.
# Bounding box for node 00: [[-6, 4000], [-8, 4006], [-7, 4002]]
# Creating teacher for node 00 with 3 centroids.
# ====================
# Training Teacher Model
# Shuffling data
# ====================
# Epoch: 20/400..
#  Training loss: 2860.53760..
#  torch.mean(F): 2851.03760..
#  Reg Proj: 9.33386..
#  Reg Latent: 0.16489..
#  Repulsive: 0.00114..
#  Memory: 570.20752..
#  Memory: 570.20752..
#  Output:
#  [[-32.369495 -21.19914   -8.061031]
#  [ 99.605316  72.55134   25.232857]
#  [ 38.604824  29.745855   9.448605]]
# ====================
# Epoch: 40/400..
#  Training loss: 2562.04810..
#  torch.mean(F): 2551.03809..
#  Reg Proj: 10.80710..
#  Reg Latent: 0.20275..
#  Repulsive: 0.00034..
#  Memory: 510.20762..
#  Memory: 510.20762..
#  Output:
#  [[ 22.302427  37.054497  98.2774  ]
#  [183.67844  295.6909   710.3522  ]
#  [142.64572  231.26067  580.3289  ]]
# ====================
# Epoch: 60/400..
#  Training loss: 1335.45789..
#  torch.mean(F): 1334.12146..
#  Reg Proj: 1.18659..
#  Reg Latent: 0.14951..
#  Repulsive: 0.00020..
#  Memory: 266.82429..
#  Memory: 266.82429..
#  Output:
#  [[1485.9197 1059.6094  889.6179]
#  [2072.37   1480.1826 1243.1449]
#  [2332.166  1658.3474 1393.2798]]
# ====================
# Epoch: 80/400..
#  Training loss: 2719.16919..
#  torch.mean(F): 2708.04834..
#  Reg Proj: 10.78797..
#  Reg Latent: 0.33082..
#  Repulsive: 0.00189..
#  Memory: 541.60967..
#  Memory: 541.60967..
#  Output:
#  [[140.86063 285.60043 198.87555]
#  [105.93492 206.78351 150.45438]
#  [ 91.13939 182.09276 128.53154]]
# ====================
# Epoch: 100/400..
#  Training loss: 2730.96899..
#  torch.mean(F): 2723.13110..
#  Reg Proj: 7.56399..
#  Reg Latent: 0.27334..
#  Repulsive: 0.00045..
#  Memory: 544.62622..
#  Memory: 544.62622..
#  Output:
#  [[-15.913003 -64.067795 349.31067 ]
#  [-20.303053 -93.73495  895.609   ]
#  [-15.627803 -84.48059  982.0785  ]]
# ====================
# Epoch: 120/400..
#  Training loss: 2400.09790..
#  torch.mean(F): 2389.17969..
#  Reg Proj: 10.68196..
#  Reg Latent: 0.22274..
#  Repulsive: 0.01376..
#  Memory: 477.83594..
#  Memory: 477.83594..
#  Output:
#  [[235.41515 710.4116  596.96716]
#  [196.80898 623.4843  524.7914 ]
#  [196.76239 625.782   526.6184 ]]
# ====================
# Epoch: 140/400..
#  Training loss: 2282.90356..
#  torch.mean(F): 2272.49365..
#  Reg Proj: 10.25766..
#  Reg Latent: 0.15116..
#  Repulsive: 0.00127..
#  Memory: 454.49873..
#  Memory: 454.49873..
#  Output:
#  [[656.6792  452.63303 650.4436 ]
#  [738.0591  503.13632 725.14606]
#  [783.1776  532.87134 768.2219 ]]
# ====================
# Epoch: 160/400..
#  Training loss: 2886.54688..
#  torch.mean(F): 2875.04663..
#  Reg Proj: 11.16606..
#  Reg Latent: 0.33003..
#  Repulsive: 0.00419..
#  Memory: 575.00933..
#  Memory: 575.00933..
#  Output:
#  [[ 35.40355    7.236806  19.18076 ]
#  [135.59258   12.954913  37.94988 ]
#  [143.8864    15.658942  44.596283]]
# ====================
# Epoch: 180/400..
#  Training loss: 2857.98779..
#  torch.mean(F): 2847.92480..
#  Reg Proj: 9.78174..
#  Reg Latent: 0.27950..
#  Repulsive: 0.00176..
#  Memory: 569.58496..
#  Memory: 569.58496..
#  Output:
#  [[  3.448142   100.083275     0.59317434]
#  [ 25.612991   167.3874       5.535604  ]
#  [ 27.796833   197.25803      6.042511  ]]
# ====================
# Epoch: 200/400..
#  Training loss: 3200.27368..
#  torch.mean(F): 3088.28369..
#  Reg Proj: 111.15164..
#  Reg Latent: 0.83528..
#  Repulsive: 0.00318..
#  Memory: 617.65674..
#  Memory: 617.65674..
#  Output:
#  [[ 1.84197693e+03  5.53891895e+03 -1.14847526e-01]
#  [ 1.54537878e+03  4.64481641e+03  1.15619816e-01]
#  [ 1.83965576e+03  5.52928809e+03  2.42490806e-02]]
# ====================
# Epoch: 220/400..
#  Training loss: 2882.30103..
#  torch.mean(F): 2871.01904..
#  Reg Proj: 11.04553..
#  Reg Latent: 0.23417..
#  Repulsive: 0.00238..
#  Memory: 574.20381..
#  Memory: 574.20381..
#  Output:
#  [[-1.74458206e-01  8.99671402e+01  6.28803978e+01]
#  [ 5.17876297e-02  1.23784676e+02  8.67916946e+01]
#  [-3.07485908e-02  1.53115662e+02  1.07332428e+02]]
# ====================
# Epoch: 240/400..
#  Training loss: 2654.15747..
#  torch.mean(F): 2644.91992..
#  Reg Proj: 8.99128..
#  Reg Latent: 0.24530..
#  Repulsive: 0.00095..
#  Memory: 528.98398..
#  Memory: 528.98398..
#  Output:
#  [[484.42526   33.2395   160.27194 ]
#  [539.21234   34.340427 179.52995 ]
#  [664.9711    50.06328  221.33813 ]]
# ====================
# Epoch: 260/400..
#  Training loss: 2777.88623..
#  torch.mean(F): 2774.17334..
#  Reg Proj: 3.56881..
#  Reg Latent: 0.14328..
#  Repulsive: 0.00073..
#  Memory: 554.83467..
#  Memory: 554.83467..
#  Output:
#  [[-7.6190162e-01 -7.6190162e-01  6.1764929e+02]
#  [-4.3944873e-02 -4.3944873e-02  5.3785956e+02]
#  [-2.5899190e-01 -2.5899190e-01  3.9712967e+02]]
# ====================
# Epoch: 280/400..
#  Training loss: 2786.23535..
#  torch.mean(F): 2778.66357..
#  Reg Proj: 7.42141..
#  Reg Latent: 0.14626..
#  Repulsive: 0.00424..
#  Memory: 555.73271..
#  Memory: 555.73271..
#  Output:
#  [[ 4.8954556e+02  1.7541376e+01 -9.5667511e-01]
#  [ 5.5700391e+02  2.0558056e+01 -3.1606190e-02]
#  [ 4.8073773e+02  1.7793894e+01 -3.4979150e-01]]
# ====================
# Epoch: 300/400..
#  Training loss: 2783.24878..
#  torch.mean(F): 2772.30200..
#  Reg Proj: 10.80085..
#  Reg Latent: 0.14511..
#  Repulsive: 0.00104..
#  Memory: 554.46040..
#  Memory: 554.46040..
#  Output:
#  [[ 72.36645   36.718834 239.28534 ]
#  [ 86.246445  44.003643 284.047   ]
#  [129.4859    65.9845   426.8293  ]]
# ====================
# Epoch: 320/400..
#  Training loss: 2461.18091..
#  torch.mean(F): 2450.18018..
#  Reg Proj: 10.82043..
#  Reg Latent: 0.18021..
#  Repulsive: 0.00030..
#  Memory: 490.03604..
#  Memory: 490.03604..
#  Output:
#  [[599.3399   470.63245  384.1361  ]
#  [ 91.07987   71.52401   58.385094]
#  [365.2916   286.43124  233.64597 ]]
# ====================
# Epoch: 340/400..
#  Training loss: 2591.26001..
#  torch.mean(F): 2581.51489..
#  Reg Proj: 9.49294..
#  Reg Latent: 0.25186..
#  Repulsive: 0.00017..
#  Memory: 516.30298..
#  Memory: 516.30298..
#  Output:
#  [[ 8.15810181e+02  1.50469086e+02  1.24315506e+02]
#  [-7.33819656e+01 -3.30717111e+00 -5.68699241e-01]
#  [ 3.20274078e+02  6.43531952e+01  5.43025093e+01]]
# ====================
# Epoch: 360/400..
#  Training loss: 2504.79932..
#  torch.mean(F): 2494.48413..
#  Reg Proj: 10.04606..
#  Reg Latent: 0.26871..
#  Repulsive: 0.00019..
#  Memory: 498.89683..
#  Memory: 498.89683..
#  Output:
#  [[780.2      250.42764  371.3182  ]
#  [-37.685387 -12.764623 -16.585497]
#  [323.81918  103.57932  154.96228 ]]
# ====================
# Epoch: 380/400..
#  Training loss: 1350.35132..
#  torch.mean(F): 1345.82715..
#  Reg Proj: 4.23128..
#  Reg Latent: 0.29275..
#  Repulsive: 0.00007..
#  Memory: 269.16543..
#  Memory: 269.16543..
#  Output:
#  [[2085.5044  2905.101   1763.8541 ]
#  [ 589.7253   808.0522   513.19086]
#  [1505.0631  2085.1318  1285.2538 ]]
# ====================
# Epoch: 400/400..
#  Training loss: 2773.80713..
#  torch.mean(F): 2762.61914..
#  Reg Proj: 10.78141..
#  Reg Latent: 0.40268..
#  Repulsive: 0.00399..
#  Memory: 552.52383..
#  Memory: 552.52383..
#  Output:
#  [[110.33033 147.9994  209.47218]
#  [ 84.89174 109.05769 179.41971]
#  [ 95.20499 124.44408 194.45265]]
# ====================
# getUncertaintyArea
# Ouputs are [[1485.9197 1059.6094  889.6179]
#  [2072.37   1480.1826 1243.1449]
#  [2332.166  1658.3474 1393.2798]]
# scale is 4014
# dx is 4006.0, dy is 4014.0, dz is 4009.0
# z is torch.Size([8000])
# Processing...
# flag is 1535
# m is 6466
# i is 8000
# Labeled 0/6466 points.
# Labeled 1000/6466 points.
# Labeled 2000/6466 points.
# Labeled 3000/6466 points.
# Labeled 4000/6466 points.
# Labeled 5000/6466 points.
# Labeled 6000/6466 points.
# Labeled all 6466/6466 points.
# Creating student for node 00 with 3 centroids.
# Device is: cpu
# ====================
# Training Student Model
# Acc:  0.5262913702443551
# Epoch:  0 Cost:  866.2225952148438
# Acc:  0.7554902567274977
# Epoch:  300 Cost:  50.395904541015625
# Acc:  0.892514692236313
# Epoch:  600 Cost:  30.492481231689453
# Acc:  0.7834828332817816
# Epoch:  900 Cost:  44.163726806640625
# Acc:  0.8229198886483142
# Epoch:  1200 Cost:  32.71229934692383
# Acc:  0.9226724404577792
# Epoch:  1500 Cost:  24.275833129882812
# Acc:  0.7278069904113826
# Epoch:  1800 Cost:  100.3896255493164
# Acc:  0.831580575317043
# Epoch:  2100 Cost:  36.863948822021484
# Acc:  0.903340550572224
# Epoch:  2400 Cost:  27.385801315307617
# Acc:  0.9263841633158058
# Epoch:  2700 Cost:  22.13658332824707
#
# ====================
# Creating student for node 01 that has 4602 data, which is more than the threshold 300.
# Bounding box for node 01: [[29, 4007], [125, 4007], [141, 4008]]
# Creating teacher for node 01 with 3 centroids.
# ====================
# Training Teacher Model
# Shuffling data
# ====================
# Epoch: 20/400..
#  Training loss: 1838.57739..
#  torch.mean(F): 1834.73938..
#  Reg Proj: 2.82612..
#  Reg Latent: 1.01169..
#  Repulsive: 0.00016..
#  Memory: 366.94788..
#  Memory: 366.94788..
#  Output:
#  [[2896.538   870.2211 1880.317 ]
#  [3440.1052 1046.6688 2267.6348]
#  [2462.5688  759.0715 1634.166 ]]
# ====================
# Epoch: 40/400..
#  Training loss: 2786.90967..
#  torch.mean(F): 2762.47803..
#  Reg Proj: 23.56460..
#  Reg Latent: 0.86672..
#  Repulsive: 0.00036..
#  Memory: 552.49561..
#  Memory: 552.49561..
#  Output:
#  [[ 410.7288   224.1449   836.466  ]
#  [ 454.81424  245.9564   953.3487 ]
#  [ 723.449    393.27057 1459.6212 ]]
# ====================
# Epoch: 60/400..
#  Training loss: 1409.51758..
#  torch.mean(F): 1403.64160..
#  Reg Proj: 5.56011..
#  Reg Latent: 0.31568..
#  Repulsive: 0.00030..
#  Memory: 280.72832..
#  Memory: 280.72832..
#  Output:
#  [[2012.9844 2189.9575 2810.687 ]
#  [1170.6484 1270.125  1628.0186]
#  [1238.4747 1357.8048 1747.9072]]
# ====================
# Epoch: 80/400..
#  Training loss: 2008.03845..
#  torch.mean(F): 1966.04211..
#  Reg Proj: 41.13768..
#  Reg Latent: 0.85855..
#  Repulsive: 0.00008..
#  Memory: 393.20842..
#  Memory: 393.20842..
#  Output:
#  [[1354.1185   541.18567  952.8525 ]
#  [4326.1724  1750.4453  3031.1467 ]
#  [4836.8003  1958.2194  3389.3635 ]]
# ====================
# Epoch: 100/400..
#  Training loss: 2547.68750..
#  torch.mean(F): 2526.04785..
#  Reg Proj: 20.86945..
#  Reg Latent: 0.76950..
#  Repulsive: 0.00065..
#  Memory: 505.20957..
#  Memory: 505.20957..
#  Output:
#  [[ 690.55707  719.13806  611.2504 ]
#  [ 977.54395 1019.39105  877.48047]
#  [1037.8439  1083.1328   935.56995]]
# ====================
# Epoch: 120/400..
#  Training loss: 1229.05273..
#  torch.mean(F): 1227.45288..
#  Reg Proj: 1.08922..
#  Reg Latent: 0.51011..
#  Repulsive: 0.00043..
#  Memory: 245.49058..
#  Memory: 245.49058..
#  Output:
#  [[2508.7803 2365.3281 2354.8613]
#  [2017.9476 1907.393  1902.6859]
#  [2120.4265 2006.2792 2002.3042]]
# ====================
# Epoch: 140/400..
#  Training loss: 2772.24390..
#  torch.mean(F): 2747.98730..
#  Reg Proj: 24.15309..
#  Reg Latent: 0.10260..
#  Repulsive: 0.00090..
#  Memory: 549.59746..
#  Memory: 549.59746..
#  Output:
#  [[626.79895 482.6769  734.6691 ]
#  [769.4135  592.01105 900.87775]
#  [695.9958  535.2435  814.35175]]
# ====================
# Epoch: 160/400..
#  Training loss: 2581.82324..
#  torch.mean(F): 2560.69409..
#  Reg Proj: 20.90845..
#  Reg Latent: 0.21966..
#  Repulsive: 0.00100..
#  Memory: 512.13882..
#  Memory: 512.13882..
#  Output:
#  [[ 966.03864 1047.743    626.9026 ]
#  [1103.8301  1197.6328   715.7721 ]
#  [1032.1185  1121.2141   669.4992 ]]
# ====================
# Epoch: 180/400..
#  Training loss: 3232.45825..
#  torch.mean(F): 3205.79468..
#  Reg Proj: 26.41513..
#  Reg Latent: 0.24625..
#  Repulsive: 0.00231..
#  Memory: 641.15894..
#  Memory: 641.15894..
#  Output:
#  [[127.21211 262.55295 471.61874]
#  [148.79706 299.65158 538.67664]
#  [138.55266 276.96478 498.4738 ]]
# ====================
# Epoch: 200/400..
#  Training loss: 2343.42773..
#  torch.mean(F): 2327.58154..
#  Reg Proj: 15.50778..
#  Reg Latent: 0.33701..
#  Repulsive: 0.00141..
#  Memory: 465.51631..
#  Memory: 465.51631..
#  Output:
#  [[1182.2058   811.3873   916.3441 ]
#  [1444.0852   994.52295 1125.1135 ]
#  [1418.4971   978.6394  1107.4125 ]]
# ====================
# Epoch: 220/400..
#  Training loss: 1283.65173..
#  torch.mean(F): 1282.84888..
#  Reg Proj: 0.00761..
#  Reg Latent: 0.79474..
#  Repulsive: 0.00061..
#  Memory: 256.56978..
#  Memory: 256.56978..
#  Output:
#  [[3252.2688 3072.803  2447.8022]
#  [2709.746  2555.6892 2036.7318]
#  [3311.682  3123.6567 2489.5178]]
# ====================
# Epoch: 240/400..
#  Training loss: 1691.26294..
#  torch.mean(F): 1687.91760..
#  Reg Proj: 2.97915..
#  Reg Latent: 0.36588..
#  Repulsive: 0.00041..
#  Memory: 337.58352..
#  Memory: 337.58352..
#  Output:
#  [[2509.0642 1567.4615 1729.0417]
#  [2101.2344 1319.1    1456.5308]
#  [2233.884  1403.8253 1549.6709]]
# ====================
# Epoch: 260/400..
#  Training loss: 2602.85791..
#  torch.mean(F): 2582.80908..
#  Reg Proj: 19.90819..
#  Reg Latent: 0.13823..
#  Repulsive: 0.00254..
#  Memory: 516.56182..
#  Memory: 516.56182..
#  Output:
#  [[1140.1737   716.72437  773.23627]
#  [1242.615    784.8611   845.10846]
#  [1155.9794   731.55164  787.04596]]
# ====================
# Epoch: 280/400..
#  Training loss: 1564.99634..
#  torch.mean(F): 1563.35852..
#  Reg Proj: 1.53131..
#  Reg Latent: 0.10612..
#  Repulsive: 0.00054..
#  Memory: 312.67170..
#  Memory: 312.67170..
#  Output:
#  [[1699.0127 2344.5317 1245.2174]
#  [2054.4495 2831.8296 1505.9552]
#  [2105.986  2902.644  1544.0707]]
# ====================
# Epoch: 300/400..
#  Training loss: 1194.30127..
#  torch.mean(F): 1193.50403..
#  Reg Proj: 0.70626..
#  Reg Latent: 0.09065..
#  Repulsive: 0.00026..
#  Memory: 238.70081..
#  Memory: 238.70081..
#  Output:
#  [[2492.3232 2494.2866 2571.3833]
#  [1895.3129 1895.6135 1953.6776]
#  [2281.814  2283.1123 2353.3647]]
# ====================
# Epoch: 320/400..
#  Training loss: 1856.06494..
#  torch.mean(F): 1846.52429..
#  Reg Proj: 9.42703..
#  Reg Latent: 0.11277..
#  Repulsive: 0.00089..
#  Memory: 369.30486..
#  Memory: 369.30486..
#  Output:
#  [[1318.7712 1310.4757 1230.5826]
#  [1699.9626 1688.4323 1585.7964]
#  [1360.4309 1350.0688 1268.4824]]
# ====================
# Epoch: 340/400..
#  Training loss: 1319.65198..
#  torch.mean(F): 1319.53564..
#  Reg Proj: 0.00166..
#  Reg Latent: 0.11401..
#  Repulsive: 0.00059..
#  Memory: 263.90713..
#  Memory: 263.90713..
#  Output:
#  [[2053.4958 3087.807  2362.2812]
#  [2225.9595 3344.4617 2561.3772]
#  [2137.311  3211.0547 2460.3687]]
# ====================
# Epoch: 360/400..
#  Training loss: 1527.55017..
#  torch.mean(F): 1523.82544..
#  Reg Proj: 3.61781..
#  Reg Latent: 0.10659..
#  Repulsive: 0.00032..
#  Memory: 304.76509..
#  Memory: 304.76509..
#  Output:
#  [[2382.987  3912.823  2650.7925]
#  [2229.6313 3649.2075 2477.3938]
#  [2523.2295 4127.923  2803.6582]]
# ====================
# Epoch: 380/400..
#  Training loss: 1163.80725..
#  torch.mean(F): 1163.70398..
#  Reg Proj: 0.00386..
#  Reg Latent: 0.09893..
#  Repulsive: 0.00043..
#  Memory: 232.74080..
#  Memory: 232.74080..
#  Output:
#  [[2884.3232 2723.0408 3015.003 ]
#  [2774.599  2619.4978 2900.47  ]
#  [2480.7896 2342.18   2593.253 ]]
# ====================
# Epoch: 400/400..
#  Training loss: 1337.38538..
#  torch.mean(F): 1337.28979..
#  Reg Proj: 0.00023..
#  Reg Latent: 0.09486..
#  Repulsive: 0.00050..
#  Memory: 267.45796..
#  Memory: 267.45796..
#  Output:
#  [[3234.387  3225.6106 3164.8962]
#  [3143.1428 3133.4348 3075.8967]
#  [2847.1265 2837.6587 2786.4578]]
# ====================
# getUncertaintyArea
# Ouputs are [[2102.2695 2562.1428 2501.2207]
#  [3230.3381 3241.8706 2654.9763]
#  [2162.405  2927.6323 2000.2014]]
# scale is 3978
# dx is 3978.0, dy is 3882.0, dz is 3867.0
# z is torch.Size([8000])
# Processing...
# flag is 4700
# m is 3301
# i is 8000
# Labeled 0/3301 points.
# Labeled 1000/3301 points.
# Labeled 2000/3301 points.
# Labeled 3000/3301 points.
# Labeled all 3301/3301 points.
# Creating student for node 01 with 3 centroids.
# Device is: cpu
# ====================
# Training Student Model
# Acc:  0.5001514692517419
# Epoch:  0 Cost:  763.3370361328125
# Acc:  0.7555286276885792
# Epoch:  300 Cost:  49.26633071899414
# Acc:  0.7985458951832778
# Epoch:  600 Cost:  44.70064163208008
# Acc:  0.8385337776431384
# Epoch:  900 Cost:  41.86711120605469
# Acc:  0.839139654650106
# Epoch:  1200 Cost:  37.264869689941406
# Acc:  0.8736746440472584
# Epoch:  1500 Cost:  32.87883377075195
# Acc:  0.8539836413208118
# Epoch:  1800 Cost:  31.472972869873047
# Acc:  0.8806422296273856
# Epoch:  2100 Cost:  30.28668785095215
# Acc:  0.8776128445925477
# Epoch:  2400 Cost:  28.395294189453125
# Acc:  0.8863980611935777
# Epoch:  2700 Cost:  26.809141159057617
#
# ====================
# Creating student for node 02 that has 1669 data, which is more than the threshold 300.
# Bounding box for node 02: [[-4, 2714], [-8, 2804], [-8, 2834]]
# Creating teacher for node 02 with 3 centroids.
# ====================
# Training Teacher Model
# Shuffling data
# ====================
# Epoch: 20/400..
#  Training loss: 865.68866..
#  torch.mean(F): 865.45691..
#  Reg Proj: 0.11172..
#  Reg Latent: 0.11987..
#  Repulsive: 0.00016..
#  Memory: 173.09138..
#  Memory: 173.09138..
#  Output:
#  [[ 628.5553  1127.3157   570.98926]
#  [1030.3588  1862.259    928.52454]
#  [ 436.11954  785.78296  395.1434 ]]
# ====================
# Epoch: 40/400..
#  Training loss: 1421.82056..
#  torch.mean(F): 1421.77405..
#  Reg Proj: 0.00002..
#  Reg Latent: 0.04498..
#  Repulsive: 0.00162..
#  Memory: 284.35481..
#  Memory: 284.35481..
#  Output:
#  [[377.8224  224.44868 360.3969 ]
#  [233.54088 138.56425 223.67845]
#  [259.2351  155.04793 249.6098 ]]
# ====================
# Epoch: 60/400..
#  Training loss: 1581.07886..
#  torch.mean(F): 1580.83655..
#  Reg Proj: 0.00002..
#  Reg Latent: 0.24076..
#  Repulsive: 0.00158..
#  Memory: 316.16731..
#  Memory: 316.16731..
#  Output:
#  [[232.52692  221.73868  125.05188 ]
#  [202.70859  200.49588  112.49018 ]
#  [111.61996  117.644745  65.484856]]
# ====================
# Epoch: 80/400..
#  Training loss: 1205.20056..
#  torch.mean(F): 1205.04919..
#  Reg Proj: 0.00002..
#  Reg Latent: 0.14802..
#  Repulsive: 0.00329..
#  Memory: 241.00984..
#  Memory: 241.00984..
#  Output:
#  [[963.9025  325.3128  548.0984 ]
#  [825.7298  279.89786 464.1223 ]
#  [815.29047 275.99005 456.12234]]
# ====================
# Epoch: 100/400..
#  Training loss: 1306.08398..
#  torch.mean(F): 1305.96265..
#  Reg Proj: 0.00002..
#  Reg Latent: 0.12009..
#  Repulsive: 0.00126..
#  Memory: 261.19253..
#  Memory: 261.19253..
#  Output:
#  [[642.81024 350.02646 643.40717]
#  [614.90753 331.65585 609.2713 ]
#  [472.12177 253.76959 466.3979 ]]
# ====================
# Epoch: 120/400..
#  Training loss: 946.33905..
#  torch.mean(F): 946.24548..
#  Reg Proj: 0.00009..
#  Reg Latent: 0.09246..
#  Repulsive: 0.00098..
#  Memory: 189.24910..
#  Memory: 189.24910..
#  Output:
#  [[797.96155 904.151   755.27765]
#  [764.9648  861.4237  728.81024]
#  [589.5662  662.4543  564.3631 ]]
# ====================
# Epoch: 140/400..
#  Training loss: 1310.88330..
#  torch.mean(F): 1310.81970..
#  Reg Proj: 0.00002..
#  Reg Latent: 0.06203..
#  Repulsive: 0.00154..
#  Memory: 262.16394..
#  Memory: 262.16394..
#  Output:
#  [[460.5922  258.33823 552.5718 ]
#  [433.51425 245.45314 519.6774 ]
#  [364.59424 207.40738 437.9527 ]]
# ====================
# Epoch: 160/400..
#  Training loss: 877.15027..
#  torch.mean(F): 877.09839..
#  Reg Proj: 0.00201..
#  Reg Latent: 0.04956..
#  Repulsive: 0.00029..
#  Memory: 175.41968..
#  Memory: 175.41968..
#  Output:
#  [[ 964.35425  814.12994  616.7734 ]
#  [1337.6099  1132.4786   863.2338 ]
#  [ 772.5633   653.3756   501.81387]]
# ====================
# Epoch: 180/400..
#  Training loss: 1197.07825..
#  torch.mean(F): 1197.03967..
#  Reg Proj: 0.00002..
#  Reg Latent: 0.03721..
#  Repulsive: 0.00137..
#  Memory: 239.40793..
#  Memory: 239.40793..
#  Output:
#  [[704.7063  370.19928 356.0251 ]
#  [747.6424  397.5151  378.91574]
#  [820.56323 436.44907 415.9308 ]]
# ====================
# Epoch: 200/400..
#  Training loss: 1143.71619..
#  torch.mean(F): 1143.68506..
#  Reg Proj: 0.00003..
#  Reg Latent: 0.02930..
#  Repulsive: 0.00179..
#  Memory: 228.73701..
#  Memory: 228.73701..
#  Output:
#  [[661.37787 518.92175 499.2616 ]
#  [688.22284 542.4803  520.7355 ]
#  [766.5101  589.9666  571.1517 ]]
# ====================
# Epoch: 220/400..
#  Training loss: 1481.26904..
#  torch.mean(F): 1481.23999..
#  Reg Proj: 0.00002..
#  Reg Latent: 0.02658..
#  Repulsive: 0.00239..
#  Memory: 296.24800..
#  Memory: 296.24800..
#  Output:
#  [[394.13095 132.73148 253.79556]
#  [299.92963 102.92272 193.47108]
#  [317.82297 111.02037 204.37973]]
# ====================
# Epoch: 240/400..
#  Training loss: 1504.83936..
#  torch.mean(F): 1504.78125..
#  Reg Proj: 0.00002..
#  Reg Latent: 0.05698..
#  Repulsive: 0.00114..
#  Memory: 300.95625..
#  Memory: 300.95625..
#  Output:
#  [[298.2911   204.95575  193.80626 ]
#  [ 39.682823  20.415808  28.2476  ]
#  [267.2707   171.20694  171.07492 ]]
# ====================
# Epoch: 260/400..
#  Training loss: 1602.04932..
#  torch.mean(F): 1602.02441..
#  Reg Proj: 0.00002..
#  Reg Latent: 0.02305..
#  Repulsive: 0.00185..
#  Memory: 320.40488..
#  Memory: 320.40488..
#  Output:
#  [[ 48.577423 111.92357   44.26352 ]
#  [ 37.541676  88.178795  36.110634]
#  [ 89.01239  202.98938   85.018456]]
# ====================
# Epoch: 280/400..
#  Training loss: 1195.67627..
#  torch.mean(F): 1195.65112..
#  Reg Proj: 0.00003..
#  Reg Latent: 0.02477..
#  Repulsive: 0.00038..
#  Memory: 239.13022..
#  Memory: 239.13022..
#  Output:
#  [[292.92337 104.08673 381.40622]
#  [694.0962  281.98788 912.9077 ]
#  [603.7206  244.82054 790.6353 ]]
# ====================
# Epoch: 300/400..
#  Training loss: 1349.76013..
#  torch.mean(F): 1349.74304..
#  Reg Proj: 0.00002..
#  Reg Latent: 0.01641..
#  Repulsive: 0.00074..
#  Memory: 269.94861..
#  Memory: 269.94861..
#  Output:
#  [[144.40094  76.63468 243.76979]
#  [371.02985 309.89093 594.4047 ]
#  [347.21045 258.66455 539.8585 ]]
# ====================
# Epoch: 320/400..
#  Training loss: 1487.12109..
#  torch.mean(F): 1487.10913..
#  Reg Proj: 0.00002..
#  Reg Latent: 0.01117..
#  Repulsive: 0.00068..
#  Memory: 297.42183..
#  Memory: 297.42183..
#  Output:
#  [[186.6967  235.60477 118.24229]
#  [257.61813 326.5197  164.19196]
#  [ 81.30806 100.06381  46.98883]]
# ====================
# Epoch: 340/400..
#  Training loss: 995.84033..
#  torch.mean(F): 995.75922..
#  Reg Proj: 0.00083..
#  Reg Latent: 0.07994..
#  Repulsive: 0.00033..
#  Memory: 199.15184..
#  Memory: 199.15184..
#  Output:
#  [[ 613.25555 1375.0798   934.0238 ]
#  [ 546.41534 1235.3932   833.3923 ]
#  [ 344.00946  754.52997  520.4532 ]]
# ====================
# Epoch: 360/400..
#  Training loss: 1430.31250..
#  torch.mean(F): 1429.62488..
#  Reg Proj: 0.63857..
#  Reg Latent: 0.04896..
#  Repulsive: 0.00015..
#  Memory: 285.92498..
#  Memory: 285.92498..
#  Output:
#  [[1732.4557     59.192326  150.61958 ]
#  [1186.4623     51.575962  107.7422  ]
#  [ 737.13025    50.127617   69.64324 ]]
# ====================
# Epoch: 380/400..
#  Training loss: 1191.03796..
#  torch.mean(F): 1190.97180..
#  Reg Proj: 0.00005..
#  Reg Latent: 0.06583..
#  Repulsive: 0.00035..
#  Memory: 238.19436..
#  Memory: 238.19436..
#  Output:
#  [[ 623.9098   282.85092  134.86902]
#  [ 510.29773  233.70114   76.67152]
#  [1312.47     639.45215  275.32278]]
# ====================
# Epoch: 400/400..
#  Training loss: 1050.12524..
#  torch.mean(F): 1050.07434..
#  Reg Proj: 0.00004..
#  Reg Latent: 0.05038..
#  Repulsive: 0.00043..
#  Memory: 210.01487..
#  Memory: 210.01487..
#  Output:
#  [[491.147   623.9153  490.5495 ]
#  [434.28082 841.14404 576.69086]
#  [671.8077  703.63226 578.3504 ]]
# ====================
# getUncertaintyArea
# Ouputs are [[ 771.7344   938.00336  920.7384 ]
#  [1118.379   1356.5182  1337.7887 ]
#  [ 622.9622   758.3314   747.47614]]
# scale is 2842
# dx is 2718.0, dy is 2812.0, dz is 2842.0
# z is torch.Size([8000])
# Processing...
# flag is 5190
# m is 2811
# i is 8000
# Labeled 0/2811 points.
# Labeled 1000/2811 points.
# Labeled 2000/2811 points.
# Labeled all 2811/2811 points.
# Creating student for node 02 with 3 centroids.
# Device is: cpu
# ====================
# Training Student Model
# Acc:  0.3877623621487015
# Epoch:  0 Cost:  2207.683349609375
# Acc:  0.640697260761295
# Epoch:  300 Cost:  83.43157196044922
# Acc:  0.4325862682319459
# Epoch:  600 Cost:  137.34751892089844
# Acc:  0.7958022056207755
# Epoch:  900 Cost:  41.11807632446289
# Acc:  0.8224831020988972
# Epoch:  1200 Cost:  36.577823638916016
# Acc:  0.8612593383137673
# Epoch:  1500 Cost:  29.41124725341797
# Acc:  0.856634649590893
# Epoch:  1800 Cost:  30.024921417236328
# Acc:  0.8939879046602632
# Epoch:  2100 Cost:  24.733388900756836
# Acc:  0.87940234791889
# Epoch:  2400 Cost:  26.820056915283203
# Acc:  0.6036997509782995
# Epoch:  2700 Cost:  72.36927795410156
#
# ====================
# Creating student for node 001 that has 1222 data, which is more than the threshold 300.
# Bounding box for node 001: [[-6, 3670], [-7, 3739], [-7, 3524]]
# Creating teacher for node 001 with 3 centroids.
# ====================
# Training Teacher Model
# Shuffling data
# ====================
# Epoch: 20/400..
#  Training loss: 2611.14648..
#  torch.mean(F): 2604.46875..
#  Reg Proj: 6.58300..
#  Reg Latent: 0.09423..
#  Repulsive: 0.00048..
#  Memory: 520.89375..
#  Memory: 520.89375..
#  Output:
#  [[ -68.472404  -61.38186  -143.24042 ]
#  [ 137.78125   123.52748   284.952   ]
#  [ -21.3377    -19.136469  -49.01533 ]]
# ====================
# Epoch: 40/400..
#  Training loss: 1625.81885..
#  torch.mean(F): 1622.11426..
#  Reg Proj: 3.63850..
#  Reg Latent: 0.06606..
#  Repulsive: 0.00005..
#  Memory: 324.42285..
#  Memory: 324.42285..
#  Output:
#  [[ 330.11182  1217.3604    308.2126  ]
#  [ 748.71173  2840.2969    697.03204 ]
#  [ -19.843775  -71.8151    -18.498379]]
# ====================
# Epoch: 60/400..
#  Training loss: 2141.61304..
#  torch.mean(F): 2136.11401..
#  Reg Proj: 5.42079..
#  Reg Latent: 0.07784..
#  Repulsive: 0.00018..
#  Memory: 427.22280..
#  Memory: 427.22280..
#  Output:
#  [[283.16357  940.3337   442.74036 ]
#  [199.29555  663.42865  312.      ]
#  [-23.878311 -78.934906 -37.317875]]
# ====================
# Epoch: 80/400..
#  Training loss: 1763.96130..
#  torch.mean(F): 1758.03149..
#  Reg Proj: 5.85595..
#  Reg Latent: 0.07352..
#  Repulsive: 0.00038..
#  Memory: 351.60630..
#  Memory: 351.60630..
#  Output:
#  [[1035.9235  1070.932    667.49036]
#  [ 939.6164   972.10596  607.14856]
#  [ 227.23415  236.09361  149.34108]]
# ====================
# Epoch: 100/400..
#  Training loss: 1435.34949..
#  torch.mean(F): 1433.17029..
#  Reg Proj: 2.12805..
#  Reg Latent: 0.05080..
#  Repulsive: 0.00031..
#  Memory: 286.63406..
#  Memory: 286.63406..
#  Output:
#  [[1184.0127   916.77875 1714.8187 ]
#  [1273.4417   988.2822  1844.3813 ]
#  [ 699.02057  558.84064 1013.17975]]
# ====================
# Epoch: 120/400..
#  Training loss: 1219.72949..
#  torch.mean(F): 1215.91296..
#  Reg Proj: 3.76057..
#  Reg Latent: 0.05575..
#  Repulsive: 0.00014..
#  Memory: 243.18259..
#  Memory: 243.18259..
#  Output:
#  [[1309.0984  1856.9081  1850.7003 ]
#  [ 496.44373  703.9455   701.59045]
#  [1014.468   1437.1412  1432.4457 ]]
# ====================
# Epoch: 140/400..
#  Training loss: 2161.57568..
#  torch.mean(F): 2155.77173..
#  Reg Proj: 5.75630..
#  Reg Latent: 0.04711..
#  Repulsive: 0.00042..
#  Memory: 431.15435..
#  Memory: 431.15435..
#  Output:
#  [[537.34845 438.93622 533.7158 ]
#  [201.41978 163.99776 199.4454 ]
#  [649.2358  534.3192  648.8046 ]]
# ====================
# Epoch: 160/400..
#  Training loss: 2230.25977..
#  torch.mean(F): 2224.28979..
#  Reg Proj: 5.93029..
#  Reg Latent: 0.03863..
#  Repulsive: 0.00128..
#  Memory: 444.85796..
#  Memory: 444.85796..
#  Output:
#  [[372.58862 499.66452 620.2766 ]
#  [190.41853 255.23112 316.791  ]
#  [389.13126 521.755   647.78876]]
# ====================
# Epoch: 180/400..
#  Training loss: 1230.70996..
#  torch.mean(F): 1228.26331..
#  Reg Proj: 2.40507..
#  Reg Latent: 0.04139..
#  Repulsive: 0.00030..
#  Memory: 245.65266..
#  Memory: 245.65266..
#  Output:
#  [[1495.825   1391.6907  1694.1191 ]
#  [ 801.117    745.5774   907.33453]
#  [1610.4048  1497.1687  1823.3469 ]]
# ====================
# Epoch: 200/400..
#  Training loss: 1590.64185..
#  torch.mean(F): 1587.99243..
#  Reg Proj: 2.60797..
#  Reg Latent: 0.04117..
#  Repulsive: 0.00028..
#  Memory: 317.59849..
#  Memory: 317.59849..
#  Output:
#  [[1152.5767  2187.4792   729.72205]
#  [ 917.00146 1740.3772   580.59436]
#  [ 823.48883 1556.4893   520.9612 ]]
# ====================
# Epoch: 220/400..
#  Training loss: 2435.63379..
#  torch.mean(F): 2429.49121..
#  Reg Proj: 6.10138..
#  Reg Latent: 0.03779..
#  Repulsive: 0.00336..
#  Memory: 485.89824..
#  Memory: 485.89824..
#  Output:
#  [[204.82684 209.20924 293.22217]
#  [239.03194 243.99463 341.28705]
#  [230.30359 234.23714 324.29855]]
# ====================
# Epoch: 240/400..
#  Training loss: 2084.13013..
#  torch.mean(F): 2079.92822..
#  Reg Proj: 4.11347..
#  Reg Latent: 0.08789..
#  Repulsive: 0.00047..
#  Memory: 415.98564..
#  Memory: 415.98564..
#  Output:
#  [[516.5063  316.5785  740.3739 ]
#  [645.65204 394.45563 944.83264]
#  [428.3426  266.29315 612.9422 ]]
# ====================
# Epoch: 260/400..
#  Training loss: 2636.63379..
#  torch.mean(F): 2629.71777..
#  Reg Proj: 6.85641..
#  Reg Latent: 0.05866..
#  Repulsive: 0.00092..
#  Memory: 525.94355..
#  Memory: 525.94355..
#  Output:
#  [[ -59.41378   -50.13948  -162.31523 ]
#  [ -41.94083   -35.27971  -114.39091 ]
#  [  71.614105   26.323729   68.089294]]
# ====================
# Epoch: 280/400..
#  Training loss: 2685.37378..
#  torch.mean(F): 2679.35327..
#  Reg Proj: 5.98228..
#  Reg Latent: 0.03604..
#  Repulsive: 0.00211..
#  Memory: 535.87065..
#  Memory: 535.87065..
#  Output:
#  [[-35.928013 -40.374905 -33.193882]
#  [105.07391   94.27922   92.054825]
#  [ 86.87097   79.98427   76.69901 ]]
# ====================
# Epoch: 300/400..
#  Training loss: 1292.59631..
#  torch.mean(F): 1287.47168..
#  Reg Proj: 5.10092..
#  Reg Latent: 0.02336..
#  Repulsive: 0.00042..
#  Memory: 257.49434..
#  Memory: 257.49434..
#  Output:
#  [[ 863.82367 1218.8005   961.6637 ]
#  [1193.3319  1690.4514  1333.0483 ]
#  [ 785.17175 1120.1632   882.3796 ]]
# ====================
# Epoch: 320/400..
#  Training loss: 2578.29883..
#  torch.mean(F): 2571.10913..
#  Reg Proj: 7.15188..
#  Reg Latent: 0.03110..
#  Repulsive: 0.00686..
#  Memory: 514.22183..
#  Memory: 514.22183..
#  Output:
#  [[237.71309  128.32353   64.28425 ]
#  [208.12392  112.62823   56.100834]
#  [231.11035  124.77633   62.381706]]
# ====================
# Epoch: 340/400..
#  Training loss: 2031.05945..
#  torch.mean(F): 2025.03210..
#  Reg Proj: 5.99085..
#  Reg Latent: 0.03573..
#  Repulsive: 0.00079..
#  Memory: 405.00642..
#  Memory: 405.00642..
#  Output:
#  [[785.7453  572.76105 578.1519 ]
#  [570.01385 417.8623  419.42337]
#  [514.21606 377.2653  377.36038]]
# ====================
# Epoch: 360/400..
#  Training loss: 2124.96265..
#  torch.mean(F): 2119.27173..
#  Reg Proj: 5.66229..
#  Reg Latent: 0.02753..
#  Repulsive: 0.00103..
#  Memory: 423.85435..
#  Memory: 423.85435..
#  Output:
#  [[330.89832 737.2623  359.93625]
#  [419.358   990.1235  460.8164 ]
#  [300.02728 700.0108  328.99072]]
# ====================
# Epoch: 380/400..
#  Training loss: 2521.06079..
#  torch.mean(F): 2514.95142..
#  Reg Proj: 6.07187..
#  Reg Latent: 0.03588..
#  Repulsive: 0.00173..
#  Memory: 502.99028..
#  Memory: 502.99028..
#  Output:
#  [[174.9304   186.92458  268.1021  ]
#  [109.16081  118.127914 178.45111 ]
#  [144.71283  156.13765  232.46535 ]]
# ====================
# Epoch: 400/400..
#  Training loss: 1384.53296..
#  torch.mean(F): 1379.67761..
#  Reg Proj: 4.80399..
#  Reg Latent: 0.05086..
#  Repulsive: 0.00051..
#  Memory: 275.93552..
#  Memory: 275.93552..
#  Output:
#  [[1520.3743 1698.7494 2832.7363]
#  [1470.784  1644.2954 2740.2864]
#  [1317.7739 1469.886  2462.259 ]]
# ====================
# getUncertaintyArea
# Ouputs are [[1836.3118 1453.5844 1055.1134]
#  [2161.7107 1711.6897 1242.7452]]
# scale is 3746
# dx is 3676.0, dy is 3746.0, dz is 3531.0
# z is torch.Size([8000])
# Processing...
# flag is 6595
# m is 1406
# i is 8000
# Labeled 0/1406 points.
# Labeled 1000/1406 points.
# Labeled all 1406/1406 points.
# Creating student for node 001 with 2 centroids.
# Device is: cpu
# ====================
# Training Student Model
# Acc:  0.4423897581792319
# Epoch:  0 Cost:  4671.13525390625
# Acc:  0.7339971550497866
# Epoch:  300 Cost:  50.77342987060547
# Acc:  0.7567567567567568
# Epoch:  600 Cost:  46.43912887573242
# Acc:  0.829302987197724
# Epoch:  900 Cost:  34.95603561401367
# Acc:  0.7908961593172119
# Epoch:  1200 Cost:  38.42570877075195
# Acc:  0.9182076813655761
# Epoch:  1500 Cost:  22.234912872314453
# Acc:  0.6401137980085349
# Epoch:  1800 Cost:  73.63013458251953
# Acc:  0.8314366998577525
# Epoch:  2100 Cost:  39.02185821533203
# Acc:  0.8862019914651493
# Epoch:  2400 Cost:  28.776948928833008
# Acc:  0.8975817923186344
# Epoch:  2700 Cost:  26.579204559326172
#
# ====================
# Creating student for node 002 that has 2235 data, which is more than the threshold 300.
# Bounding box for node 002: [[-4, 4000], [-8, 4006], [-7, 4002]]
# Creating teacher for node 002 with 3 centroids.
# ====================
# Training Teacher Model
# Shuffling data
# ====================
# Epoch: 20/400..
#  Training loss: 3120.10742..
#  torch.mean(F): 3106.03906..
#  Reg Proj: 13.96864..
#  Reg Latent: 0.09688..
#  Repulsive: 0.00258..
#  Memory: 621.20781..
#  Memory: 621.20781..
#  Output:
#  [[-46.126102 -49.666    -14.678815]
#  [-26.05307  -30.142103 -18.061419]
#  [-36.663082 -39.321903 -71.60726 ]]
# ====================
# Epoch: 40/400..
#  Training loss: 3159.46997..
#  torch.mean(F): 3142.88281..
#  Reg Proj: 16.42820..
#  Reg Latent: 0.15563..
#  Repulsive: 0.00336..
#  Memory: 628.57656..
#  Memory: 628.57656..
#  Output:
#  [[-68.98586  -30.898256 -32.872856]
#  [-43.70437  -20.0222   -21.459202]
#  [-88.913826 -39.6149   -42.13892 ]]
# ====================
# Epoch: 60/400..
#  Training loss: 3175.75854..
#  torch.mean(F): 3161.14697..
#  Reg Proj: 14.49740..
#  Reg Latent: 0.11191..
#  Repulsive: 0.00246..
#  Memory: 632.22939..
#  Memory: 632.22939..
#  Output:
#  [[  0.5307911    0.45972183   0.4437239 ]
#  [-32.64697    -31.028399   -28.21254   ]
#  [-60.781155   -57.638325   -52.470917  ]]
# ====================
# Epoch: 80/400..
#  Training loss: 3119.15601..
#  torch.mean(F): 3104.94434..
#  Reg Proj: 14.04920..
#  Reg Latent: 0.16086..
#  Repulsive: 0.00150..
#  Memory: 620.98887..
#  Memory: 620.98887..
#  Output:
#  [[  -0.49489403  -18.121115    -42.099354  ]
#  [  -1.4717295   -39.868534    -94.78841   ]
#  [  -3.6107965   -60.81878    -142.3945    ]]
# ====================
# Epoch: 100/400..
#  Training loss: 3127.14111..
#  torch.mean(F): 3117.02710..
#  Reg Proj: 9.90957..
#  Reg Latent: 0.20183..
#  Repulsive: 0.00255..
#  Memory: 623.40542..
#  Memory: 623.40542..
#  Output:
#  [[-1.1256974e+00 -1.6714084e+02  4.6230621e+00]
#  [-3.1335399e-02 -1.0815650e+02  1.0174248e+01]
#  [-1.2093098e-01 -1.3618410e+02  1.4743313e+01]]
# ====================
# Epoch: 120/400..
#  Training loss: 3215.81299..
#  torch.mean(F): 3203.12769..
#  Reg Proj: 12.21802..
#  Reg Latent: 0.38260..
#  Repulsive: 0.08481..
#  Memory: 640.62554..
#  Memory: 640.62554..
#  Output:
#  [[ -52.268597 -106.85043   -58.796276]
#  [ -52.497738 -107.46392   -59.10177 ]
#  [ -51.536137 -105.431915  -58.012974]]
# ====================
# Epoch: 140/400..
#  Training loss: 3237.69678..
#  torch.mean(F): 3231.71631..
#  Reg Proj: 5.69767..
#  Reg Latent: 0.28000..
#  Repulsive: 0.00266..
#  Memory: 646.34326..
#  Memory: 646.34326..
#  Output:
#  [[  74.06176  -223.73619   -68.69283 ]
#  [  40.865253 -248.29991   -76.18148 ]
#  [  16.536833 -244.43748   -75.07954 ]]
# ====================
# Epoch: 160/400..
#  Training loss: 2891.75195..
#  torch.mean(F): 2885.84595..
#  Reg Proj: 5.67442..
#  Reg Latent: 0.23055..
#  Repulsive: 0.00116..
#  Memory: 577.16919..
#  Memory: 577.16919..
#  Output:
#  [[ 749.3817  -202.58455  309.14703]
#  [ 579.835   -207.17267  237.54175]
#  [ 619.581   -186.97011  255.12315]]
# ====================
# Epoch: 180/400..
#  Training loss: 2473.99268..
#  torch.mean(F): 2464.18945..
#  Reg Proj: 9.57497..
#  Reg Latent: 0.22817..
#  Repulsive: 0.00011..
#  Memory: 492.83789..
#  Memory: 492.83789..
#  Output:
#  [[1236.7863  -406.0038  2056.0984 ]
#  [ -55.05772 -465.936    -91.36203]
#  [ 167.56203 -608.89355  276.77084]]
# ====================
# Epoch: 200/400..
#  Training loss: 3053.98315..
#  torch.mean(F): 3038.62158..
#  Reg Proj: 15.10944..
#  Reg Latent: 0.25116..
#  Repulsive: 0.00101..
#  Memory: 607.72432..
#  Memory: 607.72432..
#  Output:
#  [[ 3.2523492e-01  1.7561540e+02  6.4445366e+01]
#  [ 1.3252053e-01 -1.0210150e+00  1.2715195e+00]
#  [-1.8412282e-01  4.8814156e+01  1.3642129e+01]]
# ====================
# Epoch: 220/400..
#  Training loss: 2919.56201..
#  torch.mean(F): 2908.50415..
#  Reg Proj: 10.76068..
#  Reg Latent: 0.29681..
#  Repulsive: 0.00020..
#  Memory: 581.70083..
#  Memory: 581.70083..
#  Output:
#  [[  15.297505   645.47705     13.7255535]
#  [ -24.12783   -171.74501    -19.653713 ]
#  [  20.36895    380.0768      16.176487 ]]
# ====================
# Epoch: 240/400..
#  Training loss: 2235.70532..
#  torch.mean(F): 2228.66992..
#  Reg Proj: 6.77569..
#  Reg Latent: 0.25984..
#  Repulsive: 0.00009..
#  Memory: 445.73398..
#  Memory: 445.73398..
#  Output:
#  [[1303.6709    2607.4373      18.025728 ]
#  [-109.96185   -219.75502      3.1361012]
#  [1063.0159    2126.3398       4.7661405]]
# ====================
# Epoch: 260/400..
#  Training loss: 2772.47681..
#  torch.mean(F): 2763.82178..
#  Reg Proj: 8.38379..
#  Reg Latent: 0.27128..
#  Repulsive: 0.00006..
#  Memory: 552.76436..
#  Memory: 552.76436..
#  Output:
#  [[ 5.3912988e+00  2.7137332e+03  1.7700356e+00]
#  [ 1.1336190e+01 -4.2045419e+02  3.0781407e+00]
#  [-3.5220132e+00  2.0030724e+03 -5.2067769e-01]]
# ====================
# Epoch: 280/400..
#  Training loss: 2809.09570..
#  torch.mean(F): 2798.23364..
#  Reg Proj: 10.50725..
#  Reg Latent: 0.35450..
#  Repulsive: 0.00021..
#  Memory: 559.64673..
#  Memory: 559.64673..
#  Output:
#  [[  54.723824  837.4719     26.39024 ]
#  [ 150.60803  -117.72622    70.82373 ]
#  [  49.665974  619.80963    23.357903]]
# ====================
# Epoch: 300/400..
#  Training loss: 2996.71997..
#  torch.mean(F): 2968.23730..
#  Reg Proj: 27.94049..
#  Reg Latent: 0.54216..
#  Repulsive: 0.00004..
#  Memory: 593.64746..
#  Memory: 593.64746..
#  Output:
#  [[ 4.7164264e+00  6.2946201e+03  3.3457434e+03]
#  [ 2.9273371e+01 -6.0010272e+02 -3.1510608e+02]
#  [-4.9859433e+00  5.3058828e+03  2.8161050e+03]]
# ====================
# Epoch: 320/400..
#  Training loss: 2727.07812..
#  torch.mean(F): 2715.90771..
#  Reg Proj: 10.85906..
#  Reg Latent: 0.31107..
#  Repulsive: 0.00036..
#  Memory: 543.18154..
#  Memory: 543.18154..
#  Output:
#  [[ 7.9019465e+00  8.0456555e+02  1.0197579e+00]
#  [ 6.0789825e+01  2.1233337e+03  7.1020994e+00]
#  [-8.2546127e-01  7.0956842e+02 -7.0065171e-02]]
# ====================
# Epoch: 340/400..
#  Training loss: 2198.34106..
#  torch.mean(F): 2188.09717..
#  Reg Proj: 9.97568..
#  Reg Latent: 0.26811..
#  Repulsive: 0.00020..
#  Memory: 437.61943..
#  Memory: 437.61943..
#  Output:
#  [[ 614.2726   1086.4657     15.355097]
#  [1229.3322   2170.7104    126.72768 ]
#  [ 500.61523   888.8281     17.700697]]
# ====================
# Epoch: 360/400..
#  Training loss: 2111.63501..
#  torch.mean(F): 2104.18433..
#  Reg Proj: 7.15121..
#  Reg Latent: 0.29813..
#  Repulsive: 0.00158..
#  Memory: 420.83687..
#  Memory: 420.83687..
#  Output:
#  [[1292.2039   1998.5826     14.052524]
#  [1378.2842   2134.803      29.33023 ]
#  [1310.6161   2026.3131     21.527027]]
# ====================
# Epoch: 380/400..
#  Training loss: 2161.90112..
#  torch.mean(F): 2160.03784..
#  Reg Proj: 1.52077..
#  Reg Latent: 0.34115..
#  Repulsive: 0.00141..
#  Memory: 432.00757..
#  Memory: 432.00757..
#  Output:
#  [[2646.1028 2986.305  3112.3547]
#  [2466.5405 2785.591  2902.674 ]
#  [2490.2007 2812.6875 2927.811 ]]
# ====================
# Epoch: 400/400..
#  Training loss: 1649.50525..
#  torch.mean(F): 1647.76880..
#  Reg Proj: 1.43628..
#  Reg Latent: 0.29868..
#  Repulsive: 0.00152..
#  Memory: 329.55376..
#  Memory: 329.55376..
#  Output:
#  [[1227.742  1217.3248 2429.2483]
#  [1247.9896 1235.1807 2468.1692]
#  [1199.6957 1192.1897 2364.1821]]
# ====================
# getUncertaintyArea
# Ouputs are [[2134.5117   786.12866 2581.0964 ]
#  [2385.2517  1659.8552  2381.8667 ]
#  [1822.3029  1030.1475  1961.2253 ]]
# scale is 4014
# dx is 4004.0, dy is 4014.0, dz is 4009.0
# z is torch.Size([8000])
# Processing...
# flag is 4005
# m is 3996
# i is 8000
# Labeled 0/3996 points.
# Labeled 1000/3996 points.
# Labeled 2000/3996 points.
# Labeled 3000/3996 points.
# Labeled all 3996/3996 points.
# Creating student for node 002 with 3 centroids.
# Device is: cpu
# ====================
# Training Student Model
# Acc:  0.13513513513513514
# Epoch:  0 Cost:  5889.5185546875
# ...
# ====================
# Training Teacher Model
# ====================
# Epoch: 20/400..
#  Training loss: 2629.81543..
#  torch.mean(F): 2613.56201..
#  Reg Proj: 16.14426..
#  Reg Latent: 0.10649..
#  Repulsive: 0.00271..
#  Memory: 522.71240..
#  Memory: 522.71240..
#  Output:
#  [[ -0.85465914  14.831793    -4.652847  ]
#  [  3.7520702   92.26369     24.197012  ]
#  [  5.660602   100.42985     39.422356  ]]
# ====================
# Epoch: 40/400..
#  Training loss: 1930.76074..
#  torch.mean(F): 1925.32495..
#  Reg Proj: 5.35109..
#  Reg Latent: 0.08458..
#  Repulsive: 0.00018..
#  Memory: 385.06499..
#  Memory: 385.06499..
#  Output:
#  [[  69.3899   265.65256  369.40082]
#  [ 103.09817  516.76526  701.74207]
#  [ 196.76813  923.64813 1259.7579 ]]
# ====================
# Epoch: 60/400..
#  Training loss: 2655.62671..
#  torch.mean(F): 2642.31494..
#  Reg Proj: 13.20552..
#  Reg Latent: 0.10416..
#  Repulsive: 0.00200..
#  Memory: 528.46299..
#  Memory: 528.46299..
#  Output:
#  [[ 82.24381   17.83184   91.40492 ]
#  [ 48.38145    8.930603  54.230583]
#  [115.80965   21.585337 129.41911 ]]
# ====================
# Epoch: 80/400..
#  Training loss: 2692.92334..
#  torch.mean(F): 2637.08984..
#  Reg Proj: 55.70964..
#  Reg Latent: 0.12333..
#  Repulsive: 0.00057..
#  Memory: 527.41797..
#  Memory: 527.41797..
#  Output:
#  [[-23.526394  -4.789077 117.26259 ]
#  [ 59.53122   18.346582 112.22541 ]
#  [ 71.19546   24.306551 406.71558 ]]
# ====================
# Epoch: 100/400..
#  Training loss: 1473.35754..
#  torch.mean(F): 1472.80676..
#  Reg Proj: 0.36323..
#  Reg Latent: 0.18733..
#  Repulsive: 0.00017..
#  Memory: 294.56135..
#  Memory: 294.56135..
#  Output:
#  [[ 273.31528 1232.7079   643.6784 ]
#  [ 155.60963  700.9368   366.30994]
#  [ 360.4296  1622.9042   847.56726]]
# ====================
# Epoch: 120/400..
#  Training loss: 2279.52344..
#  torch.mean(F): 2223.23120..
#  Reg Proj: 55.94455..
#  Reg Latent: 0.34694..
#  Repulsive: 0.00062..
#  Memory: 444.64624..
#  Memory: 444.64624..
#  Output:
#  [[  1.3368522 698.8303      9.587337 ]
#  [ -0.8630132 184.10367     3.9005692]
#  [  2.8297276 638.3161     15.440179 ]]
# ====================
# Epoch: 140/400..
#  Training loss: 2183.75610..
#  torch.mean(F): 2182.73389..
#  Reg Proj: 0.54860..
#  Reg Latent: 0.47318..
#  Repulsive: 0.00050..
#  Memory: 436.54678..
#  Memory: 436.54678..
#  Output:
#  [[103.92283  532.1311   380.27905 ]
#  [ 54.833355 305.8482   216.22601 ]
#  [121.01175  640.1231   453.51505 ]]
# ====================
# Epoch: 160/400..
#  Training loss: 1995.73877..
#  torch.mean(F): 1714.60059..
#  Reg Proj: 280.57366..
#  Reg Latent: 0.56324..
#  Repulsive: 0.00121..
#  Memory: 342.92012..
#  Memory: 342.92012..
#  Output:
#  [[  18.432423 2957.2415     17.047987]
#  [  25.731775 2932.2112     22.034472]
#  [  79.17764  8511.954      69.36549 ]]
# ====================
# Epoch: 180/400..
#  Training loss: 1953.25513..
#  torch.mean(F): 1952.43213..
#  Reg Proj: 0.50401..
#  Reg Latent: 0.31836..
#  Repulsive: 0.00057..
#  Memory: 390.48643..
#  Memory: 390.48643..
#  Output:
#  [[ 671.6176   482.41818  159.38965]
#  [ 597.9878   428.3887   143.03955]
#  [1000.8004   717.96875  238.23062]]
# ====================
# Epoch: 200/400..
#  Training loss: 1195.21851..
#  torch.mean(F): 1191.17102..
#  Reg Proj: 3.66165..
#  Reg Latent: 0.38521..
#  Repulsive: 0.00055..
#  Memory: 238.23420..
#  Memory: 238.23420..
#  Output:
#  [[ 473.8464  2638.8225  2300.732  ]
#  [ 486.03662 2706.9805  2358.9966 ]
#  [ 577.1801  3217.5159  2804.7756 ]]
# ====================
# Epoch: 220/400..
#  Training loss: 2182.87744..
#  torch.mean(F): 2173.81567..
#  Reg Proj: 8.85116..
#  Reg Latent: 0.21038..
#  Repulsive: 0.00036..
#  Memory: 434.76313..
#  Memory: 434.76313..
#  Output:
#  [[223.30634 411.3408  548.00214]
#  [307.05215 566.47705 748.55597]
#  [134.19058 247.63446 328.75342]]
# ====================
# Epoch: 240/400..
#  Training loss: 2282.09863..
#  torch.mean(F): 1750.50635..
#  Reg Proj: 531.33857..
#  Reg Latent: 0.25311..
#  Repulsive: 0.00056..
#  Memory: 350.10127..
#  Memory: 350.10127..
#  Output:
#  [[1320.534    585.2411   863.01575]
#  [2593.5342  1148.1571  1693.4447 ]
#  [2535.3032  1123.075   1656.3212 ]]
# ====================
# Epoch: 260/400..
#  Training loss: 1845.50208..
#  torch.mean(F): 1799.66943..
#  Reg Proj: 45.26903..
#  Reg Latent: 0.56293..
#  Repulsive: 0.00056..
#  Memory: 359.93389..
#  Memory: 359.93389..
#  Output:
#  [[ 781.8081   578.6473   571.73663]
#  [1167.1393   821.2362   821.8074 ]
#  [1089.2227   789.41705  784.56793]]
# ====================
# Epoch: 280/400..
#  Training loss: 1509.67017..
#  torch.mean(F): 1503.09119..
#  Reg Proj: 5.84549..
#  Reg Latent: 0.73329..
#  Repulsive: 0.00022..
#  Memory: 300.61824..
#  Memory: 300.61824..
#  Output:
#  [[2133.1733 4095.7856 2907.9844]
#  [1768.9355 3430.2249 2409.1694]
#  [1670.9392 3217.4297 2273.8677]]
# ====================
# Epoch: 300/400..
#  Training loss: 1452.05432..
#  torch.mean(F): 1449.61072..
#  Reg Proj: 1.70363..
#  Reg Latent: 0.73979..
#  Repulsive: 0.00025..
#  Memory: 289.92214..
#  Memory: 289.92214..
#  Output:
#  [[ 550.5588  2697.478    207.82574]
#  [ 392.56128 2123.0408   178.65501]
#  [ 358.85486 1929.059    150.27222]]
# ====================
# Epoch: 320/400..
#  Training loss: 1136.51404..
#  torch.mean(F): 1130.22876..
#  Reg Proj: 5.54059..
#  Reg Latent: 0.74451..
#  Repulsive: 0.00009..
#  Memory: 226.04575..
#  Memory: 226.04575..
#  Output:
#  [[1416.3358 2798.6404 1783.5983]
#  [2348.228  4646.848  2958.2756]
#  [1735.8771 3409.0889 2189.5305]]
# ====================
# Epoch: 340/400..
#  Training loss: 1358.70984..
#  torch.mean(F): 1357.77515..
#  Reg Proj: 0.28213..
#  Reg Latent: 0.65226..
#  Repulsive: 0.00037..
#  Memory: 271.55503..
#  Memory: 271.55503..
#  Output:
#  [[ 294.15756 1492.6139   561.33704]
#  [ 387.7833  1967.2393   724.431  ]
#  [ 320.59396 1628.8541   617.2535 ]]
# ====================
# Epoch: 360/400..
#  Training loss: 1087.53271..
#  torch.mean(F): 1086.62634..
#  Reg Proj: 0.16920..
#  Reg Latent: 0.73272..
#  Repulsive: 0.00456..
#  Memory: 217.32527..
#  Memory: 217.32527..
#  Output:
#  [[ 569.09314 2124.3281  1421.5948 ]
#  [ 563.8879  2082.7778  1401.0245 ]
#  [ 555.1082  2084.2222  1391.3257 ]]
# ====================
# Epoch: 380/400..
#  Training loss: 1065.80505..
#  torch.mean(F): 1064.71924..
#  Reg Proj: 0.25090..
#  Reg Latent: 0.83319..
#  Repulsive: 0.00167..
#  Memory: 212.94385..
#  Memory: 212.94385..
#  Output:
#  [[ 493.9767  3210.2903  1643.6543 ]
#  [ 480.1648  3113.4119  1593.5537 ]
#  [ 483.66034 3147.2102  1611.9639 ]]
# ====================
# Epoch: 400/400..
#  Training loss: 1134.83728..
#  torch.mean(F): 1132.94763..
#  Reg Proj: 1.04004..
#  Reg Latent: 0.84895..
#  Repulsive: 0.00066..
#  Memory: 226.58953..
#  Memory: 226.58953..
#  Output:
#  [[ 652.45575 3102.6406   759.106  ]
#  [ 682.58203 3293.6492   812.6384 ]
#  [ 639.43634 3025.737    737.2869 ]]
# ====================
# getUncertaintyArea
# Ouputs are [[1286.8386 2134.7776 1938.4568]
#  [1044.1764 2460.835  1626.4933]
#  [1050.1519 2176.1125 1364.4229]]
# scale is 3149
# dx is 2921.0, dy is 3149.0, dz is 2962.0
# z is torch.Size([8000])
# Processing...
# flag is 1551
# m is 6450
# i is 8000
# Labeled 0/6450 points.
# Labeled 1000/6450 points.
# Labeled 2000/6450 points.
# Labeled 3000/6450 points.
# Labeled 4000/6450 points.
# Labeled 5000/6450 points.
# Labeled 6000/6450 points.
# Labeled all 6450/6450 points.
# Creating student for node 001020 with 3 centroids.
# Device is: cpu
# ====================
# Training Student Model
# Acc:  0.4327131782945736
# Epoch:  0 Cost:  3945.722900390625
# Acc:  0.844031007751938
# Epoch:  300 Cost:  31.719552993774414
# Acc:  0.8807751937984496
# Epoch:  600 Cost:  27.0364933013916
# Acc:  0.8945736434108527
# Epoch:  900 Cost:  25.4976863861084
# Acc:  0.9043410852713178
# Epoch:  1200 Cost:  21.69235610961914
# Acc:  0.9046511627906977
# Epoch:  1500 Cost:  21.1707763671875
# Acc:  0.9049612403100775
# Epoch:  1800 Cost:  22.430805206298828
# Acc:  0.9226356589147287
# Epoch:  2100 Cost:  17.927417755126953
# Acc:  0.8649612403100775
# Epoch:  2400 Cost:  30.44612693786621
# Acc:  0.889922480620155
# Epoch:  2700 Cost:  25.563684463500977
#
# ====================
# Creating student for node 010002 that has 311 data, which is more than the threshold 300.
# Bounding box for node 010002: [[58, 2970], [1117, 3966], [1789, 4002]]
# Creating teacher for node 010002 with 3 centroids.
# ====================
# Training Teacher Model
# ====================
# Epoch: 20/400..
#  Training loss: 3490.92017..
#  torch.mean(F): 3445.92920..
#  Reg Proj: 44.81959..
#  Reg Latent: 0.15194..
#  Repulsive: 0.01963..
#  Memory: 689.18584..
#  Memory: 689.18584..
#  Output:
#  [[-27.146738  -8.255374 -16.19566 ]
#  [114.1882    29.913956  68.580315]
#  [-25.584421  -8.433204 -15.308883]]
# ====================
# Epoch: 40/400..
#  Training loss: 3151.19507..
#  torch.mean(F): 3123.62280..
#  Reg Proj: 27.40601..
#  Reg Latent: 0.16588..
#  Repulsive: 0.00044..
#  Memory: 624.72456..
#  Memory: 624.72456..
#  Output:
#  [[292.80215 215.78798 257.65268]
#  [444.53906 330.54828 396.51828]
#  [ 97.63202  71.7132   85.40606]]
# ====================
# Epoch: 60/400..
#  Training loss: 1927.84314..
#  torch.mean(F): 1895.93994..
#  Reg Proj: 31.69562..
#  Reg Latent: 0.20736..
#  Repulsive: 0.00007..
#  Memory: 379.18799..
#  Memory: 379.18799..
#  Output:
#  [[1590.3004  1356.7698  1082.3588 ]
#  [ 597.5648   511.1924   406.97812]
#  [2893.6448  2470.2334  1969.6642 ]]
# ====================
# Epoch: 80/400..
#  Training loss: 2645.23193..
#  torch.mean(F): 2620.04639..
#  Reg Proj: 24.94015..
#  Reg Latent: 0.24461..
#  Repulsive: 0.00078..
#  Memory: 524.00928..
#  Memory: 524.00928..
#  Output:
#  [[591.55096 898.11383 883.934  ]
#  [465.1898  704.9215  694.3039 ]
#  [526.6974  798.9498  786.5931 ]]
# ====================
# Epoch: 100/400..
#  Training loss: 1329.53271..
#  torch.mean(F): 1304.04028..
#  Reg Proj: 25.13984..
#  Reg Latent: 0.35237..
#  Repulsive: 0.00017..
#  Memory: 260.80806..
#  Memory: 260.80806..
#  Output:
#  [[ 366.9419   884.75494 1250.8447 ]
#  [ 736.9182  1777.5282  2514.9485 ]
#  [ 297.39     717.2058  1014.5303 ]]
# ====================
# Epoch: 120/400..
#  Training loss: 1167.53796..
#  torch.mean(F): 1160.07959..
#  Reg Proj: 7.11348..
#  Reg Latent: 0.34459..
#  Repulsive: 0.00026..
#  Memory: 232.01592..
#  Memory: 232.01592..
#  Output:
#  [[1611.416  1737.897  4546.359 ]
#  [1328.2458 1432.4014 3747.7808]
#  [1390.9579 1500.1461 3924.3237]]
# ====================
# Epoch: 140/400..
#  Training loss: 1096.36914..
#  torch.mean(F): 1082.62207..
#  Reg Proj: 13.28713..
#  Reg Latent: 0.45977..
#  Repulsive: 0.00026..
#  Memory: 216.52441..
#  Memory: 216.52441..
#  Output:
#  [[1156.1084 1731.1775 1732.5273]
#  [1618.3413 2424.113  2425.4617]
#  [1285.7994 1925.7196 1926.9684]]
# ====================
# Epoch: 160/400..
#  Training loss: 3487.11255..
#  torch.mean(F): 3457.46313..
#  Reg Proj: 29.08523..
#  Reg Latent: 0.52872..
#  Repulsive: 0.03538..
#  Memory: 691.49263..
#  Memory: 691.49263..
#  Output:
#  [[39.103127 53.06988  41.03571 ]
#  [44.473988 60.255848 46.62309 ]
#  [39.81416  54.21321  41.828102]]
# ====================
# Epoch: 180/400..
#  Training loss: 2617.35205..
#  torch.mean(F): 2540.04297..
#  Reg Proj: 76.81340..
#  Reg Latent: 0.49546..
#  Repulsive: 0.00035..
#  Memory: 508.00859..
#  Memory: 508.00859..
#  Output:
#  [[ 161.91565  229.68338  900.8742 ]
#  [ 242.77815  344.5508  1349.398  ]
#  [ 194.49028  275.9083  1081.3713 ]]
# ====================
# Epoch: 200/400..
#  Training loss: 1426.76721..
#  torch.mean(F): 1407.65369..
#  Reg Proj: 18.50423..
#  Reg Latent: 0.60913..
#  Repulsive: 0.00013..
#  Memory: 281.53074..
#  Memory: 281.53074..
#  Output:
#  [[2236.2632 2165.8547 2204.4006]
#  [1560.0446 1510.8691 1537.1877]
#  [1044.9008 1011.9376 1029.7428]]
# ====================
# Epoch: 220/400..
#  Training loss: 2249.47827..
#  torch.mean(F): 2221.14624..
#  Reg Proj: 27.47153..
#  Reg Latent: 0.86004..
#  Repulsive: 0.00041..
#  Memory: 444.22925..
#  Memory: 444.22925..
#  Output:
#  [[ 237.35329 1248.375   1141.1921 ]
#  [ 263.539   1385.1432  1265.9496 ]
#  [ 188.21832  988.715    903.71246]]
# ====================
# Epoch: 240/400..
#  Training loss: 1358.20422..
#  torch.mean(F): 1349.14709..
#  Reg Proj: 7.75598..
#  Reg Latent: 1.30086..
#  Repulsive: 0.00021..
#  Memory: 269.82942..
#  Memory: 269.82942..
#  Output:
#  [[ 136.9852  3349.3381  2302.6023 ]
#  [ 104.74588 2546.697   1750.3439 ]
#  [ 114.6673  2798.038   1923.3102 ]]
# ====================
# Epoch: 260/400..
#  Training loss: 2337.30225..
#  torch.mean(F): 2310.94775..
#  Reg Proj: 25.42214..
#  Reg Latent: 0.93198..
#  Repulsive: 0.00049..
#  Memory: 462.18955..
#  Memory: 462.18955..
#  Output:
#  [[ 236.81235 2313.8381  1050.9    ]
#  [ 214.85806 2111.2747   957.96655]
#  [ 203.69815 1991.3188   904.4147 ]]
# ====================
# Epoch: 280/400..
#  Training loss: 729.14960..
#  torch.mean(F): 723.80798..
#  Reg Proj: 3.66714..
#  Reg Latent: 1.67164..
#  Repulsive: 0.00290..
#  Memory: 144.76160..
#  Memory: 144.76160..
#  Output:
#  [[1083.6329 2985.7417 2913.9736]
#  [1136.5106 2914.9495 2845.0664]
#  [1097.871  2996.5193 2924.01  ]]
# ====================
# Epoch: 300/400..
#  Training loss: 1557.18176..
#  torch.mean(F): 1541.16431..
#  Reg Proj: 14.67552..
#  Reg Latent: 1.34169..
#  Repulsive: 0.00024..
#  Memory: 308.23286..
#  Memory: 308.23286..
#  Output:
#  [[  82.23847 2906.5996  1778.386  ]
#  [  76.58329 2608.6401  1596.0941 ]
#  [  90.12754 3224.822   1972.5154 ]]
# ====================
# Epoch: 320/400..
#  Training loss: 1135.40332..
#  torch.mean(F): 1129.61340..
#  Reg Proj: 4.83822..
#  Reg Latent: 0.95087..
#  Repulsive: 0.00071..
#  Memory: 225.92268..
#  Memory: 225.92268..
#  Output:
#  [[ 735.96564 2456.9712  2373.5679 ]
#  [ 757.6892  2528.168   2442.7427 ]
#  [ 681.4493  2275.5046  2198.451  ]]
# ====================
# Epoch: 340/400..
#  Training loss: 950.28839..
#  torch.mean(F): 947.19305..
#  Reg Proj: 1.90803..
#  Reg Latent: 1.18721..
#  Repulsive: 0.00015..
#  Memory: 189.43861..
#  Memory: 189.43861..
#  Output:
#  [[ 642.2617 2480.1821 4340.4717]
#  [ 717.0691 2768.8647 4846.633 ]
#  [ 570.3435 2203.9858 3857.0266]]
# ====================
# Epoch: 360/400..
#  Training loss: 1017.23334..
#  torch.mean(F): 1006.06781..
#  Reg Proj: 9.80847..
#  Reg Latent: 1.35658..
#  Repulsive: 0.00050..
#  Memory: 201.21356..
#  Memory: 201.21356..
#  Output:
#  [[ 913.9459  1981.7205  4218.9116 ]
#  [ 846.42535 1838.6653  3915.4353 ]
#  [ 878.1553  1901.7028  4048.2344 ]]
# ====================
# Epoch: 380/400..
#  Training loss: 1250.85547..
#  torch.mean(F): 1227.48901..
#  Reg Proj: 21.33475..
#  Reg Latent: 2.03139..
#  Repulsive: 0.00031..
#  Memory: 245.49780..
#  Memory: 245.49780..
#  Output:
#  [[ 938.6049 3004.7756 1875.3958]
#  [ 990.6398 3174.399  1980.8779]
#  [1114.41   3566.7283 2225.9875]]
# ====================
# Epoch: 400/400..
#  Training loss: 1708.41650..
#  torch.mean(F): 1695.94177..
#  Reg Proj: 10.18466..
#  Reg Latent: 2.28957..
#  Repulsive: 0.00045..
#  Memory: 339.18835..
#  Memory: 339.18835..
#  Output:
#  [[ 182.31346 1643.7783  2000.0344 ]
#  [ 230.39253 1266.0242  1532.0953 ]
#  [ 150.95647 1342.4352  1630.3138 ]]
# ====================
# getUncertaintyArea
# Ouputs are [[1079.9548 2616.165  3260.42  ]
#  [1057.8832 2636.5146 2779.5945]
#  [1318.3905 3070.8645 3421.576 ]]
# scale is 2912
# dx is 2912.0, dy is 2849.0, dz is 2213.0
# z is torch.Size([8000])
# Processing...
# flag is 1525
# m is 6476
# i is 8000
# Labeled 0/6476 points.
# Labeled 1000/6476 points.
# Labeled 2000/6476 points.
# Labeled 3000/6476 points.
# Labeled 4000/6476 points.
# Labeled 5000/6476 points.
# Labeled 6000/6476 points.
# Labeled all 6476/6476 points.
# Creating student for node 010002 with 3 centroids.
# Device is: cpu
# ====================
# Training Student Model
# Acc:  0.08987029030265596
# Epoch:  0 Cost:  11289.0927734375
# Acc:  0.8431130327362569
# Epoch:  300 Cost:  33.01177215576172
# Acc:  0.8639592340951204
# Epoch:  600 Cost:  30.08026695251465
# Acc:  0.8761581222977146
# Epoch:  900 Cost:  28.26373291015625
# Acc:  0.8820259419394688
# Epoch:  1200 Cost:  27.54952049255371
# Acc:  0.9104385423100679
# Epoch:  1500 Cost:  21.490535736083984
# Acc:  0.9254169240271772
# Epoch:  1800 Cost:  19.427762985229492
# Acc:  0.9352995676343422
# Epoch:  2100 Cost:  18.12885856628418
# Acc:  0.8874305126621371
# Epoch:  2400 Cost:  27.036216735839844
# Acc:  0.9013279802347128
# Epoch:  2700 Cost:  23.62618064880371

# %%
# Report some tree stats.
leaves = ktree.get_leaves()
number_of_nodes = ktree.number_of_nodes

height = max([len(leaf.index) for leaf in leaves])
print(f"Tree height is {height}.")

leaf_sizes = [len(leaf.data) for leaf in leaves]
print(f"Created {len(leaves)} leaves with sizes")
print(leaf_sizes)
print(number_of_nodes)
# Out:
# Tree height is 7.
# Created 61 leaves with sizes
# [271, 292, 1, 42, 134, 149, 20, 178, 219, 187, 238, 83, 179, 284, 43, 119, 248, 224, 786, 31, 198, 183, 205, 37, 69, 170, 227, 140, 148, 103, 72, 176, 103, 191, 153, 61, 95, 153, 118, 146, 250, 115, 163, 195, 139, 172, 235, 183, 113, 289, 261, 90, 102, 136, 83, 145, 273, 268, 96, 74, 141]
# 93

# %%
from src.utils import accuracy as acc

k = [500,1000]

for different_k in k:
    print(f"Current k is: {different_k}")
    print("Printing results for random queries")
    acc.random_queries(ktree, k = different_k)
# Out:
# Current k is: 500
# Printing results for random queries
# The number of queries per layer are:
# [300. 300. 287. 239.  91.  23.]
# The percentage of correct predictions per layer is:
# [100. 100. 100. 100. 100. 100.]
# The number of queries per layer are:
# [300. 300. 296. 258.  88.  24.]
# The percentage of correct predictions per layer is:
# [100. 100. 100. 100. 100. 100.]
# The number of queries per layer are:
# [300. 300. 289. 242.  88.  20.]
# The percentage of correct predictions per layer is:
# [100. 100. 100. 100. 100. 100.]
# The number of queries per layer are:
# [300. 300. 294. 248.  90.  23.]
# The percentage of correct predictions per layer is:
# [100. 100. 100. 100. 100. 100.]
# The mean percentage of correct predictions per layer is:
# [100. 100. 100. 100. 100. 100.]
# Current k is: 1000
# Printing results for random queries
# The number of queries per layer are:
# [300. 300. 287. 239.  91.  23.]
# The percentage of correct predictions per layer is:
# [100. 100. 100. 100. 100. 100.]
# The number of queries per layer are:
# [300. 300. 296. 258.  88.  24.]
# The percentage of correct predictions per layer is:
# [100. 100. 100. 100. 100. 100.]
# The number of queries per layer are:
# [300. 300. 289. 242.  88.  20.]
# The percentage of correct predictions per layer is:
# [100. 100. 100. 100. 100. 100.]
# The number of queries per layer are:
# [300. 300. 294. 248.  90.  23.]
# The percentage of correct predictions per layer is:
# [100. 100. 100. 100. 100. 100.]
# The mean percentage of correct predictions per layer is:
# [100. 100. 100. 100. 100. 100.]

# %%
import numpy as np
import matplotlib.pyplot as plt
mean_acc_per_layer = np.zeros(height)
times=0
while times < 4:
    # now lets create randomly N points in the space 0-300, 0-300
    n = 300
    random_p = torch.zeros(n, 3)
    x_lim = [min(data[:, 0]), max(data[:, 0])]
    y_lim = [min(data[:, 1]), max(data[:, 1])]
    z_lim = [min(data[:, 2]), max(data[:, 2])]

    for i in range(n):
        random_p[i] = torch.Tensor([np.random.randint(x_lim[0], x_lim[1]), np.random.randint(y_lim[0], y_lim[1]), np.random.randint(z_lim[0], z_lim[1])])
    infer_points = random_p.to(device)

    correct_predictions_per_layer = np.zeros(height)
    accuracy_per_layer = np.zeros(height)
    
    qp = infer_points
    for i, query_point in enumerate(qp):
        preds_per_layer = ktree.query_verbose(query_point)["predictions per layer"]
        brute_force = ktree.root.query(query_point)

        for j, pred in enumerate(preds_per_layer):
            if np.array_equal(pred, brute_force):
                correct_predictions_per_layer[j] += 1

    accuracy_per_layer = correct_predictions_per_layer / len(infer_points) * 100
    mean_acc_per_layer += accuracy_per_layer
    times += 1
    print(f"The percentage of correct predictions per layer is: ")
    print(accuracy_per_layer)

print(f"The mean percentage of correct predictions is: ")
print(mean_acc_per_layer/times)
# Out:
# The percentage of correct predictions per layer is:
# [86.66666667 75.66666667 65.66666667 57.66666667 42.33333333 11.
#   1.66666667]
# The percentage of correct predictions per layer is:
# [88.66666667 76.33333333 61.33333333 57.33333333 42.66666667 11.66666667
#   2.        ]
# The percentage of correct predictions per layer is:
# [87.66666667 79.33333333 67.66666667 61.66666667 45.66666667  9.
#   1.        ]
# The percentage of correct predictions per layer is:
# [89.33333333 79.         68.66666667 63.         47.66666667 11.66666667
#   2.        ]
# The mean percentage of correct predictions is:
# [88.08333333 77.58333333 65.83333333 59.91666667 44.58333333 10.83333333
#   1.66666667]

# %%
import numpy as np
import matplotlib.pyplot as plt
mean_acc_per_layer = np.zeros(height)
times=0
while times < 4:
    # now lets create randomly N points in the space 0-300, 0-300
    n = 300
    random_p = torch.zeros(n, 3)
    x_lim = [min(data[:, 0]), max(data[:, 0])]
    y_lim = [min(data[:, 1]), max(data[:, 1])]
    z_lim = [min(data[:, 2]), max(data[:, 2])]

    for i in range(n):
        random_p[i] = torch.Tensor([np.random.randint(x_lim[0], x_lim[1]), np.random.randint(y_lim[0], y_lim[1]), np.random.randint(z_lim[0], z_lim[1])])
    infer_points = random_p.to(device)
    
    qp = infer_points
    for i, query_point in enumerate(qp):
        preds_per_layer = ktree.query_verbose(query_point)["predictions per layer"]
        k_nearest_neighbors = ktree.root.query(query_point, k=2)

        for j, pred in enumerate(preds_per_layer):
            if any(np.array_equal(pred, neighbor) for neighbor in k_nearest_neighbors):
                correct_predictions_per_layer[j] += 1

    accuracy_per_layer = correct_predictions_per_layer / len(infer_points) * 100
    mean_acc_per_layer += accuracy_per_layer
    times += 1
    print(f"The percentage of correct predictions per layer is: ")
    print(accuracy_per_layer)

print(f"The mean percentage of correct predictions is: ")
print(mean_acc_per_layer/times)
# Out:
# The percentage of correct predictions per layer is:
# [89.33333333 79.         68.66666667 63.         47.66666667 11.66666667
#   2.        ]
# The percentage of correct predictions per layer is:
# [89.33333333 79.         68.66666667 63.         47.66666667 11.66666667
#   2.        ]
# The percentage of correct predictions per layer is:
# [89.33333333 79.         68.66666667 63.         47.66666667 11.66666667
#   2.        ]
# The percentage of correct predictions per layer is:
# [89.33333333 79.         68.66666667 63.         47.66666667 11.66666667
#   2.        ]
# The mean percentage of correct predictions is:
# [89.33333333 79.         68.66666667 63.         47.66666667 11.66666667
#   2.        ]

# %%
import numpy as np
import matplotlib.pyplot as plt
mean_acc_per_layer = np.zeros(height)
times=0

while times < 1:
    nop =  500
    random_p = torch.zeros(nop, 3)
    x_lim = [min(data[:, 0]), max(data[:, 0])]
    y_lim = [min(data[:, 1]), max(data[:, 1])]
    z_lim = [min(data[:, 2]), max(data[:, 2])]
    num = int(nop ** (1/3))
    for i, x in enumerate(np.linspace(x_lim[0],x_lim[1], num)):
        for j, y in enumerate(np.linspace(y_lim[0],y_lim[1], num)):
            for k, z in enumerate(np.linspace(z_lim[0],z_lim[1], num)):
                random_p[i * (num ** 2) + j * num + k] = torch.Tensor([x, y, z])
    
    infer_points = random_p.to(device)
    # plt.scatter(infer_points[:,0], infer_points[:,1], infer_points[:,2])

    correct_predictions_per_layer = np.zeros(height)
    accuracy_per_layer = np.zeros(height)

    qp = infer_points
    for i, query_point in enumerate(qp):
        preds_per_layer = ktree.query_verbose(query_point)["predictions per layer"]
        brute_force = ktree.root.query(query_point)

        for j, pred in enumerate(preds_per_layer):
            if np.array_equal(pred, brute_force):
                correct_predictions_per_layer[j] += 1

    accuracy_per_layer = correct_predictions_per_layer / len(infer_points) * 100
    mean_acc_per_layer += accuracy_per_layer
    times += 1
    print(f"The percentage of correct predictions per layer is: ")
    print(accuracy_per_layer)

print(f"The mean percentage of correct predictions is: ")
print(mean_acc_per_layer/times)
# Out:
# The percentage of correct predictions per layer is:
# [88.4 83.  77.2 72.2 30.6  8.6  1.4]
# The mean percentage of correct predictions is:
# [88.4 83.  77.2 72.2 30.6  8.6  1.4]

# %%
import numpy as np
import matplotlib.pyplot as plt
mean_acc_per_layer = np.zeros(height)
times=0

while times < 1:
    nop =  500
    random_p = torch.zeros(nop, 3)
    x_lim = [min(data[:, 0]), max(data[:, 0])]
    y_lim = [min(data[:, 1]), max(data[:, 1])]
    z_lim = [min(data[:, 2]), max(data[:, 2])]
    num = int(nop ** (1/3))
    for i, x in enumerate(np.linspace(x_lim[0],x_lim[1], num)):
        for j, y in enumerate(np.linspace(y_lim[0],y_lim[1], num)):
            for k, z in enumerate(np.linspace(z_lim[0],z_lim[1], num)):
                random_p[i * (num ** 2) + j * num + k] = torch.Tensor([x, y, z])
    
    infer_points = random_p.to(device)
    # plt.scatter(infer_points[:,0], infer_points[:,1], infer_points[:,2])

    correct_predictions_per_layer = np.zeros(height)
    accuracy_per_layer = np.zeros(height)

    qp = infer_points
    for i, query_point in enumerate(qp):
        preds_per_layer = ktree.query_verbose(query_point)["predictions per layer"]
        k_nearest_neighbors = ktree.root.query(query_point, k=3)

        
        for j, pred in enumerate(preds_per_layer):
            if any(np.array_equal(pred, neighbor) for neighbor in k_nearest_neighbors):
                correct_predictions_per_layer[j] += 1

    accuracy_per_layer = correct_predictions_per_layer / len(infer_points) * 100
    mean_acc_per_layer += accuracy_per_layer
    times += 1
    print(f"The percentage of correct predictions per layer is: ")
    print(accuracy_per_layer)

print(f"The mean percentage of correct predictions is: ")
print(mean_acc_per_layer/times)
# Out:
# The percentage of correct predictions per layer is:
# [0. 0. 0. 0. 0. 0. 0.]
# The mean percentage of correct predictions is:
# [0. 0. 0. 0. 0. 0. 0.]
